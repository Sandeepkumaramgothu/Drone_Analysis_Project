# %%
# !pip install --upgrade keras
# !pip install --upgrade keras tensorflow
import os
import math
import numpy as np
import librosa
import json
import pandas as pd
from termcolor import colored
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
# !pip install tensorboard
# !pip install visualkeras
import visualkeras
from keras.utils import plot_model
from datetime import datetime
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn import svm
from sklearn.svm import SVC
import pickle
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from IPython.display import Audio
from scipy.io import wavfile
import scipy
import soundfile as sf
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras import layers, models
from sklearn.metrics import classification_report
import random

import csv
from keras.callbacks import Callback
from keras.callbacks import CSVLogger
from sklearn.metrics import precision_recall_fscore_support

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting keras
#   Downloading keras-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Collecting namex (from keras)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Collecting optree (from keras)
#   Downloading optree-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Downloading keras-3.4.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.0 MB/s eta 0:00:00
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.7/347.7 kB 12.1 MB/s eta 0:00:00
# Installing collected packages: namex, optree, keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.4.1 which is incompatible.
# Successfully installed keras-3.4.1 namex-0.0.8 optree-0.12.1
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting tensorflow
#   Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Collecting ml-dtypes (from keras)
#   Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow)
#   Downloading tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 2.7 MB/s eta 0:00:00
# Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 39.7 MB/s eta 0:00:00
# Downloading tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 55.4 MB/s eta 0:00:00
# Installing collected packages: ml-dtypes, tensorboard, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.17.0 which is incompatible.
# Successfully installed ml-dtypes-0.4.0 tensorboard-2.17.0 tensorflow-2.17.0
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Collecting visualkeras
#   Downloading visualkeras-0.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.26.4)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (661 bytes)
# Downloading visualkeras-0.1.3-py3-none-any.whl (16 kB)
# Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 13.0 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18.post0 visualkeras-0.1.3
# Mounted at /content/drive

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms_256HL/Train/'
test_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms_256HL/Test/'

num_classes = 7
height = 128
n_fft = 2048
hop_length = 256
sr = 16000
T = 1

hop_size_sec = hop_length / sr
audio_length_samples = T * sr

width = 1 + int((audio_length_samples - n_fft) / hop_length)

channels = 3

train_datagen = ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator()

batch_size = 32

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical')

model = tf.keras.Sequential()

# Convolutional layers
model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(height, width, channels)))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Conv2D(128, (3, 3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))

# Flatten layer to feed into fully connected layers
model.add(tf.keras.layers.Flatten())

# Dense layers
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(num_classes, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy', 'precision', 'recall', 'f1_score'])

epochs = 185
metrics_data = []

for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")

    train_generator.reset()

    history = model.fit(
        train_generator,
        steps_per_epoch=len(train_generator),
        epochs=1,
        verbose=1)

    accuracy = history.history['accuracy'][0]
    precision = history.history['precision'][0]
    recall = history.history['recall'][0]

    f1_score_tensor = history.history['f1_score'][0]
    f1_score_value = np.mean(f1_score_tensor)

    metrics_data.append([accuracy, precision, recall, f1_score_value])

csv_filename = 'training_metrics.csv'

with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Accuracy', 'Precision', 'Recall', 'F1 Score'])
    writer.writerows(metrics_data)

print(f"Training metrics saved to {csv_filename}")

loss, accuracy, precision, recall, f1_score = model.evaluate(test_generator)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test F1 Score:", f1_score)

model.save('al-emadi_cnn_standardized_unknown__256HL.keras')
# Out:
# Found 3088 images belonging to 7 classes.
# Found 768 images belonging to 7 classes.
# Epoch 1/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 102s 972ms/step - accuracy: 0.4640 - f1_score: 0.2738 - loss: 12.0010 - precision: 0.5650 - recall: 0.3465
# Epoch 2/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 98s 963ms/step - accuracy: 0.7407 - f1_score: 0.6480 - loss: 0.7890 - precision: 0.8324 - recall: 0.6268
# Epoch 3/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 96s 943ms/step - accuracy: 0.8096 - f1_score: 0.7405 - loss: 0.5848 - precision: 0.8696 - recall: 0.7528
# Epoch 4/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 97s 939ms/step - accuracy: 0.8162 - f1_score: 0.7611 - loss: 0.5276 - precision: 0.8744 - recall: 0.7653
# Epoch 5/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 100s 987ms/step - accuracy: 0.8390 - f1_score: 0.7774 - loss: 0.4680 - precision: 0.8865 - recall: 0.7876
# Epoch 6/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 919ms/step - accuracy: 0.8419 - f1_score: 0.7949 - loss: 0.4545 - precision: 0.8800 - recall: 0.8058
# Epoch 7/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 908ms/step - accuracy: 0.8550 - f1_score: 0.8143 - loss: 0.4008 - precision: 0.8886 - recall: 0.8197
# Epoch 8/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 933ms/step - accuracy: 0.8651 - f1_score: 0.8347 - loss: 0.3899 - precision: 0.9015 - recall: 0.8349
# Epoch 9/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 96s 938ms/step - accuracy: 0.8753 - f1_score: 0.8481 - loss: 0.3456 - precision: 0.9117 - recall: 0.8506
# Epoch 10/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 944ms/step - accuracy: 0.8896 - f1_score: 0.8671 - loss: 0.3128 - precision: 0.9295 - recall: 0.8643
# Epoch 11/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 921ms/step - accuracy: 0.8951 - f1_score: 0.8732 - loss: 0.2953 - precision: 0.9213 - recall: 0.8726
# Epoch 12/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 929ms/step - accuracy: 0.8954 - f1_score: 0.8752 - loss: 0.2904 - precision: 0.9248 - recall: 0.8726
# Epoch 13/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 937ms/step - accuracy: 0.8867 - f1_score: 0.8704 - loss: 0.3266 - precision: 0.9122 - recall: 0.8637
# Epoch 14/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 104s 1s/step - accuracy: 0.8917 - f1_score: 0.8709 - loss: 0.3036 - precision: 0.9165 - recall: 0.8687
# Epoch 15/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 925ms/step - accuracy: 0.9043 - f1_score: 0.8906 - loss: 0.2744 - precision: 0.9288 - recall: 0.8875
# Epoch 16/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 934ms/step - accuracy: 0.9317 - f1_score: 0.9206 - loss: 0.2147 - precision: 0.9475 - recall: 0.9150
# Epoch 17/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 97s 944ms/step - accuracy: 0.9172 - f1_score: 0.9038 - loss: 0.2661 - precision: 0.9327 - recall: 0.8965
# Epoch 18/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 932ms/step - accuracy: 0.9266 - f1_score: 0.9155 - loss: 0.2054 - precision: 0.9400 - recall: 0.9113
# Epoch 19/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 929ms/step - accuracy: 0.9189 - f1_score: 0.9047 - loss: 0.2171 - precision: 0.9346 - recall: 0.9010
# Epoch 20/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 907ms/step - accuracy: 0.9093 - f1_score: 0.8913 - loss: 0.2507 - precision: 0.9238 - recall: 0.8927
# Epoch 21/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 97s 948ms/step - accuracy: 0.9371 - f1_score: 0.9285 - loss: 0.1960 - precision: 0.9485 - recall: 0.9196
# Epoch 22/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 918ms/step - accuracy: 0.9129 - f1_score: 0.8937 - loss: 0.2390 - precision: 0.9255 - recall: 0.9035
# Epoch 23/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 940ms/step - accuracy: 0.9221 - f1_score: 0.9155 - loss: 0.2320 - precision: 0.9369 - recall: 0.9092
# Epoch 24/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 912ms/step - accuracy: 0.9312 - f1_score: 0.9161 - loss: 0.1931 - precision: 0.9445 - recall: 0.9238
# Epoch 25/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 881ms/step - accuracy: 0.9255 - f1_score: 0.9169 - loss: 0.2077 - precision: 0.9370 - recall: 0.9090
# Epoch 26/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 917ms/step - accuracy: 0.9149 - f1_score: 0.8947 - loss: 0.2599 - precision: 0.9304 - recall: 0.9071
# Epoch 27/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 911ms/step - accuracy: 0.9342 - f1_score: 0.9275 - loss: 0.2045 - precision: 0.9437 - recall: 0.9117
# Epoch 28/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 911ms/step - accuracy: 0.9335 - f1_score: 0.9263 - loss: 0.2016 - precision: 0.9459 - recall: 0.9171
# Epoch 29/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 912ms/step - accuracy: 0.9234 - f1_score: 0.8974 - loss: 0.2221 - precision: 0.9357 - recall: 0.9169
# Epoch 30/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 931ms/step - accuracy: 0.9339 - f1_score: 0.9216 - loss: 0.1907 - precision: 0.9434 - recall: 0.9251
# Epoch 31/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 920ms/step - accuracy: 0.9229 - f1_score: 0.9075 - loss: 0.2211 - precision: 0.9401 - recall: 0.9153
# Epoch 32/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 909ms/step - accuracy: 0.9220 - f1_score: 0.9021 - loss: 0.2065 - precision: 0.9398 - recall: 0.9078
# Epoch 33/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 899ms/step - accuracy: 0.9399 - f1_score: 0.9374 - loss: 0.1830 - precision: 0.9480 - recall: 0.9311
# Epoch 34/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 99s 974ms/step - accuracy: 0.9249 - f1_score: 0.9107 - loss: 0.2081 - precision: 0.9391 - recall: 0.9152
# Epoch 35/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 912ms/step - accuracy: 0.9334 - f1_score: 0.9287 - loss: 0.1893 - precision: 0.9431 - recall: 0.9234
# Epoch 36/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 924ms/step - accuracy: 0.9415 - f1_score: 0.9344 - loss: 0.1748 - precision: 0.9525 - recall: 0.9278
# Epoch 37/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 921ms/step - accuracy: 0.9359 - f1_score: 0.9258 - loss: 0.1861 - precision: 0.9461 - recall: 0.9275
# Epoch 38/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 920ms/step - accuracy: 0.9404 - f1_score: 0.9278 - loss: 0.1717 - precision: 0.9484 - recall: 0.9313
# Epoch 39/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 909ms/step - accuracy: 0.9393 - f1_score: 0.9303 - loss: 0.1809 - precision: 0.9525 - recall: 0.9254
# Epoch 40/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 923ms/step - accuracy: 0.9403 - f1_score: 0.9343 - loss: 0.1713 - precision: 0.9516 - recall: 0.9320
# Epoch 41/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 96s 945ms/step - accuracy: 0.9466 - f1_score: 0.9355 - loss: 0.1528 - precision: 0.9537 - recall: 0.9384
# Epoch 42/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 930ms/step - accuracy: 0.9510 - f1_score: 0.9480 - loss: 0.1560 - precision: 0.9595 - recall: 0.9452
# Epoch 43/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 916ms/step - accuracy: 0.9369 - f1_score: 0.9285 - loss: 0.1821 - precision: 0.9494 - recall: 0.9263
# Epoch 44/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 885ms/step - accuracy: 0.9386 - f1_score: 0.9269 - loss: 0.1932 - precision: 0.9475 - recall: 0.9292
# Epoch 45/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 903ms/step - accuracy: 0.9292 - f1_score: 0.9175 - loss: 0.2245 - precision: 0.9384 - recall: 0.9155
# Epoch 46/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 925ms/step - accuracy: 0.9515 - f1_score: 0.9431 - loss: 0.1524 - precision: 0.9611 - recall: 0.9426
# Epoch 47/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 925ms/step - accuracy: 0.9456 - f1_score: 0.9346 - loss: 0.1580 - precision: 0.9553 - recall: 0.9383
# Epoch 48/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.9481 - f1_score: 0.9431 - loss: 0.1503 - precision: 0.9593 - recall: 0.9466
# Epoch 49/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 103s 999ms/step - accuracy: 0.9319 - f1_score: 0.9197 - loss: 0.2101 - precision: 0.9420 - recall: 0.9227
# Epoch 50/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 102s 998ms/step - accuracy: 0.9401 - f1_score: 0.9297 - loss: 0.1737 - precision: 0.9473 - recall: 0.9332
# Epoch 51/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 914ms/step - accuracy: 0.9451 - f1_score: 0.9391 - loss: 0.1523 - precision: 0.9526 - recall: 0.9397
# Epoch 52/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 888ms/step - accuracy: 0.9461 - f1_score: 0.9429 - loss: 0.1417 - precision: 0.9551 - recall: 0.9414
# Epoch 53/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 906ms/step - accuracy: 0.9537 - f1_score: 0.9485 - loss: 0.1403 - precision: 0.9594 - recall: 0.9507
# Epoch 54/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 88s 870ms/step - accuracy: 0.9450 - f1_score: 0.9425 - loss: 0.1524 - precision: 0.9513 - recall: 0.9385
# Epoch 55/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 860ms/step - accuracy: 0.9452 - f1_score: 0.9361 - loss: 0.1597 - precision: 0.9534 - recall: 0.9358
# Epoch 56/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 872ms/step - accuracy: 0.9419 - f1_score: 0.9390 - loss: 0.1689 - precision: 0.9455 - recall: 0.9341
# Epoch 57/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 915ms/step - accuracy: 0.9483 - f1_score: 0.9430 - loss: 0.1516 - precision: 0.9557 - recall: 0.9434
# Epoch 58/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 911ms/step - accuracy: 0.9452 - f1_score: 0.9344 - loss: 0.1629 - precision: 0.9543 - recall: 0.9422
# Epoch 59/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 896ms/step - accuracy: 0.9461 - f1_score: 0.9386 - loss: 0.1732 - precision: 0.9556 - recall: 0.9361
# Epoch 60/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 900ms/step - accuracy: 0.9559 - f1_score: 0.9456 - loss: 0.1356 - precision: 0.9638 - recall: 0.9465
# Epoch 61/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 876ms/step - accuracy: 0.9505 - f1_score: 0.9458 - loss: 0.1491 - precision: 0.9562 - recall: 0.9451
# Epoch 62/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 901ms/step - accuracy: 0.9554 - f1_score: 0.9520 - loss: 0.1278 - precision: 0.9608 - recall: 0.9494
# Epoch 63/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 912ms/step - accuracy: 0.9593 - f1_score: 0.9567 - loss: 0.1141 - precision: 0.9620 - recall: 0.9560
# Epoch 64/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 96s 942ms/step - accuracy: 0.9661 - f1_score: 0.9644 - loss: 0.1084 - precision: 0.9703 - recall: 0.9616
# Epoch 65/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 935ms/step - accuracy: 0.9554 - f1_score: 0.9488 - loss: 0.1403 - precision: 0.9612 - recall: 0.9522
# Epoch 66/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 899ms/step - accuracy: 0.9577 - f1_score: 0.9564 - loss: 0.1150 - precision: 0.9662 - recall: 0.9513
# Epoch 67/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 913ms/step - accuracy: 0.9509 - f1_score: 0.9409 - loss: 0.1391 - precision: 0.9582 - recall: 0.9462
# Epoch 68/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 897ms/step - accuracy: 0.9605 - f1_score: 0.9526 - loss: 0.1187 - precision: 0.9632 - recall: 0.9571
# Epoch 69/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 892ms/step - accuracy: 0.9595 - f1_score: 0.9519 - loss: 0.1231 - precision: 0.9667 - recall: 0.9565
# Epoch 70/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 897ms/step - accuracy: 0.9482 - f1_score: 0.9417 - loss: 0.1568 - precision: 0.9548 - recall: 0.9403
# Epoch 71/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 928ms/step - accuracy: 0.9523 - f1_score: 0.9421 - loss: 0.1369 - precision: 0.9589 - recall: 0.9416
# Epoch 72/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 909ms/step - accuracy: 0.9662 - f1_score: 0.9621 - loss: 0.1099 - precision: 0.9686 - recall: 0.9620
# Epoch 73/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 915ms/step - accuracy: 0.9639 - f1_score: 0.9544 - loss: 0.1001 - precision: 0.9696 - recall: 0.9617
# Epoch 74/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 900ms/step - accuracy: 0.9617 - f1_score: 0.9576 - loss: 0.1299 - precision: 0.9666 - recall: 0.9565
# Epoch 75/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 906ms/step - accuracy: 0.9480 - f1_score: 0.9433 - loss: 0.1591 - precision: 0.9572 - recall: 0.9432
# Epoch 76/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 921ms/step - accuracy: 0.9599 - f1_score: 0.9549 - loss: 0.1365 - precision: 0.9655 - recall: 0.9571
# Epoch 77/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 912ms/step - accuracy: 0.9605 - f1_score: 0.9572 - loss: 0.1152 - precision: 0.9670 - recall: 0.9524
# Epoch 78/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 910ms/step - accuracy: 0.9508 - f1_score: 0.9365 - loss: 0.1364 - precision: 0.9611 - recall: 0.9457
# Epoch 79/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 901ms/step - accuracy: 0.9654 - f1_score: 0.9602 - loss: 0.1047 - precision: 0.9708 - recall: 0.9630
# Epoch 80/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 926ms/step - accuracy: 0.9566 - f1_score: 0.9487 - loss: 0.1374 - precision: 0.9600 - recall: 0.9499
# Epoch 81/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 890ms/step - accuracy: 0.9603 - f1_score: 0.9575 - loss: 0.1305 - precision: 0.9670 - recall: 0.9527
# Epoch 82/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 900ms/step - accuracy: 0.9674 - f1_score: 0.9606 - loss: 0.0944 - precision: 0.9700 - recall: 0.9607
# Epoch 83/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 910ms/step - accuracy: 0.9478 - f1_score: 0.9392 - loss: 0.1396 - precision: 0.9575 - recall: 0.9454
# Epoch 84/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 925ms/step - accuracy: 0.9591 - f1_score: 0.9566 - loss: 0.1315 - precision: 0.9634 - recall: 0.9550
# Epoch 85/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 903ms/step - accuracy: 0.9630 - f1_score: 0.9592 - loss: 0.1003 - precision: 0.9654 - recall: 0.9569
# Epoch 86/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 906ms/step - accuracy: 0.9559 - f1_score: 0.9500 - loss: 0.1422 - precision: 0.9597 - recall: 0.9518
# Epoch 87/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 923ms/step - accuracy: 0.9576 - f1_score: 0.9527 - loss: 0.1147 - precision: 0.9665 - recall: 0.9513
# Epoch 88/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 922ms/step - accuracy: 0.9629 - f1_score: 0.9564 - loss: 0.1231 - precision: 0.9679 - recall: 0.9577
# Epoch 89/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 888ms/step - accuracy: 0.9575 - f1_score: 0.9508 - loss: 0.1037 - precision: 0.9660 - recall: 0.9503
# Epoch 90/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 923ms/step - accuracy: 0.9654 - f1_score: 0.9595 - loss: 0.1246 - precision: 0.9677 - recall: 0.9534
# Epoch 91/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 930ms/step - accuracy: 0.9467 - f1_score: 0.9380 - loss: 0.1772 - precision: 0.9546 - recall: 0.9431
# Epoch 92/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 916ms/step - accuracy: 0.9582 - f1_score: 0.9422 - loss: 0.1241 - precision: 0.9642 - recall: 0.9534
# Epoch 93/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 932ms/step - accuracy: 0.9628 - f1_score: 0.9627 - loss: 0.1032 - precision: 0.9668 - recall: 0.9578
# Epoch 94/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 919ms/step - accuracy: 0.9641 - f1_score: 0.9567 - loss: 0.1031 - precision: 0.9688 - recall: 0.9582
# Epoch 95/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 910ms/step - accuracy: 0.9560 - f1_score: 0.9478 - loss: 0.1801 - precision: 0.9638 - recall: 0.9482
# Epoch 96/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 885ms/step - accuracy: 0.9767 - f1_score: 0.9714 - loss: 0.0824 - precision: 0.9808 - recall: 0.9704
# Epoch 97/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 879ms/step - accuracy: 0.9509 - f1_score: 0.9379 - loss: 0.1382 - precision: 0.9559 - recall: 0.9476
# Epoch 98/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 95s 923ms/step - accuracy: 0.9625 - f1_score: 0.9589 - loss: 0.1167 - precision: 0.9704 - recall: 0.9566
# Epoch 99/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 925ms/step - accuracy: 0.9616 - f1_score: 0.9606 - loss: 0.1277 - precision: 0.9663 - recall: 0.9569
# Epoch 100/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 897ms/step - accuracy: 0.9586 - f1_score: 0.9526 - loss: 0.1123 - precision: 0.9704 - recall: 0.9566
# Epoch 101/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 899ms/step - accuracy: 0.9522 - f1_score: 0.9400 - loss: 0.1636 - precision: 0.9555 - recall: 0.9468
# Epoch 102/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 926ms/step - accuracy: 0.9601 - f1_score: 0.9547 - loss: 0.1099 - precision: 0.9671 - recall: 0.9535
# Epoch 103/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 879ms/step - accuracy: 0.9649 - f1_score: 0.9611 - loss: 0.1034 - precision: 0.9691 - recall: 0.9615
# Epoch 104/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 872ms/step - accuracy: 0.9604 - f1_score: 0.9592 - loss: 0.1260 - precision: 0.9648 - recall: 0.9583
# Epoch 105/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 890ms/step - accuracy: 0.9711 - f1_score: 0.9643 - loss: 0.0955 - precision: 0.9762 - recall: 0.9680
# Epoch 106/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 907ms/step - accuracy: 0.9705 - f1_score: 0.9666 - loss: 0.0958 - precision: 0.9740 - recall: 0.9649
# Epoch 107/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 909ms/step - accuracy: 0.9537 - f1_score: 0.9444 - loss: 0.1561 - precision: 0.9614 - recall: 0.9459
# Epoch 108/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 893ms/step - accuracy: 0.9608 - f1_score: 0.9596 - loss: 0.1014 - precision: 0.9644 - recall: 0.9568
# Epoch 109/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 861ms/step - accuracy: 0.9606 - f1_score: 0.9587 - loss: 0.1143 - precision: 0.9644 - recall: 0.9565
# Epoch 110/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 870ms/step - accuracy: 0.9677 - f1_score: 0.9634 - loss: 0.0884 - precision: 0.9705 - recall: 0.9658
# Epoch 111/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 893ms/step - accuracy: 0.9632 - f1_score: 0.9559 - loss: 0.1271 - precision: 0.9655 - recall: 0.9586
# Epoch 112/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 897ms/step - accuracy: 0.9651 - f1_score: 0.9586 - loss: 0.0915 - precision: 0.9737 - recall: 0.9565
# Epoch 113/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 879ms/step - accuracy: 0.9658 - f1_score: 0.9627 - loss: 0.0952 - precision: 0.9692 - recall: 0.9624
# Epoch 114/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 898ms/step - accuracy: 0.9702 - f1_score: 0.9662 - loss: 0.0869 - precision: 0.9748 - recall: 0.9607
# Epoch 115/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 892ms/step - accuracy: 0.9707 - f1_score: 0.9681 - loss: 0.0971 - precision: 0.9749 - recall: 0.9670
# Epoch 116/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 930ms/step - accuracy: 0.9566 - f1_score: 0.9495 - loss: 0.1082 - precision: 0.9620 - recall: 0.9514
# Epoch 117/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 94s 927ms/step - accuracy: 0.9727 - f1_score: 0.9683 - loss: 0.0850 - precision: 0.9783 - recall: 0.9688
# Epoch 118/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 891ms/step - accuracy: 0.9545 - f1_score: 0.9479 - loss: 0.1308 - precision: 0.9595 - recall: 0.9487
# Epoch 119/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 879ms/step - accuracy: 0.9616 - f1_score: 0.9512 - loss: 0.1072 - precision: 0.9713 - recall: 0.9600
# Epoch 120/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 895ms/step - accuracy: 0.9674 - f1_score: 0.9683 - loss: 0.0973 - precision: 0.9710 - recall: 0.9608
# Epoch 121/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 892ms/step - accuracy: 0.9698 - f1_score: 0.9683 - loss: 0.0798 - precision: 0.9744 - recall: 0.9669
# Epoch 122/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 913ms/step - accuracy: 0.9683 - f1_score: 0.9630 - loss: 0.1119 - precision: 0.9717 - recall: 0.9649
# Epoch 123/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 885ms/step - accuracy: 0.9518 - f1_score: 0.9432 - loss: 0.1530 - precision: 0.9551 - recall: 0.9433
# Epoch 124/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 884ms/step - accuracy: 0.9600 - f1_score: 0.9493 - loss: 0.1229 - precision: 0.9702 - recall: 0.9550
# Epoch 125/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 886ms/step - accuracy: 0.9729 - f1_score: 0.9755 - loss: 0.0785 - precision: 0.9763 - recall: 0.9704
# Epoch 126/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 904ms/step - accuracy: 0.9676 - f1_score: 0.9691 - loss: 0.0956 - precision: 0.9740 - recall: 0.9653
# Epoch 127/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 88s 855ms/step - accuracy: 0.9663 - f1_score: 0.9565 - loss: 0.1185 - precision: 0.9714 - recall: 0.9632
# Epoch 128/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 878ms/step - accuracy: 0.9634 - f1_score: 0.9620 - loss: 0.1113 - precision: 0.9670 - recall: 0.9607
# Epoch 129/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 886ms/step - accuracy: 0.9692 - f1_score: 0.9691 - loss: 0.0843 - precision: 0.9757 - recall: 0.9662
# Epoch 130/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 875ms/step - accuracy: 0.9501 - f1_score: 0.9413 - loss: 0.1848 - precision: 0.9554 - recall: 0.9434
# Epoch 131/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 902ms/step - accuracy: 0.9606 - f1_score: 0.9507 - loss: 0.1247 - precision: 0.9650 - recall: 0.9566
# Epoch 132/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 876ms/step - accuracy: 0.9792 - f1_score: 0.9754 - loss: 0.0744 - precision: 0.9814 - recall: 0.9742
# Epoch 133/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 869ms/step - accuracy: 0.9563 - f1_score: 0.9487 - loss: 0.1261 - precision: 0.9641 - recall: 0.9538
# Epoch 134/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 883ms/step - accuracy: 0.9623 - f1_score: 0.9486 - loss: 0.1562 - precision: 0.9665 - recall: 0.9583
# Epoch 135/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 908ms/step - accuracy: 0.9619 - f1_score: 0.9542 - loss: 0.1146 - precision: 0.9713 - recall: 0.9556
# Epoch 136/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 891ms/step - accuracy: 0.9719 - f1_score: 0.9708 - loss: 0.0760 - precision: 0.9735 - recall: 0.9700
# Epoch 137/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 886ms/step - accuracy: 0.9733 - f1_score: 0.9694 - loss: 0.1101 - precision: 0.9759 - recall: 0.9712
# Epoch 138/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 901ms/step - accuracy: 0.9660 - f1_score: 0.9612 - loss: 0.1225 - precision: 0.9707 - recall: 0.9612
# Epoch 139/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 878ms/step - accuracy: 0.9568 - f1_score: 0.9492 - loss: 0.1456 - precision: 0.9605 - recall: 0.9525
# Epoch 140/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 903ms/step - accuracy: 0.9578 - f1_score: 0.9495 - loss: 0.1377 - precision: 0.9605 - recall: 0.9557
# Epoch 141/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 914ms/step - accuracy: 0.9645 - f1_score: 0.9614 - loss: 0.1170 - precision: 0.9707 - recall: 0.9593
# Epoch 142/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 886ms/step - accuracy: 0.9648 - f1_score: 0.9517 - loss: 0.1231 - precision: 0.9714 - recall: 0.9632
# Epoch 143/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 899ms/step - accuracy: 0.9605 - f1_score: 0.9554 - loss: 0.1081 - precision: 0.9660 - recall: 0.9562
# Epoch 144/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 872ms/step - accuracy: 0.9602 - f1_score: 0.9526 - loss: 0.1464 - precision: 0.9635 - recall: 0.9558
# Epoch 145/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 892ms/step - accuracy: 0.9653 - f1_score: 0.9624 - loss: 0.1096 - precision: 0.9723 - recall: 0.9613
# Epoch 146/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 893ms/step - accuracy: 0.9725 - f1_score: 0.9649 - loss: 0.0814 - precision: 0.9759 - recall: 0.9690
# Epoch 147/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 875ms/step - accuracy: 0.9654 - f1_score: 0.9613 - loss: 0.1232 - precision: 0.9701 - recall: 0.9609
# Epoch 148/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 897ms/step - accuracy: 0.9738 - f1_score: 0.9683 - loss: 0.0955 - precision: 0.9767 - recall: 0.9705
# Epoch 149/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 881ms/step - accuracy: 0.9577 - f1_score: 0.9463 - loss: 0.1390 - precision: 0.9637 - recall: 0.9520
# Epoch 150/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 874ms/step - accuracy: 0.9563 - f1_score: 0.9460 - loss: 0.1358 - precision: 0.9643 - recall: 0.9501
# Epoch 151/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 893ms/step - accuracy: 0.9654 - f1_score: 0.9635 - loss: 0.0976 - precision: 0.9705 - recall: 0.9631
# Epoch 152/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 88s 860ms/step - accuracy: 0.9683 - f1_score: 0.9630 - loss: 0.0849 - precision: 0.9743 - recall: 0.9645
# Epoch 153/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 871ms/step - accuracy: 0.9713 - f1_score: 0.9615 - loss: 0.0931 - precision: 0.9782 - recall: 0.9627
# Epoch 154/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 878ms/step - accuracy: 0.9635 - f1_score: 0.9601 - loss: 0.1106 - precision: 0.9665 - recall: 0.9600
# Epoch 155/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 893ms/step - accuracy: 0.9677 - f1_score: 0.9690 - loss: 0.1091 - precision: 0.9713 - recall: 0.9629
# Epoch 156/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 884ms/step - accuracy: 0.9613 - f1_score: 0.9526 - loss: 0.1091 - precision: 0.9681 - recall: 0.9542
# Epoch 157/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 885ms/step - accuracy: 0.9584 - f1_score: 0.9469 - loss: 0.1281 - precision: 0.9632 - recall: 0.9524
# Epoch 158/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 899ms/step - accuracy: 0.9662 - f1_score: 0.9631 - loss: 0.1067 - precision: 0.9689 - recall: 0.9600
# Epoch 159/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 889ms/step - accuracy: 0.9680 - f1_score: 0.9651 - loss: 0.0959 - precision: 0.9730 - recall: 0.9658
# Epoch 160/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 883ms/step - accuracy: 0.9683 - f1_score: 0.9629 - loss: 0.1045 - precision: 0.9701 - recall: 0.9665
# Epoch 161/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 899ms/step - accuracy: 0.9660 - f1_score: 0.9594 - loss: 0.1146 - precision: 0.9729 - recall: 0.9647
# Epoch 162/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 89s 871ms/step - accuracy: 0.9570 - f1_score: 0.9480 - loss: 0.1898 - precision: 0.9613 - recall: 0.9526
# Epoch 163/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 885ms/step - accuracy: 0.9706 - f1_score: 0.9651 - loss: 0.0864 - precision: 0.9750 - recall: 0.9687
# Epoch 164/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 907ms/step - accuracy: 0.9689 - f1_score: 0.9633 - loss: 0.0940 - precision: 0.9709 - recall: 0.9620
# Epoch 165/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 885ms/step - accuracy: 0.9761 - f1_score: 0.9768 - loss: 0.0818 - precision: 0.9791 - recall: 0.9728
# Epoch 166/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 897ms/step - accuracy: 0.9795 - f1_score: 0.9759 - loss: 0.0623 - precision: 0.9805 - recall: 0.9771
# Epoch 167/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 887ms/step - accuracy: 0.9748 - f1_score: 0.9716 - loss: 0.0903 - precision: 0.9779 - recall: 0.9706
# Epoch 168/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 902ms/step - accuracy: 0.9609 - f1_score: 0.9440 - loss: 0.1393 - precision: 0.9646 - recall: 0.9557
# Epoch 169/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 905ms/step - accuracy: 0.9676 - f1_score: 0.9676 - loss: 0.1024 - precision: 0.9711 - recall: 0.9643
# Epoch 170/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 888ms/step - accuracy: 0.9789 - f1_score: 0.9726 - loss: 0.0624 - precision: 0.9811 - recall: 0.9758
# Epoch 171/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 871ms/step - accuracy: 0.9694 - f1_score: 0.9646 - loss: 0.1055 - precision: 0.9701 - recall: 0.9684
# Epoch 172/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 900ms/step - accuracy: 0.9779 - f1_score: 0.9687 - loss: 0.0715 - precision: 0.9796 - recall: 0.9731
# Epoch 173/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 910ms/step - accuracy: 0.9711 - f1_score: 0.9685 - loss: 0.0897 - precision: 0.9734 - recall: 0.9681
# Epoch 174/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 887ms/step - accuracy: 0.9709 - f1_score: 0.9659 - loss: 0.1172 - precision: 0.9738 - recall: 0.9663
# Epoch 175/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 903ms/step - accuracy: 0.9777 - f1_score: 0.9761 - loss: 0.0680 - precision: 0.9815 - recall: 0.9763
# Epoch 176/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 897ms/step - accuracy: 0.9787 - f1_score: 0.9742 - loss: 0.0870 - precision: 0.9816 - recall: 0.9748
# Epoch 177/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 922ms/step - accuracy: 0.9765 - f1_score: 0.9719 - loss: 0.0773 - precision: 0.9800 - recall: 0.9711
# Epoch 178/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 918ms/step - accuracy: 0.9698 - f1_score: 0.9684 - loss: 0.1394 - precision: 0.9738 - recall: 0.9674
# Epoch 179/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 91s 892ms/step - accuracy: 0.9395 - f1_score: 0.9211 - loss: 0.2105 - precision: 0.9479 - recall: 0.9338
# Epoch 180/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 93s 918ms/step - accuracy: 0.9744 - f1_score: 0.9650 - loss: 0.0872 - precision: 0.9782 - recall: 0.9722
# Epoch 181/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 884ms/step - accuracy: 0.9657 - f1_score: 0.9620 - loss: 0.1054 - precision: 0.9697 - recall: 0.9619
# Epoch 182/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 907ms/step - accuracy: 0.9749 - f1_score: 0.9695 - loss: 0.0896 - precision: 0.9784 - recall: 0.9726
# Epoch 183/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 876ms/step - accuracy: 0.9684 - f1_score: 0.9663 - loss: 0.0863 - precision: 0.9727 - recall: 0.9664
# Epoch 184/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 90s 875ms/step - accuracy: 0.9778 - f1_score: 0.9765 - loss: 0.0870 - precision: 0.9804 - recall: 0.9734
# Epoch 185/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 88s 861ms/step - accuracy: 0.9659 - f1_score: 0.9634 - loss: 0.1036 - precision: 0.9678 - recall: 0.9588
# Training metrics saved to training_metrics.csv
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 167s 7s/step - accuracy: 0.9579 - f1_score: 0.9531 - loss: 0.2775 - precision: 0.9579 - recall: 0.9579
# Test Loss: 0.23520642518997192
# Test Accuracy: 0.9674479365348816
# Test Precision: 0.9674479365348816
# Test Recall: 0.9674479365348816
# Test F1 Score: tf.Tensor(
# [0.9626168  0.9904762  0.91919184 0.9803921  0.9795917  0.9735006
#  0.9803921 ], shape=(7,), dtype=float32)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator

num_classes = 7
height = 128
n_fft = 2048
hop_length = 256
sr = 16000
T = 1

hop_size_sec = hop_length / sr
audio_length_samples = T * sr

width = 1 + int((audio_length_samples - n_fft) / hop_length)

channels = 3

batch_size = 32

model = tf.keras.models.load_model('/content/al-emadi_cnn_standardized_unknown__256HL.keras')

test_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms_256HL/Test/'

test_datagen = ImageDataGenerator()

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

loss, accuracy, precision, recall, f1_score = model.evaluate(test_generator)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test F1 Score:", f1_score)

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true class labels
true_classes = test_generator.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)
print("\nConfusion Matrix:")
print(conf_matrix)

# Get class labels
class_labels = list(test_generator.class_indices.keys())

# Calculate accuracy for each class
class_accuracy = {}
for i, class_label in enumerate(class_labels):
    correct_indices = np.where(true_classes == i)[0]
    correct_predictions = np.sum(predicted_classes[correct_indices] == i)
    total_samples = len(correct_indices)
    class_accuracy[class_label] = correct_predictions / total_samples if total_samples > 0 else 0.0

# Print accuracy for each class
print("\nAccuracy for each class:")
for class_label in class_labels:
    print(f"{class_label}: {class_accuracy[class_label]:.4f}")

# Print classification report (includes precision, recall, F1-score)
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# Found 768 images belonging to 7 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 620ms/step - accuracy: 0.9675 - f1_score: 0.6534 - loss: 0.1739 - precision: 0.9675 - recall: 0.9675
# Test Loss: 0.23520641028881073
# Test Accuracy: 0.9674479365348816
# Test Precision: 0.9674479365348816
# Test Recall: 0.9674479365348816
# Test F1 Score: tf.Tensor(
# [0.9626168  0.9904762  0.91919184 0.9803921  0.9795917  0.9735006
#  0.9803921 ], shape=(7,), dtype=float32)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 645ms/step
#
# Confusion Matrix:
# [[103   0   1   0   0   0   0]
#  [  0  52   0   0   0   0   0]
#  [  2   1  91   0   0  10   0]
#  [  0   0   0  50   0   0   0]
#  [  0   0   0   1  48   1   0]
#  [  5   0   2   0   0 349   1]
#  [  0   0   0   1   0   0  50]]
#
# Accuracy for each class:
# Bebop: 0.9904
# Crazyflie: 1.0000
# Mambo: 0.8750
# Matrice100: 1.0000
# Mavic: 0.9600
# NonDrone: 0.9776
# Phantom: 0.9804
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Bebop       0.94      0.99      0.96       104
#    Crazyflie       0.98      1.00      0.99        52
#        Mambo       0.97      0.88      0.92       104
#   Matrice100       0.96      1.00      0.98        50
#        Mavic       1.00      0.96      0.98        50
#     NonDrone       0.97      0.98      0.97       357
#      Phantom       0.98      0.98      0.98        51
#
#     accuracy                           0.97       768
#    macro avg       0.97      0.97      0.97       768
# weighted avg       0.97      0.97      0.97       768

# %%
import os
import numpy as np
from scipy.stats import entropy
from tensorflow.keras.preprocessing import image

model = tf.keras.models.load_model('/content/al-emadi_cnn_standardized_unknown__256HL.keras')
classes = ['Bebop', 'Crazyflie', 'Mambo', 'Matrice100', 'Mavic', 'NonDrone', 'Phantom']

known_counter = 0
unknown_counter = 0

def load_spectrogram(file_path):
    # Load and preprocess the image
    num_classes = 7
    height = 128
    n_fft = 2048
    hop_length = 256
    sr = 16000
    T = 1

    hop_size_sec = hop_length / sr
    audio_length_samples = T * sr

    width = 1 + int((audio_length_samples - n_fft) / hop_length)

    channels = 3

    img = image.load_img(file_path, target_size=(height, width))  # Assuming input size expected by your model
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    #img_array = img_array / 255.0  # Normalize pixel values to [0, 1]
    return img_array

# Function to classify a single spectrogram
def classify_spectrogram(spectrogram, entropy_threshold):
    global known_counter
    global unknown_counter

    probabilities = model.predict(spectrogram)[0]  # Get class probabilities from the model
    ent = entropy(probabilities, base=2)  # Calculate entropy of the probability distribution

    if ent > entropy_threshold:
        unknown_counter+=1
        return "UnknownDrone"
    else:
        known_counter+=1
        max_index = np.argmax(probabilities)  # Get the index of the maximum probability
        return classes[max_index]  # Return the corresponding drone class

# Directory containing spectrogram files
unknown_spectrogram_dir = '/content/drive/MyDrive/UnknownDrone_256HL/'
spectrogram_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms_256HL/Test/Phantom/'

# VALUE UP = UNKNOWN DRONE DECREASE | VALUE DOWN = UNKNOWN DRONE INCREASE
entropy_threshold =  0.05 # Adjust this threshold based on your model and validation results

# List all files in the directory
spectrogram_files = os.listdir(spectrogram_dir)

# Process each spectrogram file
for filename in spectrogram_files:
    if filename.endswith('.png'):  # Assuming spectrograms are saved as PNG files
        # Load the spectrogram (you need to implement this part based on your data loading method)
        spectrogram = load_spectrogram(os.path.join(spectrogram_dir, filename))

        # Classify the spectrogram
        predicted_class = classify_spectrogram(spectrogram, entropy_threshold)

        # Print the filename and predicted class
        print(f"{filename}: {predicted_class}")

print("Unknown Drone Count:", unknown_counter)
print("Known Drone Count:", known_counter)
print("Accuracy:", (known_counter)/(known_counter+unknown_counter))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Phantom_Test_File1_0_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Phantom_Test_File1_8_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Phantom_Test_File2_3_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Phantom_Test_File2_10_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Phantom_Test_File2_13_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Phantom_Test_File2_16_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Phantom_Test_File2_21_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Phantom_Test_File2_24_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Phantom_Test_File3_4_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Phantom_Test_File3_9_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Phantom_Test_File1_0_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File1_8_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Phantom_Test_File2_3_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Phantom_Test_File2_10_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Phantom_Test_File2_13_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Phantom_Test_File2_16_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Phantom_Test_File2_21_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Phantom_Test_File2_24_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File2_26_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Phantom_Test_File3_4_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File3_9_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File1_0_PS-1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Phantom_Test_File1_8_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Phantom_Test_File2_3_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Phantom_Test_File2_10_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Phantom_Test_File2_13_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Phantom_Test_File2_16_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File2_21_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Phantom_Test_File2_24_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File3_4_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File3_9_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File1_0_PS+1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File1_8_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Phantom_Test_File2_3_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Phantom_Test_File2_10_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Phantom_Test_File2_13_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Phantom_Test_File2_16_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Phantom_Test_File2_21_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Phantom_Test_File2_24_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Phantom_Test_File3_4_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Phantom_Test_File3_9_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Phantom_Test_File1_0_PS+2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Phantom_Test_File1_8_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Phantom_Test_File2_3_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Phantom_Test_File2_10_PS+2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Phantom_Test_File2_13_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Phantom_Test_File2_16_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File2_21_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Phantom_Test_File2_24_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Phantom_Test_File3_4_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Phantom_Test_File3_9_PS+2_mel.png: Phantom
# Unknown Drone Count: 4
# Known Drone Count: 47
# Accuracy: 0.9215686274509803
