# %%
# !pip install --upgrade keras
# !pip install --upgrade keras tensorflow
import os
import math
import numpy as np
import librosa
import json
import pandas as pd
from termcolor import colored
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
# !pip install tensorboard
# !pip install visualkeras
import visualkeras
from keras.utils import plot_model
from datetime import datetime
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn import svm
from sklearn.svm import SVC
import pickle
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from IPython.display import Audio
from scipy.io import wavfile
import scipy
import soundfile as sf
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras import layers, models
from sklearn.metrics import classification_report
import random
import csv
from keras.callbacks import Callback
from keras.callbacks import CSVLogger
from sklearn.metrics import precision_recall_fscore_support

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting keras
#   Downloading keras-3.4.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Collecting namex (from keras)
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.9.0)
# Collecting optree (from keras)
#   Downloading optree-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.7/347.7 kB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Installing collected packages: namex, optree, keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.4.1 which is incompatible.
# Successfully installed keras-3.4.1 namex-0.0.8 optree-0.12.1
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting tensorflow
#   Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.9.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Collecting h5py (from keras)
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 74.0 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Collecting ml-dtypes (from keras)
#   Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 76.3 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow)
#   Downloading tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 79.1 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Installing collected packages: ml-dtypes, h5py, tensorboard, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.17.0 which is incompatible.
# Successfully installed h5py-3.11.0 ml-dtypes-0.4.0 tensorboard-2.17.0 tensorflow-2.17.0
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.25.2)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Collecting visualkeras
#   Downloading visualkeras-0.1.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.25.2)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 21.7 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18.post0 visualkeras-0.1.1
# Mounted at /content/drive

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms/Train/'
test_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms/Test/'

num_classes = 7
height = 128
n_fft = 2048
hop_length = 512
sr = 16000
T = 1

hop_size_sec = hop_length / sr
audio_length_samples = T * sr

width = 1 + int((audio_length_samples - n_fft) / hop_length)

channels = 3

train_datagen = ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator()

batch_size = 32

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical')

cnn_model = tf.keras.Sequential()
cnn_model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(height, width, channels)))
cnn_model.add(tf.keras.layers.MaxPooling2D((2, 2)))
cnn_model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
cnn_model.add(tf.keras.layers.MaxPooling2D((2, 2)))
cnn_model.add(tf.keras.layers.Conv2D(128, (3, 3), activation='relu'))
cnn_model.add(tf.keras.layers.MaxPooling2D((2, 2)))
cnn_model.add(tf.keras.layers.Flatten())

# RNN model
rnn_model = tf.keras.Sequential([
    tf.keras.layers.Reshape((width, height * channels), input_shape=(height, width, channels)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu', return_sequences=True)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu', return_sequences=True)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu')),
    tf.keras.layers.BatchNormalization()
])

# Combine CNN and RNN models
model = tf.keras.Sequential([
    tf.keras.layers.Reshape((1, height, width, channels), input_shape=(height, width, channels)),
    tf.keras.layers.TimeDistributed(cnn_model),  # TimeDistributed applies the CNN model to each time step
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu')),  # RNN on top of CNN features
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy', 'precision', 'recall', 'f1_score'])

epochs = 200
metrics_data = []

for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")

    train_generator.reset()

    history = model.fit(
        train_generator,
        steps_per_epoch=len(train_generator),
        epochs=1,
        verbose=1)

    # Get metrics from history
    accuracy = history.history['accuracy'][0]
    precision = history.history['precision'][0]
    recall = history.history['recall'][0]

    f1_score_tensor = history.history['f1_score'][0]
    f1_score_value = np.mean(f1_score_tensor)

    # Store metrics in a list
    metrics_data.append([accuracy, precision, recall, f1_score_value])

# Save metrics to a CSV file
csv_filename = 'training_metrics.csv'

with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Accuracy', 'Precision', 'Recall', 'F1 Score'])
    writer.writerows(metrics_data)

print(f"Training metrics saved to {csv_filename}")

loss, accuracy, precision, recall, f1_score = model.evaluate(test_generator)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test F1 Score:", f1_score)

model.save('al-emadi_crnn_standardized_unknown.keras')
# Out:
# Found 3088 images belonging to 7 classes.
# Found 768 images belonging to 7 classes.
# Epoch 1/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 104s 711ms/step - accuracy: 0.3659 - f1_score: 0.1549 - loss: 1.7605 - precision: 0.7204 - recall: 0.0488
# Epoch 2/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 79s 759ms/step - accuracy: 0.5513 - f1_score: 0.2397 - loss: 1.2586 - precision: 0.8033 - recall: 0.3586
# Epoch 3/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 77s 750ms/step - accuracy: 0.6887 - f1_score: 0.5023 - loss: 0.9298 - precision: 0.8784 - recall: 0.4742
# Epoch 4/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 713ms/step - accuracy: 0.7071 - f1_score: 0.5510 - loss: 0.8360 - precision: 0.8456 - recall: 0.5599
# Epoch 5/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 711ms/step - accuracy: 0.7351 - f1_score: 0.5912 - loss: 0.7553 - precision: 0.8537 - recall: 0.6118
# Epoch 6/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 76s 732ms/step - accuracy: 0.7872 - f1_score: 0.6782 - loss: 0.6005 - precision: 0.8904 - recall: 0.6970
# Epoch 7/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 77s 752ms/step - accuracy: 0.7977 - f1_score: 0.7069 - loss: 0.5524 - precision: 0.8777 - recall: 0.7089
# Epoch 8/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 718ms/step - accuracy: 0.8417 - f1_score: 0.7474 - loss: 0.4702 - precision: 0.8928 - recall: 0.7709
# Epoch 9/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 692ms/step - accuracy: 0.8508 - f1_score: 0.7885 - loss: 0.4270 - precision: 0.8998 - recall: 0.8013
# Epoch 10/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 731ms/step - accuracy: 0.8213 - f1_score: 0.7582 - loss: 0.4999 - precision: 0.8816 - recall: 0.7528
# Epoch 11/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 720ms/step - accuracy: 0.8506 - f1_score: 0.7998 - loss: 0.4350 - precision: 0.8971 - recall: 0.7980
# Epoch 12/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 728ms/step - accuracy: 0.8632 - f1_score: 0.8240 - loss: 0.4010 - precision: 0.9001 - recall: 0.8268
# Epoch 13/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 695ms/step - accuracy: 0.8740 - f1_score: 0.8396 - loss: 0.3586 - precision: 0.9076 - recall: 0.8436
# Epoch 14/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 698ms/step - accuracy: 0.8960 - f1_score: 0.8644 - loss: 0.3185 - precision: 0.9182 - recall: 0.8682
# Epoch 15/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 78s 765ms/step - accuracy: 0.8845 - f1_score: 0.8489 - loss: 0.3416 - precision: 0.9069 - recall: 0.8612
# Epoch 16/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 711ms/step - accuracy: 0.9023 - f1_score: 0.8796 - loss: 0.2961 - precision: 0.9198 - recall: 0.8776
# Epoch 17/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 709ms/step - accuracy: 0.9126 - f1_score: 0.8970 - loss: 0.2863 - precision: 0.9289 - recall: 0.8942
# Epoch 18/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 699ms/step - accuracy: 0.9111 - f1_score: 0.8920 - loss: 0.2588 - precision: 0.9281 - recall: 0.8998
# Epoch 19/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 718ms/step - accuracy: 0.9225 - f1_score: 0.9106 - loss: 0.2524 - precision: 0.9356 - recall: 0.9090
# Epoch 20/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 731ms/step - accuracy: 0.9200 - f1_score: 0.8987 - loss: 0.2471 - precision: 0.9392 - recall: 0.9084
# Epoch 21/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 732ms/step - accuracy: 0.9183 - f1_score: 0.9114 - loss: 0.2549 - precision: 0.9344 - recall: 0.9001
# Epoch 22/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 733ms/step - accuracy: 0.9325 - f1_score: 0.9198 - loss: 0.1947 - precision: 0.9463 - recall: 0.9214
# Epoch 23/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 711ms/step - accuracy: 0.9248 - f1_score: 0.9118 - loss: 0.2371 - precision: 0.9362 - recall: 0.9036
# Epoch 24/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 77s 749ms/step - accuracy: 0.9307 - f1_score: 0.9169 - loss: 0.2169 - precision: 0.9426 - recall: 0.9149
# Epoch 25/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 76s 744ms/step - accuracy: 0.9331 - f1_score: 0.9274 - loss: 0.2065 - precision: 0.9427 - recall: 0.9190
# Epoch 26/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 720ms/step - accuracy: 0.9370 - f1_score: 0.9308 - loss: 0.1901 - precision: 0.9487 - recall: 0.9284
# Epoch 27/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 701ms/step - accuracy: 0.9325 - f1_score: 0.9215 - loss: 0.2112 - precision: 0.9419 - recall: 0.9210
# Epoch 28/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 681ms/step - accuracy: 0.9457 - f1_score: 0.9392 - loss: 0.1879 - precision: 0.9534 - recall: 0.9324
# Epoch 29/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 725ms/step - accuracy: 0.9353 - f1_score: 0.9247 - loss: 0.2085 - precision: 0.9443 - recall: 0.9238
# Epoch 30/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 714ms/step - accuracy: 0.9422 - f1_score: 0.9372 - loss: 0.1832 - precision: 0.9535 - recall: 0.9339
# Epoch 31/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 709ms/step - accuracy: 0.9459 - f1_score: 0.9453 - loss: 0.1786 - precision: 0.9511 - recall: 0.9314
# Epoch 32/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 713ms/step - accuracy: 0.9502 - f1_score: 0.9422 - loss: 0.1558 - precision: 0.9562 - recall: 0.9459
# Epoch 33/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 684ms/step - accuracy: 0.9444 - f1_score: 0.9378 - loss: 0.1727 - precision: 0.9574 - recall: 0.9360
# Epoch 34/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 707ms/step - accuracy: 0.9405 - f1_score: 0.9265 - loss: 0.1816 - precision: 0.9460 - recall: 0.9310
# Epoch 35/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 721ms/step - accuracy: 0.9393 - f1_score: 0.9413 - loss: 0.1989 - precision: 0.9495 - recall: 0.9295
# Epoch 36/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 714ms/step - accuracy: 0.9515 - f1_score: 0.9425 - loss: 0.1467 - precision: 0.9588 - recall: 0.9454
# Epoch 37/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 686ms/step - accuracy: 0.9523 - f1_score: 0.9460 - loss: 0.1405 - precision: 0.9628 - recall: 0.9417
# Epoch 38/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 711ms/step - accuracy: 0.9270 - f1_score: 0.9114 - loss: 0.2235 - precision: 0.9381 - recall: 0.9123
# Epoch 39/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 716ms/step - accuracy: 0.9337 - f1_score: 0.9195 - loss: 0.1980 - precision: 0.9525 - recall: 0.9214
# Epoch 40/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 711ms/step - accuracy: 0.9516 - f1_score: 0.9392 - loss: 0.1567 - precision: 0.9591 - recall: 0.9428
# Epoch 41/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 677ms/step - accuracy: 0.9453 - f1_score: 0.9350 - loss: 0.1708 - precision: 0.9557 - recall: 0.9382
# Epoch 42/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 696ms/step - accuracy: 0.9440 - f1_score: 0.9318 - loss: 0.1640 - precision: 0.9539 - recall: 0.9342
# Epoch 43/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 713ms/step - accuracy: 0.9468 - f1_score: 0.9406 - loss: 0.1726 - precision: 0.9540 - recall: 0.9341
# Epoch 44/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 706ms/step - accuracy: 0.9517 - f1_score: 0.9513 - loss: 0.1413 - precision: 0.9567 - recall: 0.9435
# Epoch 45/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 683ms/step - accuracy: 0.9281 - f1_score: 0.9025 - loss: 0.2187 - precision: 0.9410 - recall: 0.9127
# Epoch 46/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 691ms/step - accuracy: 0.9431 - f1_score: 0.9239 - loss: 0.1691 - precision: 0.9516 - recall: 0.9272
# Epoch 47/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 718ms/step - accuracy: 0.9469 - f1_score: 0.9292 - loss: 0.1655 - precision: 0.9590 - recall: 0.9367
# Epoch 48/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 740ms/step - accuracy: 0.9466 - f1_score: 0.9346 - loss: 0.1519 - precision: 0.9533 - recall: 0.9412
# Epoch 49/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 719ms/step - accuracy: 0.9502 - f1_score: 0.9407 - loss: 0.1471 - precision: 0.9570 - recall: 0.9436
# Epoch 50/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 698ms/step - accuracy: 0.9559 - f1_score: 0.9500 - loss: 0.1292 - precision: 0.9632 - recall: 0.9510
# Epoch 51/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 702ms/step - accuracy: 0.9497 - f1_score: 0.9427 - loss: 0.1511 - precision: 0.9601 - recall: 0.9435
# Epoch 52/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 687ms/step - accuracy: 0.9457 - f1_score: 0.9334 - loss: 0.1726 - precision: 0.9506 - recall: 0.9367
# Epoch 53/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 709ms/step - accuracy: 0.9623 - f1_score: 0.9620 - loss: 0.1352 - precision: 0.9649 - recall: 0.9539
# Epoch 54/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 702ms/step - accuracy: 0.9570 - f1_score: 0.9497 - loss: 0.1425 - precision: 0.9620 - recall: 0.9516
# Epoch 55/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 709ms/step - accuracy: 0.9602 - f1_score: 0.9514 - loss: 0.1393 - precision: 0.9658 - recall: 0.9518
# Epoch 56/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 704ms/step - accuracy: 0.9521 - f1_score: 0.9491 - loss: 0.1505 - precision: 0.9584 - recall: 0.9484
# Epoch 57/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 672ms/step - accuracy: 0.9520 - f1_score: 0.9426 - loss: 0.1467 - precision: 0.9594 - recall: 0.9473
# Epoch 58/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 681ms/step - accuracy: 0.9682 - f1_score: 0.9644 - loss: 0.1031 - precision: 0.9722 - recall: 0.9654
# Epoch 59/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 711ms/step - accuracy: 0.9619 - f1_score: 0.9579 - loss: 0.1220 - precision: 0.9678 - recall: 0.9583
# Epoch 60/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 716ms/step - accuracy: 0.9579 - f1_score: 0.9509 - loss: 0.1297 - precision: 0.9634 - recall: 0.9540
# Epoch 61/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 709ms/step - accuracy: 0.9580 - f1_score: 0.9571 - loss: 0.1300 - precision: 0.9648 - recall: 0.9532
# Epoch 62/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 689ms/step - accuracy: 0.9614 - f1_score: 0.9564 - loss: 0.1208 - precision: 0.9663 - recall: 0.9582
# Epoch 63/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 674ms/step - accuracy: 0.9686 - f1_score: 0.9696 - loss: 0.1031 - precision: 0.9723 - recall: 0.9631
# Epoch 64/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 703ms/step - accuracy: 0.9604 - f1_score: 0.9513 - loss: 0.1313 - precision: 0.9653 - recall: 0.9528
# Epoch 65/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 719ms/step - accuracy: 0.9697 - f1_score: 0.9643 - loss: 0.1092 - precision: 0.9749 - recall: 0.9626
# Epoch 66/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 709ms/step - accuracy: 0.9644 - f1_score: 0.9622 - loss: 0.1133 - precision: 0.9715 - recall: 0.9625
# Epoch 67/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 722ms/step - accuracy: 0.9616 - f1_score: 0.9626 - loss: 0.1110 - precision: 0.9659 - recall: 0.9574
# Epoch 68/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 739ms/step - accuracy: 0.9610 - f1_score: 0.9516 - loss: 0.1195 - precision: 0.9678 - recall: 0.9570
# Epoch 69/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 704ms/step - accuracy: 0.9623 - f1_score: 0.9567 - loss: 0.1215 - precision: 0.9665 - recall: 0.9597
# Epoch 70/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 698ms/step - accuracy: 0.9617 - f1_score: 0.9558 - loss: 0.1089 - precision: 0.9659 - recall: 0.9596
# Epoch 71/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 730ms/step - accuracy: 0.9649 - f1_score: 0.9591 - loss: 0.1131 - precision: 0.9684 - recall: 0.9590
# Epoch 72/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 713ms/step - accuracy: 0.9546 - f1_score: 0.9541 - loss: 0.1366 - precision: 0.9586 - recall: 0.9517
# Epoch 73/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 703ms/step - accuracy: 0.9662 - f1_score: 0.9640 - loss: 0.1071 - precision: 0.9710 - recall: 0.9641
# Epoch 74/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 682ms/step - accuracy: 0.9687 - f1_score: 0.9684 - loss: 0.0913 - precision: 0.9722 - recall: 0.9635
# Epoch 75/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 692ms/step - accuracy: 0.9624 - f1_score: 0.9583 - loss: 0.1136 - precision: 0.9676 - recall: 0.9560
# Epoch 76/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 709ms/step - accuracy: 0.9660 - f1_score: 0.9628 - loss: 0.1008 - precision: 0.9711 - recall: 0.9624
# Epoch 77/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 710ms/step - accuracy: 0.9686 - f1_score: 0.9659 - loss: 0.0969 - precision: 0.9741 - recall: 0.9642
# Epoch 78/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 709ms/step - accuracy: 0.9658 - f1_score: 0.9644 - loss: 0.1142 - precision: 0.9699 - recall: 0.9629
# Epoch 79/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 725ms/step - accuracy: 0.9720 - f1_score: 0.9695 - loss: 0.0864 - precision: 0.9769 - recall: 0.9677
# Epoch 80/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 705ms/step - accuracy: 0.9736 - f1_score: 0.9672 - loss: 0.0808 - precision: 0.9773 - recall: 0.9688
# Epoch 81/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 710ms/step - accuracy: 0.9726 - f1_score: 0.9713 - loss: 0.1045 - precision: 0.9751 - recall: 0.9698
# Epoch 82/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 714ms/step - accuracy: 0.9767 - f1_score: 0.9774 - loss: 0.0855 - precision: 0.9794 - recall: 0.9713
# Epoch 83/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 721ms/step - accuracy: 0.9611 - f1_score: 0.9593 - loss: 0.1148 - precision: 0.9672 - recall: 0.9582
# Epoch 84/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 726ms/step - accuracy: 0.9593 - f1_score: 0.9547 - loss: 0.1301 - precision: 0.9662 - recall: 0.9556
# Epoch 85/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 696ms/step - accuracy: 0.9753 - f1_score: 0.9738 - loss: 0.0825 - precision: 0.9781 - recall: 0.9708
# Epoch 86/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 684ms/step - accuracy: 0.9769 - f1_score: 0.9760 - loss: 0.0697 - precision: 0.9803 - recall: 0.9736
# Epoch 87/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 724ms/step - accuracy: 0.9673 - f1_score: 0.9684 - loss: 0.0987 - precision: 0.9729 - recall: 0.9637
# Epoch 88/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 727ms/step - accuracy: 0.9663 - f1_score: 0.9674 - loss: 0.0985 - precision: 0.9689 - recall: 0.9632
# Epoch 89/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 727ms/step - accuracy: 0.9715 - f1_score: 0.9641 - loss: 0.0954 - precision: 0.9753 - recall: 0.9664
# Epoch 90/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 717ms/step - accuracy: 0.9682 - f1_score: 0.9671 - loss: 0.0909 - precision: 0.9724 - recall: 0.9632
# Epoch 91/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 696ms/step - accuracy: 0.9671 - f1_score: 0.9691 - loss: 0.0897 - precision: 0.9709 - recall: 0.9648
# Epoch 92/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 683ms/step - accuracy: 0.9686 - f1_score: 0.9620 - loss: 0.0922 - precision: 0.9707 - recall: 0.9643
# Epoch 93/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 724ms/step - accuracy: 0.9662 - f1_score: 0.9619 - loss: 0.1023 - precision: 0.9727 - recall: 0.9637
# Epoch 94/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 729ms/step - accuracy: 0.9738 - f1_score: 0.9717 - loss: 0.0943 - precision: 0.9781 - recall: 0.9717
# Epoch 95/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 726ms/step - accuracy: 0.9793 - f1_score: 0.9783 - loss: 0.0724 - precision: 0.9813 - recall: 0.9752
# Epoch 96/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 711ms/step - accuracy: 0.9706 - f1_score: 0.9699 - loss: 0.0893 - precision: 0.9754 - recall: 0.9694
# Epoch 97/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 690ms/step - accuracy: 0.9767 - f1_score: 0.9732 - loss: 0.0787 - precision: 0.9805 - recall: 0.9751
# Epoch 98/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 718ms/step - accuracy: 0.9655 - f1_score: 0.9627 - loss: 0.0977 - precision: 0.9687 - recall: 0.9602
# Epoch 99/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 716ms/step - accuracy: 0.9722 - f1_score: 0.9628 - loss: 0.0725 - precision: 0.9752 - recall: 0.9692
# Epoch 100/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 725ms/step - accuracy: 0.9592 - f1_score: 0.9578 - loss: 0.1262 - precision: 0.9615 - recall: 0.9551
# Epoch 101/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 719ms/step - accuracy: 0.9728 - f1_score: 0.9750 - loss: 0.0809 - precision: 0.9767 - recall: 0.9684
# Epoch 102/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 701ms/step - accuracy: 0.9838 - f1_score: 0.9800 - loss: 0.0587 - precision: 0.9864 - recall: 0.9806
# Epoch 103/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 730ms/step - accuracy: 0.9743 - f1_score: 0.9751 - loss: 0.0775 - precision: 0.9776 - recall: 0.9718
# Epoch 104/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 736ms/step - accuracy: 0.9726 - f1_score: 0.9685 - loss: 0.0791 - precision: 0.9752 - recall: 0.9705
# Epoch 105/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 721ms/step - accuracy: 0.9754 - f1_score: 0.9729 - loss: 0.0836 - precision: 0.9772 - recall: 0.9695
# Epoch 106/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 728ms/step - accuracy: 0.9742 - f1_score: 0.9702 - loss: 0.0868 - precision: 0.9772 - recall: 0.9706
# Epoch 107/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 685ms/step - accuracy: 0.9754 - f1_score: 0.9729 - loss: 0.0718 - precision: 0.9795 - recall: 0.9733
# Epoch 108/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 714ms/step - accuracy: 0.9578 - f1_score: 0.9488 - loss: 0.1493 - precision: 0.9623 - recall: 0.9538
# Epoch 109/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 726ms/step - accuracy: 0.9642 - f1_score: 0.9633 - loss: 0.1016 - precision: 0.9689 - recall: 0.9578
# Epoch 110/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 735ms/step - accuracy: 0.9769 - f1_score: 0.9755 - loss: 0.0794 - precision: 0.9806 - recall: 0.9736
# Epoch 111/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 718ms/step - accuracy: 0.9780 - f1_score: 0.9780 - loss: 0.0783 - precision: 0.9811 - recall: 0.9728
# Epoch 112/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 694ms/step - accuracy: 0.9813 - f1_score: 0.9801 - loss: 0.0593 - precision: 0.9844 - recall: 0.9802
# Epoch 113/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 678ms/step - accuracy: 0.9738 - f1_score: 0.9694 - loss: 0.0733 - precision: 0.9759 - recall: 0.9717
# Epoch 114/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 697ms/step - accuracy: 0.9765 - f1_score: 0.9751 - loss: 0.0880 - precision: 0.9795 - recall: 0.9753
# Epoch 115/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 733ms/step - accuracy: 0.9756 - f1_score: 0.9717 - loss: 0.0977 - precision: 0.9770 - recall: 0.9725
# Epoch 116/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 725ms/step - accuracy: 0.9753 - f1_score: 0.9703 - loss: 0.0814 - precision: 0.9794 - recall: 0.9690
# Epoch 117/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 719ms/step - accuracy: 0.9748 - f1_score: 0.9719 - loss: 0.0771 - precision: 0.9781 - recall: 0.9711
# Epoch 118/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 696ms/step - accuracy: 0.9749 - f1_score: 0.9728 - loss: 0.0710 - precision: 0.9772 - recall: 0.9739
# Epoch 119/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 695ms/step - accuracy: 0.9808 - f1_score: 0.9807 - loss: 0.0541 - precision: 0.9838 - recall: 0.9793
# Epoch 120/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 695ms/step - accuracy: 0.9798 - f1_score: 0.9806 - loss: 0.0587 - precision: 0.9821 - recall: 0.9776
# Epoch 121/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 713ms/step - accuracy: 0.9808 - f1_score: 0.9778 - loss: 0.0595 - precision: 0.9822 - recall: 0.9788
# Epoch 122/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 715ms/step - accuracy: 0.9687 - f1_score: 0.9668 - loss: 0.1069 - precision: 0.9699 - recall: 0.9667
# Epoch 123/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 709ms/step - accuracy: 0.9792 - f1_score: 0.9743 - loss: 0.0677 - precision: 0.9802 - recall: 0.9773
# Epoch 124/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 712ms/step - accuracy: 0.9719 - f1_score: 0.9691 - loss: 0.0815 - precision: 0.9750 - recall: 0.9706
# Epoch 125/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 683ms/step - accuracy: 0.9771 - f1_score: 0.9724 - loss: 0.0769 - precision: 0.9801 - recall: 0.9752
# Epoch 126/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 725ms/step - accuracy: 0.9787 - f1_score: 0.9789 - loss: 0.0661 - precision: 0.9813 - recall: 0.9777
# Epoch 127/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 722ms/step - accuracy: 0.9830 - f1_score: 0.9831 - loss: 0.0545 - precision: 0.9853 - recall: 0.9790
# Epoch 128/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 725ms/step - accuracy: 0.9768 - f1_score: 0.9753 - loss: 0.0763 - precision: 0.9801 - recall: 0.9739
# Epoch 129/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 698ms/step - accuracy: 0.9804 - f1_score: 0.9793 - loss: 0.0609 - precision: 0.9810 - recall: 0.9786
# Epoch 130/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 685ms/step - accuracy: 0.9856 - f1_score: 0.9853 - loss: 0.0503 - precision: 0.9869 - recall: 0.9828
# Epoch 131/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 721ms/step - accuracy: 0.9815 - f1_score: 0.9803 - loss: 0.0704 - precision: 0.9831 - recall: 0.9800
# Epoch 132/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 725ms/step - accuracy: 0.9757 - f1_score: 0.9761 - loss: 0.0693 - precision: 0.9790 - recall: 0.9739
# Epoch 133/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 707ms/step - accuracy: 0.9802 - f1_score: 0.9788 - loss: 0.0727 - precision: 0.9816 - recall: 0.9772
# Epoch 134/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 721ms/step - accuracy: 0.9780 - f1_score: 0.9763 - loss: 0.0739 - precision: 0.9813 - recall: 0.9741
# Epoch 135/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 694ms/step - accuracy: 0.9853 - f1_score: 0.9872 - loss: 0.0496 - precision: 0.9869 - recall: 0.9836
# Epoch 136/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 702ms/step - accuracy: 0.9758 - f1_score: 0.9770 - loss: 0.0661 - precision: 0.9771 - recall: 0.9737
# Epoch 137/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 704ms/step - accuracy: 0.9796 - f1_score: 0.9738 - loss: 0.0617 - precision: 0.9812 - recall: 0.9790
# Epoch 138/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 701ms/step - accuracy: 0.9760 - f1_score: 0.9747 - loss: 0.0729 - precision: 0.9788 - recall: 0.9752
# Epoch 139/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 722ms/step - accuracy: 0.9736 - f1_score: 0.9675 - loss: 0.0818 - precision: 0.9755 - recall: 0.9717
# Epoch 140/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 708ms/step - accuracy: 0.9771 - f1_score: 0.9782 - loss: 0.0639 - precision: 0.9808 - recall: 0.9748
# Epoch 141/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 672ms/step - accuracy: 0.9825 - f1_score: 0.9818 - loss: 0.0681 - precision: 0.9836 - recall: 0.9814
# Epoch 142/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 715ms/step - accuracy: 0.9718 - f1_score: 0.9710 - loss: 0.0831 - precision: 0.9749 - recall: 0.9709
# Epoch 143/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 707ms/step - accuracy: 0.9765 - f1_score: 0.9727 - loss: 0.0575 - precision: 0.9792 - recall: 0.9747
# Epoch 144/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 713ms/step - accuracy: 0.9805 - f1_score: 0.9797 - loss: 0.0580 - precision: 0.9819 - recall: 0.9801
# Epoch 145/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 716ms/step - accuracy: 0.9840 - f1_score: 0.9810 - loss: 0.0595 - precision: 0.9852 - recall: 0.9806
# Epoch 146/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 690ms/step - accuracy: 0.9791 - f1_score: 0.9716 - loss: 0.0576 - precision: 0.9825 - recall: 0.9770
# Epoch 147/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 676ms/step - accuracy: 0.9813 - f1_score: 0.9809 - loss: 0.0518 - precision: 0.9825 - recall: 0.9798
# Epoch 148/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 705ms/step - accuracy: 0.9817 - f1_score: 0.9795 - loss: 0.0523 - precision: 0.9829 - recall: 0.9799
# Epoch 149/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 720ms/step - accuracy: 0.9753 - f1_score: 0.9755 - loss: 0.0882 - precision: 0.9758 - recall: 0.9725
# Epoch 150/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 702ms/step - accuracy: 0.9817 - f1_score: 0.9804 - loss: 0.0572 - precision: 0.9834 - recall: 0.9797
# Epoch 151/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 677ms/step - accuracy: 0.9821 - f1_score: 0.9795 - loss: 0.0551 - precision: 0.9842 - recall: 0.9800
# Epoch 152/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 685ms/step - accuracy: 0.9778 - f1_score: 0.9774 - loss: 0.0705 - precision: 0.9809 - recall: 0.9755
# Epoch 153/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 720ms/step - accuracy: 0.9746 - f1_score: 0.9744 - loss: 0.0806 - precision: 0.9775 - recall: 0.9734
# Epoch 154/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 710ms/step - accuracy: 0.9829 - f1_score: 0.9773 - loss: 0.0534 - precision: 0.9848 - recall: 0.9826
# Epoch 155/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 706ms/step - accuracy: 0.9820 - f1_score: 0.9819 - loss: 0.0523 - precision: 0.9849 - recall: 0.9784
# Epoch 156/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 693ms/step - accuracy: 0.9805 - f1_score: 0.9815 - loss: 0.0598 - precision: 0.9826 - recall: 0.9788
# Epoch 157/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 704ms/step - accuracy: 0.9806 - f1_score: 0.9786 - loss: 0.0647 - precision: 0.9832 - recall: 0.9793
# Epoch 158/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 720ms/step - accuracy: 0.9814 - f1_score: 0.9823 - loss: 0.0558 - precision: 0.9821 - recall: 0.9777
# Epoch 159/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 704ms/step - accuracy: 0.9813 - f1_score: 0.9789 - loss: 0.0662 - precision: 0.9828 - recall: 0.9786
# Epoch 160/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 726ms/step - accuracy: 0.9721 - f1_score: 0.9695 - loss: 0.0879 - precision: 0.9737 - recall: 0.9709
# Epoch 161/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 675ms/step - accuracy: 0.9765 - f1_score: 0.9757 - loss: 0.0748 - precision: 0.9790 - recall: 0.9762
# Epoch 162/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 708ms/step - accuracy: 0.9780 - f1_score: 0.9728 - loss: 0.0673 - precision: 0.9803 - recall: 0.9765
# Epoch 163/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 722ms/step - accuracy: 0.9828 - f1_score: 0.9801 - loss: 0.0599 - precision: 0.9850 - recall: 0.9815
# Epoch 164/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 710ms/step - accuracy: 0.9812 - f1_score: 0.9793 - loss: 0.0608 - precision: 0.9821 - recall: 0.9776
# Epoch 165/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 669ms/step - accuracy: 0.9693 - f1_score: 0.9652 - loss: 0.0784 - precision: 0.9734 - recall: 0.9663
# Epoch 166/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 710ms/step - accuracy: 0.9804 - f1_score: 0.9807 - loss: 0.0538 - precision: 0.9836 - recall: 0.9775
# Epoch 167/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 716ms/step - accuracy: 0.9775 - f1_score: 0.9801 - loss: 0.0607 - precision: 0.9819 - recall: 0.9763
# Epoch 168/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 691ms/step - accuracy: 0.9786 - f1_score: 0.9777 - loss: 0.0649 - precision: 0.9805 - recall: 0.9766
# Epoch 169/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 726ms/step - accuracy: 0.9887 - f1_score: 0.9854 - loss: 0.0355 - precision: 0.9911 - recall: 0.9865
# Epoch 170/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 712ms/step - accuracy: 0.9830 - f1_score: 0.9808 - loss: 0.0487 - precision: 0.9848 - recall: 0.9819
# Epoch 171/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 722ms/step - accuracy: 0.9773 - f1_score: 0.9759 - loss: 0.0617 - precision: 0.9793 - recall: 0.9746
# Epoch 172/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 691ms/step - accuracy: 0.9789 - f1_score: 0.9748 - loss: 0.0672 - precision: 0.9817 - recall: 0.9763
# Epoch 173/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 721ms/step - accuracy: 0.9747 - f1_score: 0.9701 - loss: 0.0752 - precision: 0.9759 - recall: 0.9722
# Epoch 174/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 725ms/step - accuracy: 0.9833 - f1_score: 0.9814 - loss: 0.0462 - precision: 0.9859 - recall: 0.9818
# Epoch 175/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 734ms/step - accuracy: 0.9773 - f1_score: 0.9741 - loss: 0.0626 - precision: 0.9779 - recall: 0.9760
# Epoch 176/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 682ms/step - accuracy: 0.9887 - f1_score: 0.9881 - loss: 0.0381 - precision: 0.9890 - recall: 0.9859
# Epoch 177/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 695ms/step - accuracy: 0.9786 - f1_score: 0.9776 - loss: 0.0670 - precision: 0.9832 - recall: 0.9775
# Epoch 178/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 76s 740ms/step - accuracy: 0.9797 - f1_score: 0.9786 - loss: 0.0567 - precision: 0.9825 - recall: 0.9783
# Epoch 179/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 722ms/step - accuracy: 0.9867 - f1_score: 0.9851 - loss: 0.0355 - precision: 0.9873 - recall: 0.9862
# Epoch 180/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 709ms/step - accuracy: 0.9839 - f1_score: 0.9805 - loss: 0.0549 - precision: 0.9856 - recall: 0.9818
# Epoch 181/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 699ms/step - accuracy: 0.9840 - f1_score: 0.9794 - loss: 0.0464 - precision: 0.9857 - recall: 0.9832
# Epoch 182/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 678ms/step - accuracy: 0.9815 - f1_score: 0.9751 - loss: 0.0714 - precision: 0.9833 - recall: 0.9794
# Epoch 183/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 706ms/step - accuracy: 0.9759 - f1_score: 0.9751 - loss: 0.0709 - precision: 0.9779 - recall: 0.9749
# Epoch 184/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 708ms/step - accuracy: 0.9828 - f1_score: 0.9817 - loss: 0.0552 - precision: 0.9838 - recall: 0.9819
# Epoch 185/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 719ms/step - accuracy: 0.9810 - f1_score: 0.9794 - loss: 0.0602 - precision: 0.9835 - recall: 0.9782
# Epoch 186/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 679ms/step - accuracy: 0.9859 - f1_score: 0.9834 - loss: 0.0524 - precision: 0.9864 - recall: 0.9816
# Epoch 187/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 721ms/step - accuracy: 0.9831 - f1_score: 0.9822 - loss: 0.0509 - precision: 0.9833 - recall: 0.9819
# Epoch 188/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 715ms/step - accuracy: 0.9881 - f1_score: 0.9880 - loss: 0.0386 - precision: 0.9892 - recall: 0.9865
# Epoch 189/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 734ms/step - accuracy: 0.9732 - f1_score: 0.9748 - loss: 0.0742 - precision: 0.9745 - recall: 0.9718
# Epoch 190/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 697ms/step - accuracy: 0.9830 - f1_score: 0.9827 - loss: 0.0527 - precision: 0.9843 - recall: 0.9820
# Epoch 191/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 724ms/step - accuracy: 0.9839 - f1_score: 0.9821 - loss: 0.0533 - precision: 0.9863 - recall: 0.9828
# Epoch 192/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 731ms/step - accuracy: 0.9856 - f1_score: 0.9842 - loss: 0.0419 - precision: 0.9871 - recall: 0.9841
# Epoch 193/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 710ms/step - accuracy: 0.9816 - f1_score: 0.9804 - loss: 0.0582 - precision: 0.9825 - recall: 0.9810
# Epoch 194/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 684ms/step - accuracy: 0.9803 - f1_score: 0.9811 - loss: 0.0659 - precision: 0.9810 - recall: 0.9771
# Epoch 195/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 705ms/step - accuracy: 0.9784 - f1_score: 0.9773 - loss: 0.0580 - precision: 0.9794 - recall: 0.9768
# Epoch 196/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 723ms/step - accuracy: 0.9752 - f1_score: 0.9741 - loss: 0.0682 - precision: 0.9774 - recall: 0.9740
# Epoch 197/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 724ms/step - accuracy: 0.9825 - f1_score: 0.9772 - loss: 0.0576 - precision: 0.9841 - recall: 0.9812
# Epoch 198/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 673ms/step - accuracy: 0.9805 - f1_score: 0.9760 - loss: 0.0601 - precision: 0.9816 - recall: 0.9791
# Epoch 199/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 730ms/step - accuracy: 0.9859 - f1_score: 0.9841 - loss: 0.0436 - precision: 0.9883 - recall: 0.9854
# Epoch 200/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 738ms/step - accuracy: 0.9908 - f1_score: 0.9889 - loss: 0.0337 - precision: 0.9935 - recall: 0.9884
# Training metrics saved to training_metrics.csv
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 176s 8s/step - accuracy: 0.9837 - f1_score: 0.9749 - loss: 0.0484 - precision: 0.9851 - recall: 0.9837
# Test Loss: 0.0444951057434082
# Test Accuracy: 0.9830729365348816
# Test Precision: 0.9843546152114868
# Test Recall: 0.9830729365348816
# Test F1 Score: tf.Tensor(
# [0.96618354 1.         0.9711538  0.9523809  0.9473683  0.9958042
#  1.        ], shape=(7,), dtype=float32)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator

num_classes = 7
height = 128
n_fft = 2048
hop_length = 512
sr = 16000
T = 1

hop_size_sec = hop_length / sr
audio_length_samples = T * sr

width = 1 + int((audio_length_samples - n_fft) / hop_length)

channels = 3

batch_size = 32

model = tf.keras.models.load_model('al-emadi_crnn_standardized_unknown.keras')

test_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms/Test/'

test_datagen = ImageDataGenerator()

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

loss, accuracy, precision, recall, f1_score = model.evaluate(test_generator)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test F1 Score:", f1_score)

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true class labels
true_classes = test_generator.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)
print("\nConfusion Matrix:")
print(conf_matrix)

# Get class labels
class_labels = list(test_generator.class_indices.keys())

# Calculate accuracy for each class
class_accuracy = {}
for i, class_label in enumerate(class_labels):
    correct_indices = np.where(true_classes == i)[0]
    correct_predictions = np.sum(predicted_classes[correct_indices] == i)
    total_samples = len(correct_indices)
    class_accuracy[class_label] = correct_predictions / total_samples if total_samples > 0 else 0.0

# Print accuracy for each class
print("\nAccuracy for each class:")
for class_label in class_labels:
    print(f"{class_label}: {class_accuracy[class_label]:.4f}")

# Print classification report (includes precision, recall, F1-score)
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# Found 768 images belonging to 7 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 28s 993ms/step - accuracy: 0.9749 - f1_score: 0.6552 - loss: 0.0669 - precision: 0.9764 - recall: 0.9749
# Test Loss: 0.044495102018117905
# Test Accuracy: 0.9830729365348816
# Test Precision: 0.9843546152114868
# Test Recall: 0.9830729365348816
# Test F1 Score: tf.Tensor(
# [0.96618354 1.         0.9711538  0.9523809  0.9473683  0.9958042
#  1.        ], shape=(7,), dtype=float32)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 642ms/step
#
# Confusion Matrix:
# [[100   0   2   0   0   2   0]
#  [  0  52   0   0   0   0   0]
#  [  3   0 101   0   0   0   0]
#  [  0   0   0  50   0   0   0]
#  [  0   0   0   5  45   0   0]
#  [  0   0   1   0   0 356   0]
#  [  0   0   0   0   0   0  51]]
#
# Accuracy for each class:
# Bebop: 0.9615
# Crazyflie: 1.0000
# Mambo: 0.9712
# Matrice100: 1.0000
# Mavic: 0.9000
# NonDrone: 0.9972
# Phantom: 1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Bebop       0.97      0.96      0.97       104
#    Crazyflie       1.00      1.00      1.00        52
#        Mambo       0.97      0.97      0.97       104
#   Matrice100       0.91      1.00      0.95        50
#        Mavic       1.00      0.90      0.95        50
#     NonDrone       0.99      1.00      1.00       357
#      Phantom       1.00      1.00      1.00        51
#
#     accuracy                           0.98       768
#    macro avg       0.98      0.98      0.98       768
# weighted avg       0.98      0.98      0.98       768

# %%
import os
import numpy as np
from scipy.stats import entropy
from tensorflow.keras.preprocessing import image

model = tf.keras.models.load_model('/content/al-emadi_crnn_standardized_unknown.keras')
classes = ['Bebop', 'Crazyflie', 'Mambo', 'Matrice100', 'Mavic', 'NonDrone', 'Phantom']

known_counter = 0
unknown_counter = 0

def load_spectrogram(file_path):
    # Load and preprocess the image
    num_classes = 7
    height = 128
    n_fft = 2048
    hop_length = 512
    sr = 16000
    T = 1

    hop_size_sec = hop_length / sr
    audio_length_samples = T * sr

    width = 1 + int((audio_length_samples - n_fft) / hop_length)

    channels = 3

    img = image.load_img(file_path, target_size=(height, width))  # Assuming input size expected by your model
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    #img_array = img_array / 255.0  # Normalize pixel values to [0, 1]
    return img_array

# Function to classify a single spectrogram
def classify_spectrogram(spectrogram, entropy_threshold):
    global known_counter
    global unknown_counter

    probabilities = model.predict(spectrogram)[0]  # Get class probabilities from the model
    ent = entropy(probabilities, base=2)  # Calculate entropy of the probability distribution

    if ent > entropy_threshold:
        unknown_counter+=1
        return "UnknownDrone"
    else:
        known_counter+=1
        max_index = np.argmax(probabilities)  # Get the index of the maximum probability
        return classes[max_index]  # Return the corresponding drone class

# Directory containing spectrogram files
unknown_spectrogram_dir = '/content/drive/MyDrive/UnknownDrone/'
spectrogram_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms/Test/Phantom/'

# Entropy threshold
entropy_threshold =  0.0265  # Adjust this threshold based on your model and validation results

# List all files in the directory
spectrogram_files = os.listdir(spectrogram_dir)

# Process each spectrogram file
for filename in spectrogram_files:
    if filename.endswith('.png'):  # Assuming spectrograms are saved as PNG files
        # Load the spectrogram (you need to implement this part based on your data loading method)
        spectrogram = load_spectrogram(os.path.join(spectrogram_dir, filename))

        # Classify the spectrogram
        predicted_class = classify_spectrogram(spectrogram, entropy_threshold)

        # Print the filename and predicted class
        print(f"{filename}: {predicted_class}")

print("Unknown Drone Count:", unknown_counter)
print("Known Drone Count:", known_counter)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Phantom_Test_File1_0_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Phantom_Test_File2_3_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Phantom_Test_File1_8_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Phantom_Test_File2_13_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Phantom_Test_File2_10_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Phantom_Test_File2_16_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Phantom_Test_File2_24_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Phantom_Test_File2_21_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Phantom_Test_File3_4_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Phantom_Test_File1_0_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File3_9_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Phantom_Test_File1_8_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File2_3_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Phantom_Test_File2_10_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Phantom_Test_File2_13_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Phantom_Test_File2_16_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Phantom_Test_File2_21_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File2_24_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Phantom_Test_File2_26_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Phantom_Test_File3_4_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Phantom_Test_File1_0_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File3_9_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Phantom_Test_File1_8_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Phantom_Test_File2_3_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Phantom_Test_File2_10_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Phantom_Test_File2_13_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Phantom_Test_File2_16_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Phantom_Test_File2_21_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Phantom_Test_File3_4_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Phantom_Test_File2_24_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Phantom_Test_File3_9_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Phantom_Test_File1_0_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Phantom_Test_File1_8_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Phantom_Test_File2_3_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Phantom_Test_File2_10_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Phantom_Test_File2_13_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Phantom_Test_File2_16_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Phantom_Test_File2_21_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Phantom_Test_File2_24_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Phantom_Test_File3_4_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Phantom_Test_File3_9_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Phantom_Test_File1_0_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Phantom_Test_File1_8_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Phantom_Test_File2_3_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Phantom_Test_File2_10_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File2_13_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Phantom_Test_File2_16_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Phantom_Test_File2_21_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Phantom_Test_File2_24_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Phantom_Test_File3_4_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File3_9_PS+2_mel.png: Phantom
# Unknown Drone Count: 0
# Known Drone Count: 51
