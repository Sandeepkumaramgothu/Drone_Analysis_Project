# %%
# !pip install --upgrade keras
# !pip install --upgrade keras tensorflow
import os
import math
import numpy as np
import librosa
import json
import pandas as pd
from termcolor import colored
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
# !pip install tensorboard
# !pip install visualkeras
import visualkeras
from keras.utils import plot_model
from datetime import datetime
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn import svm
from sklearn.svm import SVC
import pickle
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from IPython.display import Audio
from scipy.io import wavfile
import scipy
import soundfile as sf
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras import layers, models
from sklearn.metrics import classification_report
import random
import csv
from keras.callbacks import Callback
from keras.callbacks import CSVLogger
from sklearn.metrics import precision_recall_fscore_support

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting keras
#   Downloading keras-3.4.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Collecting namex (from keras)
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.9.0)
# Collecting optree (from keras)
#   Downloading optree-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.7/347.7 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Installing collected packages: namex, optree, keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.4.1 which is incompatible.
# Successfully installed keras-3.4.1 namex-0.0.8 optree-0.12.1
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting tensorflow
#   Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.9.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Collecting h5py (from keras)
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 55.7 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Collecting ml-dtypes (from keras)
#   Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 56.5 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow)
#   Downloading tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 74.2 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Installing collected packages: ml-dtypes, h5py, tensorboard, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.17.0 which is incompatible.
# Successfully installed h5py-3.11.0 ml-dtypes-0.4.0 tensorboard-2.17.0 tensorflow-2.17.0
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.25.2)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Collecting visualkeras
#   Downloading visualkeras-0.1.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.25.2)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 13.5 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18.post0 visualkeras-0.1.0
# Mounted at /content/drive

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms/Train/'
test_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms/Test/'

num_classes = 7
height = 128
n_fft = 2048
hop_length = 512
sr = 16000
T = 1

hop_size_sec = hop_length / sr
audio_length_samples = T * sr

width = 1 + int((audio_length_samples - n_fft) / hop_length)

channels = 3

train_datagen = ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator()

batch_size = 32

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical')

cnn_model = tf.keras.Sequential()
cnn_model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(height, width, channels)))
cnn_model.add(tf.keras.layers.MaxPooling2D((2, 2)))
cnn_model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
cnn_model.add(tf.keras.layers.MaxPooling2D((2, 2)))
cnn_model.add(tf.keras.layers.Conv2D(128, (3, 3), activation='relu'))
cnn_model.add(tf.keras.layers.MaxPooling2D((2, 2)))
cnn_model.add(tf.keras.layers.Flatten())

# RNN model
rnn_model = tf.keras.Sequential([
    tf.keras.layers.Reshape((width, height * channels), input_shape=(height, width, channels)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu', return_sequences=True)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu', return_sequences=True)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu')),
    tf.keras.layers.BatchNormalization()
])

# Combine CNN and RNN models
model = tf.keras.Sequential([
    tf.keras.layers.Reshape((1, height, width, channels), input_shape=(height, width, channels)),
    tf.keras.layers.TimeDistributed(cnn_model),
    tf.keras.layers.TimeDistributed(tf.keras.layers.Flatten()),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu', return_sequences=True)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu', return_sequences=True)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu')),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy', 'precision', 'recall', 'f1_score'])

epochs = 200
metrics_data = []

for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")

    train_generator.reset()

    history = model.fit(
        train_generator,
        steps_per_epoch=len(train_generator),
        epochs=1,
        verbose=1)

    # Get metrics from history
    accuracy = history.history['accuracy'][0]
    precision = history.history['precision'][0]
    recall = history.history['recall'][0]

    f1_score_tensor = history.history['f1_score'][0]
    f1_score_value = np.mean(f1_score_tensor)

    # Store metrics in a list
    metrics_data.append([accuracy, precision, recall, f1_score_value])

# Save metrics to a CSV file
csv_filename = 'training_metrics.csv'

with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Accuracy', 'Precision', 'Recall', 'F1 Score'])
    writer.writerows(metrics_data)

print(f"Training metrics saved to {csv_filename}")

loss, accuracy, precision, recall, f1_score = model.evaluate(test_generator)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test F1 Score:", f1_score)

model.save('al-emadi_crnn_standardized_unknown.keras')
# Out:
# Found 3088 images belonging to 7 classes.
# Found 768 images belonging to 7 classes.
# Epoch 1/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 84s 679ms/step - accuracy: 0.2324 - f1_score: 0.1582 - loss: 2.0650 - precision: 0.3978 - recall: 0.0844
# Epoch 2/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 679ms/step - accuracy: 0.5598 - f1_score: 0.3916 - loss: 1.2438 - precision: 0.7617 - recall: 0.3715
# Epoch 3/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 655ms/step - accuracy: 0.7097 - f1_score: 0.6171 - loss: 0.8901 - precision: 0.8422 - recall: 0.5616
# Epoch 4/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 712ms/step - accuracy: 0.7444 - f1_score: 0.6567 - loss: 0.7208 - precision: 0.8488 - recall: 0.6426
# Epoch 5/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 678ms/step - accuracy: 0.8109 - f1_score: 0.7547 - loss: 0.5715 - precision: 0.8654 - recall: 0.7311
# Epoch 6/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 663ms/step - accuracy: 0.8319 - f1_score: 0.7840 - loss: 0.5217 - precision: 0.8864 - recall: 0.7679
# Epoch 7/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 76s 729ms/step - accuracy: 0.8492 - f1_score: 0.8029 - loss: 0.4551 - precision: 0.8921 - recall: 0.7949
# Epoch 8/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 647ms/step - accuracy: 0.8462 - f1_score: 0.8119 - loss: 0.4652 - precision: 0.8851 - recall: 0.7977
# Epoch 9/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 668ms/step - accuracy: 0.8693 - f1_score: 0.8424 - loss: 0.4031 - precision: 0.8980 - recall: 0.8325
# Epoch 10/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 687ms/step - accuracy: 0.8749 - f1_score: 0.8481 - loss: 0.3698 - precision: 0.9083 - recall: 0.8391
# Epoch 11/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 658ms/step - accuracy: 0.8653 - f1_score: 0.8441 - loss: 0.4003 - precision: 0.8977 - recall: 0.8286
# Epoch 12/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 650ms/step - accuracy: 0.8707 - f1_score: 0.8507 - loss: 0.3732 - precision: 0.8976 - recall: 0.8408
# Epoch 13/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 675ms/step - accuracy: 0.8788 - f1_score: 0.8529 - loss: 0.3471 - precision: 0.9074 - recall: 0.8546
# Epoch 14/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 678ms/step - accuracy: 0.8891 - f1_score: 0.8755 - loss: 0.3325 - precision: 0.9108 - recall: 0.8671
# Epoch 15/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 665ms/step - accuracy: 0.8945 - f1_score: 0.8770 - loss: 0.3355 - precision: 0.9168 - recall: 0.8725
# Epoch 16/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 686ms/step - accuracy: 0.8903 - f1_score: 0.8786 - loss: 0.3299 - precision: 0.9119 - recall: 0.8691
# Epoch 17/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 669ms/step - accuracy: 0.8979 - f1_score: 0.8886 - loss: 0.3093 - precision: 0.9254 - recall: 0.8779
# Epoch 18/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 670ms/step - accuracy: 0.9086 - f1_score: 0.8952 - loss: 0.2751 - precision: 0.9275 - recall: 0.8830
# Epoch 19/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 650ms/step - accuracy: 0.8983 - f1_score: 0.8831 - loss: 0.2953 - precision: 0.9168 - recall: 0.8805
# Epoch 20/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 667ms/step - accuracy: 0.9179 - f1_score: 0.9099 - loss: 0.2810 - precision: 0.9311 - recall: 0.8968
# Epoch 21/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 684ms/step - accuracy: 0.8837 - f1_score: 0.8640 - loss: 0.3426 - precision: 0.9116 - recall: 0.8613
# Epoch 22/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 712ms/step - accuracy: 0.8963 - f1_score: 0.8772 - loss: 0.2995 - precision: 0.9222 - recall: 0.8741
# Epoch 23/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 650ms/step - accuracy: 0.9019 - f1_score: 0.8887 - loss: 0.3049 - precision: 0.9196 - recall: 0.8798
# Epoch 24/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 660ms/step - accuracy: 0.9222 - f1_score: 0.9131 - loss: 0.2429 - precision: 0.9351 - recall: 0.8976
# Epoch 25/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 667ms/step - accuracy: 0.9167 - f1_score: 0.9071 - loss: 0.2462 - precision: 0.9351 - recall: 0.9039
# Epoch 26/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 667ms/step - accuracy: 0.9121 - f1_score: 0.8962 - loss: 0.2578 - precision: 0.9280 - recall: 0.8970
# Epoch 27/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 658ms/step - accuracy: 0.9195 - f1_score: 0.9125 - loss: 0.2304 - precision: 0.9315 - recall: 0.9050
# Epoch 28/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 651ms/step - accuracy: 0.9249 - f1_score: 0.9208 - loss: 0.2261 - precision: 0.9407 - recall: 0.9172
# Epoch 29/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 646ms/step - accuracy: 0.9291 - f1_score: 0.9233 - loss: 0.2150 - precision: 0.9420 - recall: 0.9162
# Epoch 30/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 664ms/step - accuracy: 0.9279 - f1_score: 0.9172 - loss: 0.2211 - precision: 0.9398 - recall: 0.9172
# Epoch 31/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 692ms/step - accuracy: 0.9141 - f1_score: 0.9004 - loss: 0.2634 - precision: 0.9315 - recall: 0.8999
# Epoch 32/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 660ms/step - accuracy: 0.9302 - f1_score: 0.9257 - loss: 0.2154 - precision: 0.9417 - recall: 0.9195
# Epoch 33/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 661ms/step - accuracy: 0.9380 - f1_score: 0.9362 - loss: 0.1785 - precision: 0.9448 - recall: 0.9301
# Epoch 34/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 727ms/step - accuracy: 0.9432 - f1_score: 0.9342 - loss: 0.1795 - precision: 0.9519 - recall: 0.9322
# Epoch 35/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 650ms/step - accuracy: 0.9231 - f1_score: 0.9166 - loss: 0.2363 - precision: 0.9333 - recall: 0.9127
# Epoch 36/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 658ms/step - accuracy: 0.9019 - f1_score: 0.8964 - loss: 0.2969 - precision: 0.9236 - recall: 0.8813
# Epoch 37/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 717ms/step - accuracy: 0.9265 - f1_score: 0.9223 - loss: 0.2141 - precision: 0.9415 - recall: 0.9084
# Epoch 38/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 650ms/step - accuracy: 0.9202 - f1_score: 0.9164 - loss: 0.2461 - precision: 0.9305 - recall: 0.9061
# Epoch 39/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 660ms/step - accuracy: 0.9331 - f1_score: 0.9251 - loss: 0.1995 - precision: 0.9448 - recall: 0.9174
# Epoch 40/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 664ms/step - accuracy: 0.9284 - f1_score: 0.9244 - loss: 0.2079 - precision: 0.9435 - recall: 0.9163
# Epoch 41/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 642ms/step - accuracy: 0.9374 - f1_score: 0.9344 - loss: 0.1670 - precision: 0.9465 - recall: 0.9305
# Epoch 42/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 644ms/step - accuracy: 0.9393 - f1_score: 0.9410 - loss: 0.1731 - precision: 0.9480 - recall: 0.9321
# Epoch 43/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 718ms/step - accuracy: 0.9369 - f1_score: 0.9335 - loss: 0.1900 - precision: 0.9457 - recall: 0.9287
# Epoch 44/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 670ms/step - accuracy: 0.9379 - f1_score: 0.9341 - loss: 0.1927 - precision: 0.9475 - recall: 0.9318
# Epoch 45/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 664ms/step - accuracy: 0.9402 - f1_score: 0.9356 - loss: 0.1940 - precision: 0.9499 - recall: 0.9304
# Epoch 46/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 694ms/step - accuracy: 0.9450 - f1_score: 0.9393 - loss: 0.1667 - precision: 0.9530 - recall: 0.9383
# Epoch 47/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 668ms/step - accuracy: 0.9381 - f1_score: 0.9325 - loss: 0.1918 - precision: 0.9474 - recall: 0.9296
# Epoch 48/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 669ms/step - accuracy: 0.9464 - f1_score: 0.9470 - loss: 0.1688 - precision: 0.9519 - recall: 0.9427
# Epoch 49/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 649ms/step - accuracy: 0.9430 - f1_score: 0.9380 - loss: 0.1828 - precision: 0.9517 - recall: 0.9342
# Epoch 50/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 669ms/step - accuracy: 0.9511 - f1_score: 0.9504 - loss: 0.1525 - precision: 0.9578 - recall: 0.9451
# Epoch 51/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 76s 742ms/step - accuracy: 0.9280 - f1_score: 0.9232 - loss: 0.2276 - precision: 0.9362 - recall: 0.9146
# Epoch 52/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 678ms/step - accuracy: 0.9400 - f1_score: 0.9411 - loss: 0.1775 - precision: 0.9500 - recall: 0.9304
# Epoch 53/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 665ms/step - accuracy: 0.9465 - f1_score: 0.9425 - loss: 0.1634 - precision: 0.9551 - recall: 0.9394
# Epoch 54/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 668ms/step - accuracy: 0.9439 - f1_score: 0.9427 - loss: 0.1649 - precision: 0.9536 - recall: 0.9370
# Epoch 55/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 73s 720ms/step - accuracy: 0.9569 - f1_score: 0.9513 - loss: 0.1427 - precision: 0.9640 - recall: 0.9499
# Epoch 56/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 665ms/step - accuracy: 0.9313 - f1_score: 0.9211 - loss: 0.2043 - precision: 0.9406 - recall: 0.9238
# Epoch 57/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 651ms/step - accuracy: 0.9556 - f1_score: 0.9556 - loss: 0.1422 - precision: 0.9639 - recall: 0.9491
# Epoch 58/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 697ms/step - accuracy: 0.9408 - f1_score: 0.9348 - loss: 0.1863 - precision: 0.9452 - recall: 0.9320
# Epoch 59/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 645ms/step - accuracy: 0.9525 - f1_score: 0.9519 - loss: 0.1535 - precision: 0.9604 - recall: 0.9464
# Epoch 60/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.9487 - f1_score: 0.9453 - loss: 0.1428 - precision: 0.9567 - recall: 0.9428
# Epoch 61/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 695ms/step - accuracy: 0.9455 - f1_score: 0.9388 - loss: 0.1542 - precision: 0.9566 - recall: 0.9405
# Epoch 62/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 668ms/step - accuracy: 0.9448 - f1_score: 0.9452 - loss: 0.1715 - precision: 0.9491 - recall: 0.9374
# Epoch 63/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 659ms/step - accuracy: 0.9528 - f1_score: 0.9500 - loss: 0.1375 - precision: 0.9603 - recall: 0.9454
# Epoch 64/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 72s 711ms/step - accuracy: 0.9564 - f1_score: 0.9529 - loss: 0.1236 - precision: 0.9646 - recall: 0.9505
# Epoch 65/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 659ms/step - accuracy: 0.9566 - f1_score: 0.9556 - loss: 0.1113 - precision: 0.9664 - recall: 0.9546
# Epoch 66/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 660ms/step - accuracy: 0.9652 - f1_score: 0.9625 - loss: 0.1084 - precision: 0.9716 - recall: 0.9587
# Epoch 67/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 723ms/step - accuracy: 0.9533 - f1_score: 0.9530 - loss: 0.1382 - precision: 0.9581 - recall: 0.9473
# Epoch 68/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 662ms/step - accuracy: 0.9590 - f1_score: 0.9520 - loss: 0.1294 - precision: 0.9657 - recall: 0.9530
# Epoch 69/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.9549 - f1_score: 0.9532 - loss: 0.1354 - precision: 0.9654 - recall: 0.9492
# Epoch 70/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 664ms/step - accuracy: 0.9510 - f1_score: 0.9520 - loss: 0.1517 - precision: 0.9606 - recall: 0.9474
# Epoch 71/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 645ms/step - accuracy: 0.9471 - f1_score: 0.9455 - loss: 0.1461 - precision: 0.9534 - recall: 0.9415
# Epoch 72/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 74s 722ms/step - accuracy: 0.9588 - f1_score: 0.9545 - loss: 0.1366 - precision: 0.9681 - recall: 0.9534
# Epoch 73/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 679ms/step - accuracy: 0.9695 - f1_score: 0.9696 - loss: 0.1001 - precision: 0.9730 - recall: 0.9627
# Epoch 74/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 650ms/step - accuracy: 0.9599 - f1_score: 0.9595 - loss: 0.1260 - precision: 0.9643 - recall: 0.9572
# Epoch 75/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 677ms/step - accuracy: 0.9572 - f1_score: 0.9539 - loss: 0.1420 - precision: 0.9615 - recall: 0.9527
# Epoch 76/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 661ms/step - accuracy: 0.9614 - f1_score: 0.9561 - loss: 0.1249 - precision: 0.9658 - recall: 0.9573
# Epoch 77/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 674ms/step - accuracy: 0.9506 - f1_score: 0.9455 - loss: 0.1443 - precision: 0.9609 - recall: 0.9415
# Epoch 78/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 678ms/step - accuracy: 0.9600 - f1_score: 0.9572 - loss: 0.1146 - precision: 0.9624 - recall: 0.9534
# Epoch 79/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 76s 744ms/step - accuracy: 0.9572 - f1_score: 0.9577 - loss: 0.1076 - precision: 0.9638 - recall: 0.9539
# Epoch 80/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 648ms/step - accuracy: 0.9604 - f1_score: 0.9572 - loss: 0.1186 - precision: 0.9689 - recall: 0.9548
# Epoch 81/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 663ms/step - accuracy: 0.9550 - f1_score: 0.9554 - loss: 0.1474 - precision: 0.9602 - recall: 0.9465
# Epoch 82/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 75s 654ms/step - accuracy: 0.9627 - f1_score: 0.9533 - loss: 0.1188 - precision: 0.9671 - recall: 0.9575
# Epoch 83/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 652ms/step - accuracy: 0.9678 - f1_score: 0.9632 - loss: 0.1248 - precision: 0.9702 - recall: 0.9618
# Epoch 84/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 664ms/step - accuracy: 0.9573 - f1_score: 0.9571 - loss: 0.1240 - precision: 0.9631 - recall: 0.9527
# Epoch 85/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 640ms/step - accuracy: 0.9542 - f1_score: 0.9506 - loss: 0.1340 - precision: 0.9596 - recall: 0.9490
# Epoch 86/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 659ms/step - accuracy: 0.9685 - f1_score: 0.9664 - loss: 0.1159 - precision: 0.9721 - recall: 0.9610
# Epoch 87/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 679ms/step - accuracy: 0.9713 - f1_score: 0.9684 - loss: 0.0912 - precision: 0.9766 - recall: 0.9690
# Epoch 88/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 696ms/step - accuracy: 0.9624 - f1_score: 0.9615 - loss: 0.1227 - precision: 0.9672 - recall: 0.9574
# Epoch 89/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 666ms/step - accuracy: 0.9576 - f1_score: 0.9528 - loss: 0.1174 - precision: 0.9653 - recall: 0.9533
# Epoch 90/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 679ms/step - accuracy: 0.9661 - f1_score: 0.9660 - loss: 0.1055 - precision: 0.9686 - recall: 0.9612
# Epoch 91/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 671ms/step - accuracy: 0.9635 - f1_score: 0.9598 - loss: 0.1252 - precision: 0.9691 - recall: 0.9595
# Epoch 92/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 662ms/step - accuracy: 0.9625 - f1_score: 0.9570 - loss: 0.1169 - precision: 0.9682 - recall: 0.9563
# Epoch 93/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 664ms/step - accuracy: 0.9626 - f1_score: 0.9586 - loss: 0.1061 - precision: 0.9698 - recall: 0.9576
# Epoch 94/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 688ms/step - accuracy: 0.9623 - f1_score: 0.9606 - loss: 0.1257 - precision: 0.9660 - recall: 0.9549
# Epoch 95/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 659ms/step - accuracy: 0.9679 - f1_score: 0.9675 - loss: 0.1107 - precision: 0.9694 - recall: 0.9622
# Epoch 96/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 659ms/step - accuracy: 0.9635 - f1_score: 0.9592 - loss: 0.1171 - precision: 0.9680 - recall: 0.9587
# Epoch 97/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 661ms/step - accuracy: 0.9715 - f1_score: 0.9714 - loss: 0.1028 - precision: 0.9740 - recall: 0.9663
# Epoch 98/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 667ms/step - accuracy: 0.9695 - f1_score: 0.9673 - loss: 0.0971 - precision: 0.9757 - recall: 0.9653
# Epoch 99/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 673ms/step - accuracy: 0.9660 - f1_score: 0.9611 - loss: 0.1022 - precision: 0.9692 - recall: 0.9609
# Epoch 100/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 647ms/step - accuracy: 0.9680 - f1_score: 0.9668 - loss: 0.0898 - precision: 0.9724 - recall: 0.9620
# Epoch 101/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 659ms/step - accuracy: 0.9703 - f1_score: 0.9697 - loss: 0.0903 - precision: 0.9728 - recall: 0.9665
# Epoch 102/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 642ms/step - accuracy: 0.9632 - f1_score: 0.9659 - loss: 0.1034 - precision: 0.9679 - recall: 0.9614
# Epoch 103/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 664ms/step - accuracy: 0.9639 - f1_score: 0.9586 - loss: 0.1071 - precision: 0.9656 - recall: 0.9592
# Epoch 104/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 71s 688ms/step - accuracy: 0.9627 - f1_score: 0.9633 - loss: 0.1161 - precision: 0.9662 - recall: 0.9589
# Epoch 105/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 642ms/step - accuracy: 0.9542 - f1_score: 0.9424 - loss: 0.1330 - precision: 0.9594 - recall: 0.9516
# Epoch 106/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 670ms/step - accuracy: 0.9679 - f1_score: 0.9670 - loss: 0.0959 - precision: 0.9711 - recall: 0.9637
# Epoch 107/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 656ms/step - accuracy: 0.9696 - f1_score: 0.9686 - loss: 0.0832 - precision: 0.9717 - recall: 0.9687
# Epoch 108/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 644ms/step - accuracy: 0.9665 - f1_score: 0.9639 - loss: 0.0995 - precision: 0.9705 - recall: 0.9611
# Epoch 109/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 660ms/step - accuracy: 0.9678 - f1_score: 0.9629 - loss: 0.1058 - precision: 0.9721 - recall: 0.9611
# Epoch 110/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 644ms/step - accuracy: 0.9757 - f1_score: 0.9746 - loss: 0.0789 - precision: 0.9780 - recall: 0.9707
# Epoch 111/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 660ms/step - accuracy: 0.9654 - f1_score: 0.9643 - loss: 0.0946 - precision: 0.9712 - recall: 0.9635
# Epoch 112/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 664ms/step - accuracy: 0.9684 - f1_score: 0.9625 - loss: 0.0854 - precision: 0.9725 - recall: 0.9635
# Epoch 113/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 643ms/step - accuracy: 0.9736 - f1_score: 0.9728 - loss: 0.0764 - precision: 0.9779 - recall: 0.9696
# Epoch 114/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 653ms/step - accuracy: 0.9619 - f1_score: 0.9567 - loss: 0.1029 - precision: 0.9676 - recall: 0.9607
# Epoch 115/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 664ms/step - accuracy: 0.9738 - f1_score: 0.9748 - loss: 0.0826 - precision: 0.9746 - recall: 0.9687
# Epoch 116/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 652ms/step - accuracy: 0.9715 - f1_score: 0.9694 - loss: 0.1017 - precision: 0.9731 - recall: 0.9676
# Epoch 117/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 658ms/step - accuracy: 0.9697 - f1_score: 0.9669 - loss: 0.1056 - precision: 0.9760 - recall: 0.9641
# Epoch 118/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 655ms/step - accuracy: 0.9750 - f1_score: 0.9748 - loss: 0.0754 - precision: 0.9765 - recall: 0.9723
# Epoch 119/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 642ms/step - accuracy: 0.9702 - f1_score: 0.9725 - loss: 0.0777 - precision: 0.9730 - recall: 0.9666
# Epoch 120/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 676ms/step - accuracy: 0.9649 - f1_score: 0.9596 - loss: 0.0900 - precision: 0.9678 - recall: 0.9595
# Epoch 121/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 659ms/step - accuracy: 0.9677 - f1_score: 0.9686 - loss: 0.0969 - precision: 0.9725 - recall: 0.9639
# Epoch 122/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 657ms/step - accuracy: 0.9668 - f1_score: 0.9670 - loss: 0.0882 - precision: 0.9735 - recall: 0.9650
# Epoch 123/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 659ms/step - accuracy: 0.9730 - f1_score: 0.9678 - loss: 0.0720 - precision: 0.9765 - recall: 0.9701
# Epoch 124/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 645ms/step - accuracy: 0.9707 - f1_score: 0.9661 - loss: 0.0893 - precision: 0.9708 - recall: 0.9688
# Epoch 125/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 673ms/step - accuracy: 0.9761 - f1_score: 0.9697 - loss: 0.0770 - precision: 0.9791 - recall: 0.9731
# Epoch 126/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 667ms/step - accuracy: 0.9614 - f1_score: 0.9581 - loss: 0.1089 - precision: 0.9662 - recall: 0.9543
# Epoch 127/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 642ms/step - accuracy: 0.9733 - f1_score: 0.9714 - loss: 0.0885 - precision: 0.9760 - recall: 0.9697
# Epoch 128/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 670ms/step - accuracy: 0.9588 - f1_score: 0.9536 - loss: 0.1228 - precision: 0.9621 - recall: 0.9541
# Epoch 129/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 681ms/step - accuracy: 0.9767 - f1_score: 0.9768 - loss: 0.0729 - precision: 0.9807 - recall: 0.9764
# Epoch 130/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 646ms/step - accuracy: 0.9699 - f1_score: 0.9651 - loss: 0.0871 - precision: 0.9752 - recall: 0.9660
# Epoch 131/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 660ms/step - accuracy: 0.9737 - f1_score: 0.9715 - loss: 0.0762 - precision: 0.9782 - recall: 0.9691
# Epoch 132/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 651ms/step - accuracy: 0.9764 - f1_score: 0.9732 - loss: 0.0780 - precision: 0.9796 - recall: 0.9726
# Epoch 133/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 673ms/step - accuracy: 0.9630 - f1_score: 0.9592 - loss: 0.1119 - precision: 0.9666 - recall: 0.9598
# Epoch 134/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 669ms/step - accuracy: 0.9700 - f1_score: 0.9657 - loss: 0.0882 - precision: 0.9750 - recall: 0.9667
# Epoch 135/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 644ms/step - accuracy: 0.9687 - f1_score: 0.9692 - loss: 0.0921 - precision: 0.9725 - recall: 0.9634
# Epoch 136/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 662ms/step - accuracy: 0.9623 - f1_score: 0.9582 - loss: 0.0981 - precision: 0.9646 - recall: 0.9604
# Epoch 137/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 678ms/step - accuracy: 0.9759 - f1_score: 0.9765 - loss: 0.0655 - precision: 0.9772 - recall: 0.9740
# Epoch 138/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 651ms/step - accuracy: 0.9793 - f1_score: 0.9780 - loss: 0.0645 - precision: 0.9809 - recall: 0.9744
# Epoch 139/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.9717 - f1_score: 0.9704 - loss: 0.0827 - precision: 0.9737 - recall: 0.9698
# Epoch 140/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 640ms/step - accuracy: 0.9658 - f1_score: 0.9603 - loss: 0.1092 - precision: 0.9691 - recall: 0.9623
# Epoch 141/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 641ms/step - accuracy: 0.9850 - f1_score: 0.9849 - loss: 0.0552 - precision: 0.9865 - recall: 0.9835
# Epoch 142/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 653ms/step - accuracy: 0.9728 - f1_score: 0.9680 - loss: 0.1006 - precision: 0.9748 - recall: 0.9707
# Epoch 143/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 654ms/step - accuracy: 0.9644 - f1_score: 0.9662 - loss: 0.0978 - precision: 0.9689 - recall: 0.9611
# Epoch 144/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 649ms/step - accuracy: 0.9783 - f1_score: 0.9776 - loss: 0.0589 - precision: 0.9823 - recall: 0.9753
# Epoch 145/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 645ms/step - accuracy: 0.9763 - f1_score: 0.9713 - loss: 0.0635 - precision: 0.9791 - recall: 0.9741
# Epoch 146/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 656ms/step - accuracy: 0.9777 - f1_score: 0.9787 - loss: 0.0747 - precision: 0.9792 - recall: 0.9759
# Epoch 147/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 647ms/step - accuracy: 0.9781 - f1_score: 0.9793 - loss: 0.0674 - precision: 0.9791 - recall: 0.9753
# Epoch 148/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 643ms/step - accuracy: 0.9778 - f1_score: 0.9775 - loss: 0.0700 - precision: 0.9794 - recall: 0.9762
# Epoch 149/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 640ms/step - accuracy: 0.9713 - f1_score: 0.9714 - loss: 0.0778 - precision: 0.9750 - recall: 0.9680
# Epoch 150/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 659ms/step - accuracy: 0.9763 - f1_score: 0.9757 - loss: 0.0719 - precision: 0.9792 - recall: 0.9731
# Epoch 151/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 645ms/step - accuracy: 0.9750 - f1_score: 0.9751 - loss: 0.0874 - precision: 0.9759 - recall: 0.9727
# Epoch 152/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.9816 - f1_score: 0.9850 - loss: 0.0575 - precision: 0.9835 - recall: 0.9800
# Epoch 153/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 646ms/step - accuracy: 0.9754 - f1_score: 0.9747 - loss: 0.0813 - precision: 0.9766 - recall: 0.9737
# Epoch 154/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 644ms/step - accuracy: 0.9819 - f1_score: 0.9776 - loss: 0.0645 - precision: 0.9820 - recall: 0.9805
# Epoch 155/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 642ms/step - accuracy: 0.9741 - f1_score: 0.9659 - loss: 0.0793 - precision: 0.9771 - recall: 0.9698
# Epoch 156/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 651ms/step - accuracy: 0.9820 - f1_score: 0.9810 - loss: 0.0719 - precision: 0.9849 - recall: 0.9766
# Epoch 157/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 662ms/step - accuracy: 0.9867 - f1_score: 0.9853 - loss: 0.0498 - precision: 0.9886 - recall: 0.9855
# Epoch 158/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 642ms/step - accuracy: 0.9753 - f1_score: 0.9751 - loss: 0.0676 - precision: 0.9773 - recall: 0.9740
# Epoch 159/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 642ms/step - accuracy: 0.9678 - f1_score: 0.9673 - loss: 0.0839 - precision: 0.9702 - recall: 0.9653
# Epoch 160/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 643ms/step - accuracy: 0.9789 - f1_score: 0.9806 - loss: 0.0752 - precision: 0.9801 - recall: 0.9767
# Epoch 161/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 655ms/step - accuracy: 0.9790 - f1_score: 0.9778 - loss: 0.0751 - precision: 0.9805 - recall: 0.9773
# Epoch 162/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 656ms/step - accuracy: 0.9791 - f1_score: 0.9777 - loss: 0.0583 - precision: 0.9815 - recall: 0.9778
# Epoch 163/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 644ms/step - accuracy: 0.9686 - f1_score: 0.9664 - loss: 0.1087 - precision: 0.9697 - recall: 0.9662
# Epoch 164/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 645ms/step - accuracy: 0.9750 - f1_score: 0.9733 - loss: 0.0725 - precision: 0.9764 - recall: 0.9728
# Epoch 165/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 656ms/step - accuracy: 0.9816 - f1_score: 0.9808 - loss: 0.0595 - precision: 0.9831 - recall: 0.9788
# Epoch 166/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 645ms/step - accuracy: 0.9799 - f1_score: 0.9752 - loss: 0.0631 - precision: 0.9827 - recall: 0.9783
# Epoch 167/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 644ms/step - accuracy: 0.9793 - f1_score: 0.9769 - loss: 0.0621 - precision: 0.9808 - recall: 0.9763
# Epoch 168/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 650ms/step - accuracy: 0.9823 - f1_score: 0.9814 - loss: 0.0548 - precision: 0.9835 - recall: 0.9796
# Epoch 169/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 658ms/step - accuracy: 0.9743 - f1_score: 0.9788 - loss: 0.0954 - precision: 0.9759 - recall: 0.9726
# Epoch 170/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 649ms/step - accuracy: 0.9877 - f1_score: 0.9862 - loss: 0.0442 - precision: 0.9883 - recall: 0.9865
# Epoch 171/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 645ms/step - accuracy: 0.9701 - f1_score: 0.9676 - loss: 0.1051 - precision: 0.9706 - recall: 0.9671
# Epoch 172/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 653ms/step - accuracy: 0.9767 - f1_score: 0.9760 - loss: 0.0701 - precision: 0.9821 - recall: 0.9737
# Epoch 173/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 664ms/step - accuracy: 0.9834 - f1_score: 0.9813 - loss: 0.0554 - precision: 0.9842 - recall: 0.9817
# Epoch 174/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 648ms/step - accuracy: 0.9720 - f1_score: 0.9710 - loss: 0.0715 - precision: 0.9732 - recall: 0.9696
# Epoch 175/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 654ms/step - accuracy: 0.9809 - f1_score: 0.9807 - loss: 0.0659 - precision: 0.9844 - recall: 0.9798
# Epoch 176/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 654ms/step - accuracy: 0.9822 - f1_score: 0.9812 - loss: 0.0562 - precision: 0.9849 - recall: 0.9800
# Epoch 177/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 644ms/step - accuracy: 0.9822 - f1_score: 0.9819 - loss: 0.0577 - precision: 0.9831 - recall: 0.9795
# Epoch 178/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 656ms/step - accuracy: 0.9769 - f1_score: 0.9736 - loss: 0.0868 - precision: 0.9797 - recall: 0.9731
# Epoch 179/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 656ms/step - accuracy: 0.9865 - f1_score: 0.9857 - loss: 0.0439 - precision: 0.9876 - recall: 0.9838
# Epoch 180/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 653ms/step - accuracy: 0.9768 - f1_score: 0.9763 - loss: 0.0698 - precision: 0.9772 - recall: 0.9767
# Epoch 181/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 647ms/step - accuracy: 0.9840 - f1_score: 0.9848 - loss: 0.0477 - precision: 0.9861 - recall: 0.9833
# Epoch 182/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 647ms/step - accuracy: 0.9823 - f1_score: 0.9821 - loss: 0.0561 - precision: 0.9835 - recall: 0.9803
# Epoch 183/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 656ms/step - accuracy: 0.9852 - f1_score: 0.9834 - loss: 0.0563 - precision: 0.9872 - recall: 0.9845
# Epoch 184/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 654ms/step - accuracy: 0.9704 - f1_score: 0.9652 - loss: 0.0930 - precision: 0.9737 - recall: 0.9670
# Epoch 185/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 649ms/step - accuracy: 0.9821 - f1_score: 0.9792 - loss: 0.0573 - precision: 0.9840 - recall: 0.9808
# Epoch 186/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 651ms/step - accuracy: 0.9760 - f1_score: 0.9750 - loss: 0.0763 - precision: 0.9773 - recall: 0.9746
# Epoch 187/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 654ms/step - accuracy: 0.9824 - f1_score: 0.9809 - loss: 0.0540 - precision: 0.9857 - recall: 0.9813
# Epoch 188/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 646ms/step - accuracy: 0.9824 - f1_score: 0.9766 - loss: 0.0614 - precision: 0.9839 - recall: 0.9817
# Epoch 189/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 645ms/step - accuracy: 0.9824 - f1_score: 0.9772 - loss: 0.0490 - precision: 0.9854 - recall: 0.9801
# Epoch 190/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 650ms/step - accuracy: 0.9852 - f1_score: 0.9848 - loss: 0.0500 - precision: 0.9863 - recall: 0.9851
# Epoch 191/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 664ms/step - accuracy: 0.9856 - f1_score: 0.9852 - loss: 0.0493 - precision: 0.9858 - recall: 0.9848
# Epoch 192/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 654ms/step - accuracy: 0.9792 - f1_score: 0.9725 - loss: 0.0677 - precision: 0.9835 - recall: 0.9783
# Epoch 193/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 640ms/step - accuracy: 0.9755 - f1_score: 0.9804 - loss: 0.0547 - precision: 0.9799 - recall: 0.9733
# Epoch 194/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 644ms/step - accuracy: 0.9817 - f1_score: 0.9819 - loss: 0.0570 - precision: 0.9838 - recall: 0.9811
# Epoch 195/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 644ms/step - accuracy: 0.9778 - f1_score: 0.9761 - loss: 0.0653 - precision: 0.9792 - recall: 0.9758
# Epoch 196/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 646ms/step - accuracy: 0.9844 - f1_score: 0.9870 - loss: 0.0484 - precision: 0.9869 - recall: 0.9834
# Epoch 197/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 648ms/step - accuracy: 0.9856 - f1_score: 0.9840 - loss: 0.0436 - precision: 0.9871 - recall: 0.9846
# Epoch 198/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 663ms/step - accuracy: 0.9824 - f1_score: 0.9819 - loss: 0.0626 - precision: 0.9842 - recall: 0.9802
# Epoch 199/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 642ms/step - accuracy: 0.9786 - f1_score: 0.9769 - loss: 0.0773 - precision: 0.9822 - recall: 0.9778
# Epoch 200/200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 648ms/step - accuracy: 0.9799 - f1_score: 0.9788 - loss: 0.0523 - precision: 0.9812 - recall: 0.9796
# Training metrics saved to training_metrics.csv
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 470s 20s/step - accuracy: 0.9720 - f1_score: 0.9674 - loss: 0.1109 - precision: 0.9731 - recall: 0.9720
# Test Loss: 0.07280538231134415
# Test Accuracy: 0.9817708134651184
# Test Precision: 0.9830508232116699
# Test Recall: 0.9817708134651184
# Test F1 Score: tf.Tensor(
# [0.98076916 1.         0.9383885  1.         1.         0.9845288
#  1.        ], shape=(7,), dtype=float32)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator

num_classes = 7
height = 128
n_fft = 2048
hop_length = 512
sr = 16000
T = 1

hop_size_sec = hop_length / sr
audio_length_samples = T * sr

width = 1 + int((audio_length_samples - n_fft) / hop_length)

channels = 3

batch_size = 32

model = tf.keras.models.load_model('al-emadi_crnn_standardized_unknown.keras')

test_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms/Test/'

test_datagen = ImageDataGenerator()

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

loss, accuracy, precision, recall, f1_score = model.evaluate(test_generator)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test F1 Score:", f1_score)

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true class labels
true_classes = test_generator.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)
print("\nConfusion Matrix:")
print(conf_matrix)

# Get class labels
class_labels = list(test_generator.class_indices.keys())

# Calculate accuracy for each class
class_accuracy = {}
for i, class_label in enumerate(class_labels):
    correct_indices = np.where(true_classes == i)[0]
    correct_predictions = np.sum(predicted_classes[correct_indices] == i)
    total_samples = len(correct_indices)
    class_accuracy[class_label] = correct_predictions / total_samples if total_samples > 0 else 0.0

# Print accuracy for each class
print("\nAccuracy for each class:")
for class_label in class_labels:
    print(f"{class_label}: {class_accuracy[class_label]:.4f}")

# Print classification report (includes precision, recall, F1-score)
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# Found 768 images belonging to 7 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 551ms/step - accuracy: 0.9794 - f1_score: 0.6631 - loss: 0.0969 - precision: 0.9811 - recall: 0.9794
# Test Loss: 0.07280539721250534
# Test Accuracy: 0.9817708134651184
# Test Precision: 0.9830508232116699
# Test Recall: 0.9817708134651184
# Test F1 Score: tf.Tensor(
# [0.98076916 1.         0.9383885  1.         1.         0.9845288
#  1.        ], shape=(7,), dtype=float32)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 14s 514ms/step
#
# Confusion Matrix:
# [[102   0   2   0   0   0   0]
#  [  0  52   0   0   0   0   0]
#  [  1   0  99   0   0   4   0]
#  [  0   0   0  50   0   0   0]
#  [  0   0   0   0  50   0   0]
#  [  1   0   6   0   0 350   0]
#  [  0   0   0   0   0   0  51]]
#
# Accuracy for each class:
# Bebop: 0.9808
# Crazyflie: 1.0000
# Mambo: 0.9519
# Matrice100: 1.0000
# Mavic: 1.0000
# NonDrone: 0.9804
# Phantom: 1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Bebop       0.98      0.98      0.98       104
#    Crazyflie       1.00      1.00      1.00        52
#        Mambo       0.93      0.95      0.94       104
#   Matrice100       1.00      1.00      1.00        50
#        Mavic       1.00      1.00      1.00        50
#     NonDrone       0.99      0.98      0.98       357
#      Phantom       1.00      1.00      1.00        51
#
#     accuracy                           0.98       768
#    macro avg       0.98      0.99      0.99       768
# weighted avg       0.98      0.98      0.98       768

# %%
import os
import numpy as np
from scipy.stats import entropy
from tensorflow.keras.preprocessing import image

model = tf.keras.models.load_model('/content/al-emadi_crnn_standardized_unknown.keras')
classes = ['Bebop', 'Crazyflie', 'Mambo', 'Matrice100', 'Mavic', 'NonDrone', 'Phantom']

known_counter = 0
unknown_counter = 0

def load_spectrogram(file_path):
    # Load and preprocess the image
    num_classes = 7
    height = 128
    n_fft = 2048
    hop_length = 512
    sr = 16000
    T = 1

    hop_size_sec = hop_length / sr
    audio_length_samples = T * sr

    width = 1 + int((audio_length_samples - n_fft) / hop_length)

    channels = 3

    img = image.load_img(file_path, target_size=(height, width))  # Assuming input size expected by your model
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    #img_array = img_array / 255.0  # Normalize pixel values to [0, 1]
    return img_array

# Function to classify a single spectrogram
def classify_spectrogram(spectrogram, entropy_threshold):
    global known_counter
    global unknown_counter

    probabilities = model.predict(spectrogram)[0]  # Get class probabilities from the model
    ent = entropy(probabilities, base=2)  # Calculate entropy of the probability distribution

    if ent > entropy_threshold:
        unknown_counter+=1
        return "UnknownDrone"
    else:
        known_counter+=1
        max_index = np.argmax(probabilities)  # Get the index of the maximum probability
        return classes[max_index]  # Return the corresponding drone class

# Directory containing spectrogram files
unknown_spectrogram_dir = '/content/drive/MyDrive/UnknownDrone/'
spectrogram_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms/Test/Phantom/'

# Entropy threshold
entropy_threshold =  0.0175  # Adjust this threshold based on your model and validation results

# List all files in the directory
spectrogram_files = os.listdir(spectrogram_dir)

# Process each spectrogram file
for filename in spectrogram_files:
    if filename.endswith('.png'):  # Assuming spectrograms are saved as PNG files
        # Load the spectrogram (you need to implement this part based on your data loading method)
        spectrogram = load_spectrogram(os.path.join(spectrogram_dir, filename))

        # Classify the spectrogram
        predicted_class = classify_spectrogram(spectrogram, entropy_threshold)

        # Print the filename and predicted class
        print(f"{filename}: {predicted_class}")

print("Unknown Drone Count:", unknown_counter)
print("Known Drone Count:", known_counter)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# Phantom_Test_File1_0_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Phantom_Test_File2_3_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Phantom_Test_File1_8_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Phantom_Test_File2_13_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Phantom_Test_File2_10_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Phantom_Test_File2_16_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Phantom_Test_File2_24_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Phantom_Test_File2_21_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Phantom_Test_File3_4_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Phantom_Test_File1_0_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File3_9_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Phantom_Test_File1_8_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Phantom_Test_File2_3_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File2_10_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Phantom_Test_File2_13_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Phantom_Test_File2_16_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Phantom_Test_File2_21_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Phantom_Test_File2_24_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File2_26_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File3_4_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File1_0_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Phantom_Test_File3_9_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Phantom_Test_File1_8_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File2_3_PS-1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File2_10_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Phantom_Test_File2_13_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Phantom_Test_File2_16_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Phantom_Test_File2_21_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Phantom_Test_File3_4_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Phantom_Test_File2_24_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Phantom_Test_File3_9_PS-1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Phantom_Test_File1_0_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Phantom_Test_File1_8_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Phantom_Test_File2_3_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Phantom_Test_File2_10_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Phantom_Test_File2_13_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Phantom_Test_File2_16_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Phantom_Test_File2_21_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Phantom_Test_File2_24_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File3_4_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Phantom_Test_File3_9_PS+1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File1_0_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File1_8_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Phantom_Test_File2_3_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Phantom_Test_File2_10_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Phantom_Test_File2_13_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Phantom_Test_File2_16_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Phantom_Test_File2_21_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Phantom_Test_File2_24_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Phantom_Test_File3_4_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File3_9_PS+2_mel.png: Phantom
# Unknown Drone Count: 5
# Known Drone Count: 46
