# %%
# !pip install --upgrade keras
# !pip install --upgrade keras tensorflow
import os
import math
import numpy as np
import librosa
import json
import pandas as pd
from termcolor import colored
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
# !pip install tensorboard
# !pip install visualkeras
import visualkeras
from keras.utils import plot_model
from datetime import datetime
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn import svm
from sklearn.svm import SVC
import pickle
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from IPython.display import Audio
from scipy.io import wavfile
import scipy
import soundfile as sf
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras import layers, models
from sklearn.metrics import classification_report
import random
import csv
from keras.callbacks import Callback
from keras.callbacks import CSVLogger
from sklearn.metrics import precision_recall_fscore_support

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting keras
#   Downloading keras-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Collecting namex (from keras)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Collecting optree (from keras)
#   Downloading optree-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Downloading keras-3.4.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.8 MB/s eta 0:00:00
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.7/347.7 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: namex, optree, keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.4.1 which is incompatible.
# Successfully installed keras-3.4.1 namex-0.0.8 optree-0.12.1
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting tensorflow
#   Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Collecting ml-dtypes (from keras)
#   Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow)
#   Downloading tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 2.4 MB/s eta 0:00:00
# Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 43.1 MB/s eta 0:00:00
# Downloading tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 48.4 MB/s eta 0:00:00
# Installing collected packages: ml-dtypes, tensorboard, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.17.0 which is incompatible.
# Successfully installed ml-dtypes-0.4.0 tensorboard-2.17.0 tensorflow-2.17.0
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Collecting visualkeras
#   Downloading visualkeras-0.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.26.4)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (661 bytes)
# Downloading visualkeras-0.1.3-py3-none-any.whl (16 kB)
# Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 18.1 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18.post0 visualkeras-0.1.3
# Mounted at /content/drive

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms_256HL/Train/'
test_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms_256HL/Test/'

num_classes = 7
height = 128
n_fft = 2048
hop_length = 256
sr = 16000
T = 1

hop_size_sec = hop_length / sr
audio_length_samples = T * sr

width = 1 + int((audio_length_samples - n_fft) / hop_length)

channels = 3

train_datagen = ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator()

batch_size = 32

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical')

model = tf.keras.Sequential([
    tf.keras.layers.Reshape((width, height * channels), input_shape=(height, width, channels)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu', return_sequences=True)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu')),  # Existing LSTM layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy', 'precision', 'recall', 'f1_score'])

epochs = 185
metrics_data = []

for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")

    train_generator.reset()

    history = model.fit(
        train_generator,
        steps_per_epoch=len(train_generator),
        epochs=1,
        verbose=1)

    # Get metrics from history
    accuracy = history.history['accuracy'][0]
    precision = history.history['precision'][0]
    recall = history.history['recall'][0]

    f1_score_tensor = history.history['f1_score'][0]
    f1_score_value = np.mean(f1_score_tensor)

    # Store metrics in a list
    metrics_data.append([accuracy, precision, recall, f1_score_value])

# Save metrics to a CSV file
csv_filename = 'training_metrics.csv'

with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Accuracy', 'Precision', 'Recall', 'F1 Score'])
    writer.writerows(metrics_data)

print(f"Training metrics saved to {csv_filename}")

loss, accuracy, precision, recall, f1_score = model.evaluate(test_generator)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test F1 Score:", f1_score)

model.save('al-emadi_rnn_mcc_standardized_unknown_256HL.keras')
# Out:
# Found 3088 images belonging to 7 classes.
# Found 768 images belonging to 7 classes.
# Epoch 1/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 133s 637ms/step - accuracy: 0.2146 - f1_score: 0.1216 - loss: 2.2302 - precision: 0.3000 - recall: 0.0561
# Epoch 2/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 650ms/step - accuracy: 0.3994 - f1_score: 0.1308 - loss: 1.7661 - precision: 0.5280 - recall: 0.1686
# Epoch 3/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 647ms/step - accuracy: 0.4193 - f1_score: 0.1338 - loss: 1.7104 - precision: 0.5614 - recall: 0.1699
# Epoch 4/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 636ms/step - accuracy: 0.4407 - f1_score: 0.1239 - loss: 1.6777 - precision: 0.5770 - recall: 0.1757
# Epoch 5/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 650ms/step - accuracy: 0.4431 - f1_score: 0.1120 - loss: 1.6457 - precision: 0.5349 - recall: 0.1467
# Epoch 6/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 638ms/step - accuracy: 0.4432 - f1_score: 0.0973 - loss: 1.5754 - precision: 0.6005 - recall: 0.1902
# Epoch 7/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 631ms/step - accuracy: 0.4739 - f1_score: 0.1230 - loss: 1.5017 - precision: 0.6555 - recall: 0.2294
# Epoch 8/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 637ms/step - accuracy: 0.4617 - f1_score: 0.1095 - loss: 1.5354 - precision: 0.6189 - recall: 0.1875
# Epoch 9/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 624ms/step - accuracy: 0.4599 - f1_score: 0.1092 - loss: 1.4805 - precision: 0.6372 - recall: 0.2129
# Epoch 10/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 626ms/step - accuracy: 0.4587 - f1_score: 0.1259 - loss: 1.4359 - precision: 0.6657 - recall: 0.2316
# Epoch 11/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 620ms/step - accuracy: 0.4792 - f1_score: 0.1648 - loss: 1.4501 - precision: 0.6445 - recall: 0.2375
# Epoch 12/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 625ms/step - accuracy: 0.4701 - f1_score: 0.1553 - loss: 1.4372 - precision: 0.6501 - recall: 0.2502
# Epoch 13/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 623ms/step - accuracy: 0.4747 - f1_score: 0.1649 - loss: 1.4163 - precision: 0.6397 - recall: 0.2746
# Epoch 14/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 630ms/step - accuracy: 0.4674 - f1_score: 0.2028 - loss: 1.4385 - precision: 0.6650 - recall: 0.2509
# Epoch 15/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 634ms/step - accuracy: 0.4722 - f1_score: 0.1914 - loss: 1.4050 - precision: 0.6739 - recall: 0.2740
# Epoch 16/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 647ms/step - accuracy: 0.4848 - f1_score: 0.2251 - loss: 1.3696 - precision: 0.7038 - recall: 0.2688
# Epoch 17/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 636ms/step - accuracy: 0.4885 - f1_score: 0.2212 - loss: 1.3900 - precision: 0.6942 - recall: 0.2647
# Epoch 18/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 629ms/step - accuracy: 0.5018 - f1_score: 0.2462 - loss: 1.3305 - precision: 0.7189 - recall: 0.2954
# Epoch 19/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 632ms/step - accuracy: 0.5115 - f1_score: 0.2838 - loss: 1.3316 - precision: 0.7042 - recall: 0.3170
# Epoch 20/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 640ms/step - accuracy: 0.5271 - f1_score: 0.3150 - loss: 1.2911 - precision: 0.7235 - recall: 0.3217
# Epoch 21/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 630ms/step - accuracy: 0.5241 - f1_score: 0.3074 - loss: 1.3055 - precision: 0.7233 - recall: 0.3302
# Epoch 22/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 634ms/step - accuracy: 0.5390 - f1_score: 0.3321 - loss: 1.2582 - precision: 0.7199 - recall: 0.3507
# Epoch 23/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.5417 - f1_score: 0.3231 - loss: 1.2284 - precision: 0.7378 - recall: 0.3508
# Epoch 24/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 639ms/step - accuracy: 0.5434 - f1_score: 0.3473 - loss: 1.2618 - precision: 0.7257 - recall: 0.3446
# Epoch 25/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 648ms/step - accuracy: 0.5518 - f1_score: 0.3448 - loss: 1.1969 - precision: 0.7266 - recall: 0.3683
# Epoch 26/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 639ms/step - accuracy: 0.5714 - f1_score: 0.3746 - loss: 1.1508 - precision: 0.7537 - recall: 0.3783
# Epoch 27/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 633ms/step - accuracy: 0.5705 - f1_score: 0.3832 - loss: 1.1401 - precision: 0.7473 - recall: 0.3889
# Epoch 28/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 646ms/step - accuracy: 0.5594 - f1_score: 0.3728 - loss: 1.2008 - precision: 0.7240 - recall: 0.3840
# Epoch 29/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 633ms/step - accuracy: 0.5638 - f1_score: 0.3908 - loss: 1.1612 - precision: 0.7176 - recall: 0.3820
# Epoch 30/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 633ms/step - accuracy: 0.5739 - f1_score: 0.3836 - loss: 1.1320 - precision: 0.7550 - recall: 0.3964
# Epoch 31/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 639ms/step - accuracy: 0.5918 - f1_score: 0.4314 - loss: 1.1008 - precision: 0.7433 - recall: 0.4187
# Epoch 32/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 644ms/step - accuracy: 0.6102 - f1_score: 0.4495 - loss: 1.0493 - precision: 0.7424 - recall: 0.4253
# Epoch 33/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 629ms/step - accuracy: 0.6103 - f1_score: 0.4564 - loss: 1.0269 - precision: 0.7636 - recall: 0.4649
# Epoch 34/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 658ms/step - accuracy: 0.6283 - f1_score: 0.4967 - loss: 0.9990 - precision: 0.7430 - recall: 0.4727
# Epoch 35/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 621ms/step - accuracy: 0.6531 - f1_score: 0.5150 - loss: 0.9159 - precision: 0.7632 - recall: 0.5188
# Epoch 36/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 643ms/step - accuracy: 0.6617 - f1_score: 0.5268 - loss: 0.9120 - precision: 0.7678 - recall: 0.5244
# Epoch 37/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 626ms/step - accuracy: 0.6738 - f1_score: 0.5382 - loss: 0.8963 - precision: 0.7877 - recall: 0.5442
# Epoch 38/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 630ms/step - accuracy: 0.6708 - f1_score: 0.5622 - loss: 0.8634 - precision: 0.7817 - recall: 0.5539
# Epoch 39/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 642ms/step - accuracy: 0.6732 - f1_score: 0.5606 - loss: 0.8596 - precision: 0.7791 - recall: 0.5697
# Epoch 40/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 628ms/step - accuracy: 0.6789 - f1_score: 0.5845 - loss: 0.8766 - precision: 0.7737 - recall: 0.5690
# Epoch 41/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 626ms/step - accuracy: 0.7051 - f1_score: 0.6223 - loss: 0.8230 - precision: 0.7880 - recall: 0.6098
# Epoch 42/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 623ms/step - accuracy: 0.6954 - f1_score: 0.5897 - loss: 0.8152 - precision: 0.7770 - recall: 0.5948
# Epoch 43/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 628ms/step - accuracy: 0.6991 - f1_score: 0.6092 - loss: 0.7740 - precision: 0.7931 - recall: 0.6109
# Epoch 44/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 633ms/step - accuracy: 0.7206 - f1_score: 0.6254 - loss: 0.7631 - precision: 0.8054 - recall: 0.6205
# Epoch 45/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 643ms/step - accuracy: 0.7175 - f1_score: 0.6380 - loss: 0.7644 - precision: 0.8001 - recall: 0.6251
# Epoch 46/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 626ms/step - accuracy: 0.7383 - f1_score: 0.6630 - loss: 0.7286 - precision: 0.8204 - recall: 0.6340
# Epoch 47/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 626ms/step - accuracy: 0.7063 - f1_score: 0.6265 - loss: 0.7693 - precision: 0.7913 - recall: 0.6164
# Epoch 48/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 627ms/step - accuracy: 0.7213 - f1_score: 0.6369 - loss: 0.7484 - precision: 0.7982 - recall: 0.6392
# Epoch 49/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 638ms/step - accuracy: 0.7408 - f1_score: 0.6579 - loss: 0.7321 - precision: 0.8111 - recall: 0.6528
# Epoch 50/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 616ms/step - accuracy: 0.7395 - f1_score: 0.6700 - loss: 0.7010 - precision: 0.8134 - recall: 0.6541
# Epoch 51/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 603ms/step - accuracy: 0.7514 - f1_score: 0.6878 - loss: 0.6969 - precision: 0.8207 - recall: 0.6757
# Epoch 52/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 602ms/step - accuracy: 0.7600 - f1_score: 0.6945 - loss: 0.6637 - precision: 0.8168 - recall: 0.6813
# Epoch 53/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 602ms/step - accuracy: 0.7531 - f1_score: 0.6864 - loss: 0.6873 - precision: 0.8223 - recall: 0.6794
# Epoch 54/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 600ms/step - accuracy: 0.7620 - f1_score: 0.6991 - loss: 0.6553 - precision: 0.8171 - recall: 0.6979
# Epoch 55/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 601ms/step - accuracy: 0.7641 - f1_score: 0.7180 - loss: 0.6462 - precision: 0.8239 - recall: 0.6863
# Epoch 56/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 598ms/step - accuracy: 0.7669 - f1_score: 0.7165 - loss: 0.6230 - precision: 0.8314 - recall: 0.6997
# Epoch 57/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 61s 592ms/step - accuracy: 0.7716 - f1_score: 0.7256 - loss: 0.6124 - precision: 0.8402 - recall: 0.7152
# Epoch 58/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 595ms/step - accuracy: 0.7773 - f1_score: 0.7436 - loss: 0.6125 - precision: 0.8480 - recall: 0.7125
# Epoch 59/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 61s 596ms/step - accuracy: 0.7680 - f1_score: 0.7203 - loss: 0.6240 - precision: 0.8281 - recall: 0.7055
# Epoch 60/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 593ms/step - accuracy: 0.7845 - f1_score: 0.7463 - loss: 0.5888 - precision: 0.8313 - recall: 0.7206
# Epoch 61/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 597ms/step - accuracy: 0.7984 - f1_score: 0.7644 - loss: 0.5687 - precision: 0.8427 - recall: 0.7463
# Epoch 62/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 594ms/step - accuracy: 0.7980 - f1_score: 0.7613 - loss: 0.5616 - precision: 0.8389 - recall: 0.7434
# Epoch 63/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 605ms/step - accuracy: 0.8098 - f1_score: 0.7851 - loss: 0.5327 - precision: 0.8565 - recall: 0.7591
# Epoch 64/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 605ms/step - accuracy: 0.8010 - f1_score: 0.7737 - loss: 0.5378 - precision: 0.8482 - recall: 0.7586
# Epoch 65/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 609ms/step - accuracy: 0.8033 - f1_score: 0.7677 - loss: 0.5424 - precision: 0.8509 - recall: 0.7560
# Epoch 66/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 602ms/step - accuracy: 0.8088 - f1_score: 0.7834 - loss: 0.5509 - precision: 0.8461 - recall: 0.7563
# Epoch 67/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 606ms/step - accuracy: 0.8186 - f1_score: 0.7870 - loss: 0.5238 - precision: 0.8618 - recall: 0.7644
# Epoch 68/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 612ms/step - accuracy: 0.8204 - f1_score: 0.7914 - loss: 0.5349 - precision: 0.8596 - recall: 0.7748
# Epoch 69/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 606ms/step - accuracy: 0.8120 - f1_score: 0.7877 - loss: 0.4872 - precision: 0.8624 - recall: 0.7772
# Epoch 70/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 632ms/step - accuracy: 0.8200 - f1_score: 0.8023 - loss: 0.5026 - precision: 0.8639 - recall: 0.7797
# Epoch 71/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 614ms/step - accuracy: 0.8391 - f1_score: 0.8207 - loss: 0.4592 - precision: 0.8770 - recall: 0.8019
# Epoch 72/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 608ms/step - accuracy: 0.8242 - f1_score: 0.8009 - loss: 0.4924 - precision: 0.8632 - recall: 0.7865
# Epoch 73/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 597ms/step - accuracy: 0.8305 - f1_score: 0.8182 - loss: 0.4616 - precision: 0.8662 - recall: 0.7970
# Epoch 74/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 608ms/step - accuracy: 0.8534 - f1_score: 0.8396 - loss: 0.4241 - precision: 0.8799 - recall: 0.8232
# Epoch 75/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 607ms/step - accuracy: 0.8477 - f1_score: 0.8263 - loss: 0.4475 - precision: 0.8795 - recall: 0.8086
# Epoch 76/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 606ms/step - accuracy: 0.8352 - f1_score: 0.8164 - loss: 0.4489 - precision: 0.8689 - recall: 0.8111
# Epoch 77/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 605ms/step - accuracy: 0.8513 - f1_score: 0.8365 - loss: 0.4359 - precision: 0.8811 - recall: 0.8161
# Epoch 78/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 613ms/step - accuracy: 0.8435 - f1_score: 0.8257 - loss: 0.4430 - precision: 0.8729 - recall: 0.8117
# Epoch 79/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 614ms/step - accuracy: 0.8577 - f1_score: 0.8390 - loss: 0.4043 - precision: 0.8855 - recall: 0.8271
# Epoch 80/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 599ms/step - accuracy: 0.8643 - f1_score: 0.8590 - loss: 0.3822 - precision: 0.8959 - recall: 0.8294
# Epoch 81/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 616ms/step - accuracy: 0.8388 - f1_score: 0.8253 - loss: 0.4365 - precision: 0.8660 - recall: 0.8095
# Epoch 82/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 609ms/step - accuracy: 0.8524 - f1_score: 0.8420 - loss: 0.4041 - precision: 0.8752 - recall: 0.8324
# Epoch 83/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 620ms/step - accuracy: 0.8636 - f1_score: 0.8513 - loss: 0.3867 - precision: 0.8921 - recall: 0.8368
# Epoch 84/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 608ms/step - accuracy: 0.8547 - f1_score: 0.8379 - loss: 0.3873 - precision: 0.8839 - recall: 0.8291
# Epoch 85/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 605ms/step - accuracy: 0.8574 - f1_score: 0.8504 - loss: 0.3842 - precision: 0.8916 - recall: 0.8331
# Epoch 86/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 626ms/step - accuracy: 0.8734 - f1_score: 0.8643 - loss: 0.3751 - precision: 0.8960 - recall: 0.8410
# Epoch 87/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 603ms/step - accuracy: 0.8577 - f1_score: 0.8430 - loss: 0.3731 - precision: 0.8872 - recall: 0.8343
# Epoch 88/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 616ms/step - accuracy: 0.8643 - f1_score: 0.8514 - loss: 0.3775 - precision: 0.8953 - recall: 0.8395
# Epoch 89/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 613ms/step - accuracy: 0.8599 - f1_score: 0.8516 - loss: 0.3861 - precision: 0.8887 - recall: 0.8263
# Epoch 90/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 612ms/step - accuracy: 0.8769 - f1_score: 0.8690 - loss: 0.3485 - precision: 0.9002 - recall: 0.8548
# Epoch 91/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 609ms/step - accuracy: 0.8584 - f1_score: 0.8370 - loss: 0.3952 - precision: 0.8868 - recall: 0.8268
# Epoch 92/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 619ms/step - accuracy: 0.8691 - f1_score: 0.8529 - loss: 0.3741 - precision: 0.8985 - recall: 0.8385
# Epoch 93/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 609ms/step - accuracy: 0.8720 - f1_score: 0.8538 - loss: 0.3624 - precision: 0.8933 - recall: 0.8358
# Epoch 94/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 606ms/step - accuracy: 0.8779 - f1_score: 0.8690 - loss: 0.3386 - precision: 0.9039 - recall: 0.8566
# Epoch 95/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 613ms/step - accuracy: 0.8557 - f1_score: 0.8383 - loss: 0.3935 - precision: 0.8889 - recall: 0.8332
# Epoch 96/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 618ms/step - accuracy: 0.8837 - f1_score: 0.8686 - loss: 0.3342 - precision: 0.9034 - recall: 0.8522
# Epoch 97/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 642ms/step - accuracy: 0.8661 - f1_score: 0.8525 - loss: 0.3797 - precision: 0.8926 - recall: 0.8415
# Epoch 98/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 616ms/step - accuracy: 0.8555 - f1_score: 0.8368 - loss: 0.4198 - precision: 0.8803 - recall: 0.8304
# Epoch 99/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 622ms/step - accuracy: 0.7318 - f1_score: 0.6608 - loss: 0.9222 - precision: 0.7858 - recall: 0.6763
# Epoch 100/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 643ms/step - accuracy: 0.8073 - f1_score: 0.7716 - loss: 0.5073 - precision: 0.8615 - recall: 0.7534
# Epoch 101/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 608ms/step - accuracy: 0.8394 - f1_score: 0.8254 - loss: 0.4421 - precision: 0.8868 - recall: 0.7993
# Epoch 102/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 621ms/step - accuracy: 0.8470 - f1_score: 0.8260 - loss: 0.4399 - precision: 0.8833 - recall: 0.8106
# Epoch 103/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 605ms/step - accuracy: 0.8540 - f1_score: 0.8409 - loss: 0.4002 - precision: 0.8969 - recall: 0.8218
# Epoch 104/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 629ms/step - accuracy: 0.8697 - f1_score: 0.8577 - loss: 0.3557 - precision: 0.8955 - recall: 0.8419
# Epoch 105/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 613ms/step - accuracy: 0.8682 - f1_score: 0.8537 - loss: 0.3567 - precision: 0.9041 - recall: 0.8371
# Epoch 106/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 614ms/step - accuracy: 0.8602 - f1_score: 0.8491 - loss: 0.3765 - precision: 0.8883 - recall: 0.8365
# Epoch 107/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 639ms/step - accuracy: 0.8687 - f1_score: 0.8490 - loss: 0.3722 - precision: 0.8908 - recall: 0.8344
# Epoch 108/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 625ms/step - accuracy: 0.8716 - f1_score: 0.8637 - loss: 0.3526 - precision: 0.8986 - recall: 0.8401
# Epoch 109/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 624ms/step - accuracy: 0.8697 - f1_score: 0.8598 - loss: 0.3460 - precision: 0.8976 - recall: 0.8460
# Epoch 110/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 624ms/step - accuracy: 0.8626 - f1_score: 0.8444 - loss: 0.3700 - precision: 0.9033 - recall: 0.8447
# Epoch 111/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 631ms/step - accuracy: 0.8724 - f1_score: 0.8640 - loss: 0.3390 - precision: 0.9049 - recall: 0.8463
# Epoch 112/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 628ms/step - accuracy: 0.8803 - f1_score: 0.8723 - loss: 0.3116 - precision: 0.9115 - recall: 0.8542
# Epoch 113/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 622ms/step - accuracy: 0.8379 - f1_score: 0.8151 - loss: 0.4496 - precision: 0.8731 - recall: 0.8126
# Epoch 114/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 638ms/step - accuracy: 0.8612 - f1_score: 0.8364 - loss: 0.4085 - precision: 0.8898 - recall: 0.8298
# Epoch 115/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 637ms/step - accuracy: 0.8557 - f1_score: 0.8429 - loss: 0.3975 - precision: 0.8847 - recall: 0.8213
# Epoch 116/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 630ms/step - accuracy: 0.8846 - f1_score: 0.8831 - loss: 0.3302 - precision: 0.9145 - recall: 0.8527
# Epoch 117/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 639ms/step - accuracy: 0.8823 - f1_score: 0.8728 - loss: 0.3278 - precision: 0.9088 - recall: 0.8541
# Epoch 118/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 611ms/step - accuracy: 0.8811 - f1_score: 0.8683 - loss: 0.3651 - precision: 0.9047 - recall: 0.8557
# Epoch 119/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 624ms/step - accuracy: 0.8852 - f1_score: 0.8767 - loss: 0.3337 - precision: 0.9154 - recall: 0.8527
# Epoch 120/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 633ms/step - accuracy: 0.8644 - f1_score: 0.8615 - loss: 0.3564 - precision: 0.8914 - recall: 0.8405
# Epoch 121/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 630ms/step - accuracy: 0.8876 - f1_score: 0.8836 - loss: 0.3109 - precision: 0.9132 - recall: 0.8695
# Epoch 122/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 617ms/step - accuracy: 0.8494 - f1_score: 0.8270 - loss: 0.4238 - precision: 0.8859 - recall: 0.8186
# Epoch 123/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 622ms/step - accuracy: 0.8667 - f1_score: 0.8523 - loss: 0.3822 - precision: 0.8911 - recall: 0.8444
# Epoch 124/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 647ms/step - accuracy: 0.8918 - f1_score: 0.8883 - loss: 0.2962 - precision: 0.9212 - recall: 0.8693
# Epoch 125/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 624ms/step - accuracy: 0.8903 - f1_score: 0.8768 - loss: 0.2813 - precision: 0.9136 - recall: 0.8681
# Epoch 126/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.8952 - f1_score: 0.8900 - loss: 0.2865 - precision: 0.9128 - recall: 0.8674
# Epoch 127/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 626ms/step - accuracy: 0.8879 - f1_score: 0.8794 - loss: 0.3066 - precision: 0.9140 - recall: 0.8651
# Epoch 128/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 637ms/step - accuracy: 0.8871 - f1_score: 0.8809 - loss: 0.2934 - precision: 0.9137 - recall: 0.8678
# Epoch 129/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 634ms/step - accuracy: 0.8889 - f1_score: 0.8842 - loss: 0.3155 - precision: 0.9159 - recall: 0.8698
# Epoch 130/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 632ms/step - accuracy: 0.8916 - f1_score: 0.8936 - loss: 0.2989 - precision: 0.9133 - recall: 0.8740
# Epoch 131/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 633ms/step - accuracy: 0.8980 - f1_score: 0.8990 - loss: 0.2912 - precision: 0.9150 - recall: 0.8845
# Epoch 132/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 625ms/step - accuracy: 0.8972 - f1_score: 0.8840 - loss: 0.2887 - precision: 0.9151 - recall: 0.8763
# Epoch 133/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 621ms/step - accuracy: 0.8976 - f1_score: 0.8909 - loss: 0.2670 - precision: 0.9202 - recall: 0.8825
# Epoch 134/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 627ms/step - accuracy: 0.8991 - f1_score: 0.8978 - loss: 0.2793 - precision: 0.9177 - recall: 0.8750
# Epoch 135/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 622ms/step - accuracy: 0.8881 - f1_score: 0.8884 - loss: 0.2948 - precision: 0.9131 - recall: 0.8684
# Epoch 136/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 614ms/step - accuracy: 0.9123 - f1_score: 0.9090 - loss: 0.2435 - precision: 0.9315 - recall: 0.8955
# Epoch 137/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 613ms/step - accuracy: 0.9060 - f1_score: 0.8989 - loss: 0.2789 - precision: 0.9244 - recall: 0.8885
# Epoch 138/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 643ms/step - accuracy: 0.8890 - f1_score: 0.8892 - loss: 0.2762 - precision: 0.9170 - recall: 0.8738
# Epoch 139/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 618ms/step - accuracy: 0.9042 - f1_score: 0.9058 - loss: 0.2870 - precision: 0.9189 - recall: 0.8850
# Epoch 140/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 614ms/step - accuracy: 0.9111 - f1_score: 0.9072 - loss: 0.2569 - precision: 0.9244 - recall: 0.8919
# Epoch 141/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 83s 807ms/step - accuracy: 0.8976 - f1_score: 0.8972 - loss: 0.2717 - precision: 0.9217 - recall: 0.8796
# Epoch 142/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 611ms/step - accuracy: 0.9067 - f1_score: 0.9010 - loss: 0.2521 - precision: 0.9263 - recall: 0.8861
# Epoch 143/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 611ms/step - accuracy: 0.9051 - f1_score: 0.9030 - loss: 0.2743 - precision: 0.9211 - recall: 0.8866
# Epoch 144/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 614ms/step - accuracy: 0.9062 - f1_score: 0.9069 - loss: 0.2466 - precision: 0.9256 - recall: 0.8871
# Epoch 145/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 612ms/step - accuracy: 0.8920 - f1_score: 0.9031 - loss: 0.2655 - precision: 0.9151 - recall: 0.8764
# Epoch 146/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 617ms/step - accuracy: 0.9190 - f1_score: 0.9251 - loss: 0.2234 - precision: 0.9346 - recall: 0.9032
# Epoch 147/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 631ms/step - accuracy: 0.9023 - f1_score: 0.9043 - loss: 0.2630 - precision: 0.9267 - recall: 0.8812
# Epoch 148/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 616ms/step - accuracy: 0.9034 - f1_score: 0.9013 - loss: 0.2441 - precision: 0.9240 - recall: 0.8854
# Epoch 149/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 614ms/step - accuracy: 0.9180 - f1_score: 0.9169 - loss: 0.2284 - precision: 0.9353 - recall: 0.9037
# Epoch 150/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 633ms/step - accuracy: 0.9135 - f1_score: 0.9155 - loss: 0.2469 - precision: 0.9312 - recall: 0.8930
# Epoch 151/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 616ms/step - accuracy: 0.9189 - f1_score: 0.9196 - loss: 0.2240 - precision: 0.9347 - recall: 0.9057
# Epoch 152/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 620ms/step - accuracy: 0.9072 - f1_score: 0.9066 - loss: 0.2464 - precision: 0.9248 - recall: 0.8897
# Epoch 153/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 632ms/step - accuracy: 0.9117 - f1_score: 0.9150 - loss: 0.2314 - precision: 0.9269 - recall: 0.8965
# Epoch 154/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 623ms/step - accuracy: 0.9138 - f1_score: 0.9092 - loss: 0.2284 - precision: 0.9352 - recall: 0.9025
# Epoch 155/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 621ms/step - accuracy: 0.9228 - f1_score: 0.9245 - loss: 0.2101 - precision: 0.9405 - recall: 0.9065
# Epoch 156/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 631ms/step - accuracy: 0.9115 - f1_score: 0.9135 - loss: 0.2391 - precision: 0.9259 - recall: 0.8994
# Epoch 157/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 622ms/step - accuracy: 0.9269 - f1_score: 0.9314 - loss: 0.2090 - precision: 0.9398 - recall: 0.9147
# Epoch 158/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 611ms/step - accuracy: 0.9224 - f1_score: 0.9259 - loss: 0.2081 - precision: 0.9406 - recall: 0.9076
# Epoch 159/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 618ms/step - accuracy: 0.9086 - f1_score: 0.9132 - loss: 0.2542 - precision: 0.9226 - recall: 0.8921
# Epoch 160/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 621ms/step - accuracy: 0.9316 - f1_score: 0.9290 - loss: 0.1980 - precision: 0.9427 - recall: 0.9153
# Epoch 161/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 614ms/step - accuracy: 0.9120 - f1_score: 0.9113 - loss: 0.2207 - precision: 0.9281 - recall: 0.8931
# Epoch 162/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 611ms/step - accuracy: 0.9306 - f1_score: 0.9343 - loss: 0.1975 - precision: 0.9401 - recall: 0.9114
# Epoch 163/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 611ms/step - accuracy: 0.9278 - f1_score: 0.9307 - loss: 0.2112 - precision: 0.9364 - recall: 0.9157
# Epoch 164/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 612ms/step - accuracy: 0.9210 - f1_score: 0.9233 - loss: 0.2206 - precision: 0.9368 - recall: 0.9082
# Epoch 165/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 617ms/step - accuracy: 0.9238 - f1_score: 0.9262 - loss: 0.1976 - precision: 0.9446 - recall: 0.9102
# Epoch 166/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 620ms/step - accuracy: 0.9257 - f1_score: 0.9308 - loss: 0.2161 - precision: 0.9417 - recall: 0.9119
# Epoch 167/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 608ms/step - accuracy: 0.9152 - f1_score: 0.9160 - loss: 0.2310 - precision: 0.9398 - recall: 0.9007
# Epoch 168/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 634ms/step - accuracy: 0.9245 - f1_score: 0.9251 - loss: 0.2012 - precision: 0.9421 - recall: 0.9118
# Epoch 169/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 609ms/step - accuracy: 0.9189 - f1_score: 0.9244 - loss: 0.2158 - precision: 0.9367 - recall: 0.9059
# Epoch 170/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 611ms/step - accuracy: 0.9324 - f1_score: 0.9378 - loss: 0.1900 - precision: 0.9421 - recall: 0.9209
# Epoch 171/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 632ms/step - accuracy: 0.9311 - f1_score: 0.9331 - loss: 0.1994 - precision: 0.9396 - recall: 0.9213
# Epoch 172/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 607ms/step - accuracy: 0.9345 - f1_score: 0.9372 - loss: 0.1964 - precision: 0.9461 - recall: 0.9240
# Epoch 173/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 607ms/step - accuracy: 0.9373 - f1_score: 0.9407 - loss: 0.1781 - precision: 0.9474 - recall: 0.9269
# Epoch 174/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 608ms/step - accuracy: 0.9215 - f1_score: 0.9284 - loss: 0.1998 - precision: 0.9378 - recall: 0.9145
# Epoch 175/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 609ms/step - accuracy: 0.9295 - f1_score: 0.9347 - loss: 0.1902 - precision: 0.9446 - recall: 0.9120
# Epoch 176/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 613ms/step - accuracy: 0.9279 - f1_score: 0.9325 - loss: 0.1941 - precision: 0.9385 - recall: 0.9173
# Epoch 177/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 609ms/step - accuracy: 0.9309 - f1_score: 0.9261 - loss: 0.1836 - precision: 0.9452 - recall: 0.9225
# Epoch 178/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 626ms/step - accuracy: 0.9324 - f1_score: 0.9357 - loss: 0.1939 - precision: 0.9393 - recall: 0.9136
# Epoch 179/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 62s 605ms/step - accuracy: 0.9300 - f1_score: 0.9353 - loss: 0.1921 - precision: 0.9450 - recall: 0.9179
# Epoch 180/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 613ms/step - accuracy: 0.9356 - f1_score: 0.9401 - loss: 0.1747 - precision: 0.9494 - recall: 0.9270
# Epoch 181/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 620ms/step - accuracy: 0.9213 - f1_score: 0.9220 - loss: 0.2111 - precision: 0.9377 - recall: 0.9098
# Epoch 182/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 63s 614ms/step - accuracy: 0.9251 - f1_score: 0.9326 - loss: 0.1929 - precision: 0.9415 - recall: 0.9143
# Epoch 183/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 625ms/step - accuracy: 0.9334 - f1_score: 0.9318 - loss: 0.1792 - precision: 0.9400 - recall: 0.9220
# Epoch 184/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 626ms/step - accuracy: 0.9282 - f1_score: 0.9315 - loss: 0.1848 - precision: 0.9473 - recall: 0.9206
# Epoch 185/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 618ms/step - accuracy: 0.9321 - f1_score: 0.9357 - loss: 0.1946 - precision: 0.9489 - recall: 0.9209
# Training metrics saved to training_metrics.csv
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 247s 11s/step - accuracy: 0.9044 - f1_score: 0.9255 - loss: 0.2853 - precision: 0.9050 - recall: 0.8853
# Test Loss: 0.2892411947250366
# Test Accuracy: 0.90234375
# Test Precision: 0.9066666960716248
# Test Recall: 0.8854166865348816
# Test F1 Score: tf.Tensor([0.8744588 1.        0.7454545 0.9708737 0.9803921 0.9125926 0.9900989], shape=(7,), dtype=float32)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator

num_classes = 7
height = 128
n_fft = 2048
hop_length = 256
sr = 16000
T = 1

hop_size_sec = hop_length / sr
audio_length_samples = T * sr

width = 1 + int((audio_length_samples - n_fft) / hop_length)

channels = 3

batch_size = 32

model = tf.keras.models.load_model('al-emadi_rnn_mcc_standardized_unknown_256HL.keras')

test_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms_256HL/Test/'

test_datagen = ImageDataGenerator()

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

loss, accuracy, precision, recall, f1_score = model.evaluate(test_generator)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test F1 Score:", f1_score)

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true class labels
true_classes = test_generator.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)
print("\nConfusion Matrix:")
print(conf_matrix)

# Get class labels
class_labels = list(test_generator.class_indices.keys())

# Calculate accuracy for each class
class_accuracy = {}
for i, class_label in enumerate(class_labels):
    correct_indices = np.where(true_classes == i)[0]
    correct_predictions = np.sum(predicted_classes[correct_indices] == i)
    total_samples = len(correct_indices)
    class_accuracy[class_label] = correct_predictions / total_samples if total_samples > 0 else 0.0

# Print accuracy for each class
print("\nAccuracy for each class:")
for class_label in class_labels:
    print(f"{class_label}: {class_accuracy[class_label]:.4f}")

# Print classification report (includes precision, recall, F1-score)
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# Found 768 images belonging to 7 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 17s 522ms/step - accuracy: 0.9316 - f1_score: 0.6329 - loss: 0.2392 - precision: 0.9338 - recall: 0.9135
# Test Loss: 0.2892412543296814
# Test Accuracy: 0.90234375
# Test Precision: 0.9066666960716248
# Test Recall: 0.8854166865348816
# Test F1 Score: tf.Tensor([0.8744588 1.        0.7454545 0.9708737 0.9803921 0.9125926 0.9900989], shape=(7,), dtype=float32)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 464ms/step
#
# Confusion Matrix:
# [[101   0   2   0   0   1   0]
#  [  0  52   0   0   0   0   0]
#  [ 13   0  82   0   0   9   0]
#  [  0   0   0  50   0   0   0]
#  [  0   0   0   0  50   0   0]
#  [ 13   0  32   3   1 308   0]
#  [  0   0   0   0   1   0  50]]
#
# Accuracy for each class:
# Bebop: 0.9712
# Crazyflie: 1.0000
# Mambo: 0.7885
# Matrice100: 1.0000
# Mavic: 1.0000
# NonDrone: 0.8627
# Phantom: 0.9804
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Bebop       0.80      0.97      0.87       104
#    Crazyflie       1.00      1.00      1.00        52
#        Mambo       0.71      0.79      0.75       104
#   Matrice100       0.94      1.00      0.97        50
#        Mavic       0.96      1.00      0.98        50
#     NonDrone       0.97      0.86      0.91       357
#      Phantom       1.00      0.98      0.99        51
#
#     accuracy                           0.90       768
#    macro avg       0.91      0.94      0.92       768
# weighted avg       0.91      0.90      0.90       768

# %%
import os
import numpy as np
from scipy.stats import entropy
from tensorflow.keras.preprocessing import image

model = tf.keras.models.load_model('/content/al-emadi_rnn_mcc_standardized_unknown_256HL.keras')
classes = ['Bebop', 'Crazyflie', 'Mambo', 'Matrice100', 'Mavic', 'NonDrone', 'Phantom']

known_counter = 0
unknown_counter = 0

def load_spectrogram(file_path):
    # Load and preprocess the image
    num_classes = 7
    height = 128
    n_fft = 2048
    hop_length = 256
    sr = 16000
    T = 1

    hop_size_sec = hop_length / sr
    audio_length_samples = T * sr

    width = 1 + int((audio_length_samples - n_fft) / hop_length)

    channels = 3

    img = image.load_img(file_path, target_size=(height, width))  # Assuming input size expected by your model
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    #img_array = img_array / 255.0  # Normalize pixel values to [0, 1]
    return img_array

# Function to classify a single spectrogram
def classify_spectrogram(spectrogram, entropy_threshold):
    global known_counter
    global unknown_counter

    probabilities = model.predict(spectrogram)[0]  # Get class probabilities from the model
    ent = entropy(probabilities, base=2)  # Calculate entropy of the probability distribution

    if ent > entropy_threshold:
        unknown_counter+=1
        return "UnknownDrone"
    else:
        known_counter+=1
        max_index = np.argmax(probabilities)  # Get the index of the maximum probability
        return classes[max_index]  # Return the corresponding drone class

# Directory containing spectrogram files
unknown_spectrogram_dir = '/content/drive/MyDrive/UnknownDrone_256HL/'
spectrogram_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms_256HL/Test/Phantom/'

# VALUE UP = UNKNOWN DRONE DECREASE | VALUE DOWN = UNKNOWN DRONE INCREASE
entropy_threshold =  0.0003 # Adjust this threshold based on your model and validation results

# List all files in the directory
spectrogram_files = os.listdir(spectrogram_dir)

# Process each spectrogram file
for filename in spectrogram_files:
    if filename.endswith('.png'):  # Assuming spectrograms are saved as PNG files
        # Load the spectrogram (you need to implement this part based on your data loading method)
        spectrogram = load_spectrogram(os.path.join(spectrogram_dir, filename))

        # Classify the spectrogram
        predicted_class = classify_spectrogram(spectrogram, entropy_threshold)

        # Print the filename and predicted class
        print(f"{filename}: {predicted_class}")

print("Unknown Drone Count:", unknown_counter)
print("Known Drone Count:", known_counter)
print("Accuracy:", known_counter/(known_counter+unknown_counter))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 682ms/step
# Phantom_Test_File1_0_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Phantom_Test_File1_8_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Phantom_Test_File2_3_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Phantom_Test_File2_10_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Phantom_Test_File2_13_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Phantom_Test_File2_16_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Phantom_Test_File2_21_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Phantom_Test_File2_24_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File3_4_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Phantom_Test_File3_9_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File1_0_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Phantom_Test_File1_8_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Phantom_Test_File2_3_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Phantom_Test_File2_10_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Phantom_Test_File2_13_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Phantom_Test_File2_16_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Phantom_Test_File2_21_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Phantom_Test_File2_24_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File2_26_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Phantom_Test_File3_4_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File3_9_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Phantom_Test_File1_0_PS-1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Phantom_Test_File1_8_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Phantom_Test_File2_3_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Phantom_Test_File2_10_PS-1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Phantom_Test_File2_13_PS-1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Phantom_Test_File2_16_PS-1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Phantom_Test_File2_21_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Phantom_Test_File2_24_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File3_4_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Phantom_Test_File3_9_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File1_0_PS+1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File1_8_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Phantom_Test_File2_3_PS+1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Phantom_Test_File2_10_PS+1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Phantom_Test_File2_13_PS+1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Phantom_Test_File2_16_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File2_21_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Phantom_Test_File2_24_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Phantom_Test_File3_4_PS+1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Phantom_Test_File3_9_PS+1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Phantom_Test_File1_0_PS+2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Phantom_Test_File1_8_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Phantom_Test_File2_3_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Phantom_Test_File2_10_PS+2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Phantom_Test_File2_13_PS+2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Phantom_Test_File2_16_PS+2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Phantom_Test_File2_21_PS+2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Phantom_Test_File2_24_PS+2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Phantom_Test_File3_4_PS+2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Phantom_Test_File3_9_PS+2_mel.png: Phantom
# Unknown Drone Count: 31
# Known Drone Count: 20
# Accuracy: 0.39215686274509803
