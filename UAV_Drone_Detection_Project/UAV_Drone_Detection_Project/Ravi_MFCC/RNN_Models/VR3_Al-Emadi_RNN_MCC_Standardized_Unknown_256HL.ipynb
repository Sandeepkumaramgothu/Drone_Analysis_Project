# %%
# !pip install --upgrade keras
# !pip install --upgrade keras tensorflow
import os
import math
import numpy as np
import librosa
import json
import pandas as pd
from termcolor import colored
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
# !pip install tensorboard
# !pip install visualkeras
import visualkeras
from keras.utils import plot_model
from datetime import datetime
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn import svm
from sklearn.svm import SVC
import pickle
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from IPython.display import Audio
from scipy.io import wavfile
import scipy
import soundfile as sf
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras import layers, models
from sklearn.metrics import classification_report
import random
import csv
from keras.callbacks import Callback
from keras.callbacks import CSVLogger
from sklearn.metrics import precision_recall_fscore_support

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting keras
#   Downloading keras-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Collecting namex (from keras)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.9.0)
# Collecting optree (from keras)
#   Downloading optree-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 758.1 kB/s eta 0:00:00
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Downloading keras-3.4.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.6 MB/s eta 0:00:00
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.7/347.7 kB 12.3 MB/s eta 0:00:00
# Installing collected packages: namex, optree, keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.4.1 which is incompatible.
# Successfully installed keras-3.4.1 namex-0.0.8 optree-0.12.1
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting tensorflow
#   Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.9.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Collecting h5py (from keras)
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Collecting ml-dtypes (from keras)
#   Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow)
#   Downloading tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Downloading tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 929.7 kB/s eta 0:00:00
# Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 1.7 MB/s eta 0:00:00
# Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.0 MB/s eta 0:00:00
# Downloading tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 1.7 MB/s eta 0:00:00
# Installing collected packages: ml-dtypes, h5py, tensorboard, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.17.0 which is incompatible.
# Successfully installed h5py-3.11.0 ml-dtypes-0.4.0 tensorboard-2.17.0 tensorflow-2.17.0
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.25.2)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Collecting visualkeras
#   Downloading visualkeras-0.1.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.25.2)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (661 bytes)
# Downloading visualkeras-0.1.2-py3-none-any.whl (16 kB)
# Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18.post0 visualkeras-0.1.2
# Mounted at /content/drive

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms_256HL/Train/'
test_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms_256HL/Test/'

num_classes = 7
height = 128
n_fft = 2048
hop_length = 256
sr = 16000
T = 1

hop_size_sec = hop_length / sr
audio_length_samples = T * sr

width = 1 + int((audio_length_samples - n_fft) / hop_length)

channels = 3

train_datagen = ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator()

batch_size = 32

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical')

model = tf.keras.Sequential([
    tf.keras.layers.Reshape((width, height * channels), input_shape=(height, width, channels)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu', return_sequences=True)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, activation='relu')),  # Existing LSTM layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy', 'precision', 'recall', 'f1_score'])

epochs = 185
metrics_data = []

for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")

    train_generator.reset()

    history = model.fit(
        train_generator,
        steps_per_epoch=len(train_generator),
        epochs=1,
        verbose=1)

    # Get metrics from history
    accuracy = history.history['accuracy'][0]
    precision = history.history['precision'][0]
    recall = history.history['recall'][0]

    f1_score_tensor = history.history['f1_score'][0]
    f1_score_value = np.mean(f1_score_tensor)

    # Store metrics in a list
    metrics_data.append([accuracy, precision, recall, f1_score_value])

# Save metrics to a CSV file
csv_filename = 'training_metrics.csv'

with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Accuracy', 'Precision', 'Recall', 'F1 Score'])
    writer.writerows(metrics_data)

print(f"Training metrics saved to {csv_filename}")

loss, accuracy, precision, recall, f1_score = model.evaluate(test_generator)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test F1 Score:", f1_score)

model.save('al-emadi_rnn_mcc_standardized_unknown_256HL.keras')
# Out:
# Found 3088 images belonging to 7 classes.
# Found 768 images belonging to 7 classes.
# Epoch 1/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 136s 657ms/step - accuracy: 0.2362 - f1_score: 0.1432 - loss: 2.0988 - precision: 0.2776 - recall: 0.0559
# Epoch 2/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 646ms/step - accuracy: 0.4221 - f1_score: 0.1622 - loss: 1.6544 - precision: 0.5978 - recall: 0.1640
# Epoch 3/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 650ms/step - accuracy: 0.4468 - f1_score: 0.1669 - loss: 1.5481 - precision: 0.6182 - recall: 0.2250
# Epoch 4/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 661ms/step - accuracy: 0.4857 - f1_score: 0.2176 - loss: 1.4252 - precision: 0.6391 - recall: 0.2572
# Epoch 5/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 665ms/step - accuracy: 0.4682 - f1_score: 0.2232 - loss: 1.4383 - precision: 0.6599 - recall: 0.2504
# Epoch 6/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 653ms/step - accuracy: 0.5087 - f1_score: 0.2847 - loss: 1.3332 - precision: 0.6702 - recall: 0.3000
# Epoch 7/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 654ms/step - accuracy: 0.5000 - f1_score: 0.2760 - loss: 1.3962 - precision: 0.6470 - recall: 0.2949
# Epoch 8/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 667ms/step - accuracy: 0.5486 - f1_score: 0.3447 - loss: 1.2243 - precision: 0.7131 - recall: 0.3568
# Epoch 9/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 660ms/step - accuracy: 0.5623 - f1_score: 0.3891 - loss: 1.1905 - precision: 0.6909 - recall: 0.3762
# Epoch 10/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 645ms/step - accuracy: 0.6093 - f1_score: 0.4132 - loss: 1.0869 - precision: 0.7480 - recall: 0.4348
# Epoch 11/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 659ms/step - accuracy: 0.5948 - f1_score: 0.4207 - loss: 1.0973 - precision: 0.7204 - recall: 0.4444
# Epoch 12/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 646ms/step - accuracy: 0.5447 - f1_score: 0.3678 - loss: 1.2293 - precision: 0.6737 - recall: 0.3699
# Epoch 13/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 645ms/step - accuracy: 0.5820 - f1_score: 0.4186 - loss: 1.1341 - precision: 0.6985 - recall: 0.4299
# Epoch 14/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 657ms/step - accuracy: 0.6115 - f1_score: 0.4340 - loss: 1.0591 - precision: 0.7460 - recall: 0.4708
# Epoch 15/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 643ms/step - accuracy: 0.6240 - f1_score: 0.4639 - loss: 1.0217 - precision: 0.7635 - recall: 0.4906
# Epoch 16/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.6318 - f1_score: 0.4801 - loss: 1.0108 - precision: 0.7471 - recall: 0.5062
# Epoch 17/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 643ms/step - accuracy: 0.6537 - f1_score: 0.4962 - loss: 0.9353 - precision: 0.7718 - recall: 0.5442
# Epoch 18/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 649ms/step - accuracy: 0.6694 - f1_score: 0.5348 - loss: 0.9045 - precision: 0.7858 - recall: 0.5585
# Epoch 19/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 643ms/step - accuracy: 0.6494 - f1_score: 0.5139 - loss: 0.9090 - precision: 0.7561 - recall: 0.5450
# Epoch 20/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 647ms/step - accuracy: 0.6625 - f1_score: 0.5357 - loss: 0.9319 - precision: 0.7661 - recall: 0.5399
# Epoch 21/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 659ms/step - accuracy: 0.6761 - f1_score: 0.5475 - loss: 0.8801 - precision: 0.7846 - recall: 0.5803
# Epoch 22/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 645ms/step - accuracy: 0.6788 - f1_score: 0.5503 - loss: 0.9146 - precision: 0.7837 - recall: 0.5650
# Epoch 23/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 652ms/step - accuracy: 0.7009 - f1_score: 0.5671 - loss: 0.8473 - precision: 0.7907 - recall: 0.5849
# Epoch 24/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 650ms/step - accuracy: 0.6963 - f1_score: 0.5846 - loss: 0.8253 - precision: 0.7950 - recall: 0.5862
# Epoch 25/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.6961 - f1_score: 0.5654 - loss: 0.8532 - precision: 0.7973 - recall: 0.5918
# Epoch 26/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 642ms/step - accuracy: 0.7031 - f1_score: 0.5866 - loss: 0.8096 - precision: 0.7989 - recall: 0.6071
# Epoch 27/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 650ms/step - accuracy: 0.7042 - f1_score: 0.5867 - loss: 0.8221 - precision: 0.8033 - recall: 0.6045
# Epoch 28/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 655ms/step - accuracy: 0.6906 - f1_score: 0.5704 - loss: 0.8212 - precision: 0.7957 - recall: 0.5950
# Epoch 29/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 653ms/step - accuracy: 0.6975 - f1_score: 0.5844 - loss: 0.7906 - precision: 0.8050 - recall: 0.6065
# Epoch 30/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 661ms/step - accuracy: 0.7094 - f1_score: 0.5966 - loss: 0.7744 - precision: 0.8069 - recall: 0.6232
# Epoch 31/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 649ms/step - accuracy: 0.7212 - f1_score: 0.5958 - loss: 0.7428 - precision: 0.8279 - recall: 0.6268
# Epoch 32/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 677ms/step - accuracy: 0.7146 - f1_score: 0.6090 - loss: 0.7472 - precision: 0.7991 - recall: 0.6188
# Epoch 33/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 660ms/step - accuracy: 0.7348 - f1_score: 0.6242 - loss: 0.7299 - precision: 0.8290 - recall: 0.6516
# Epoch 34/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 665ms/step - accuracy: 0.7412 - f1_score: 0.6268 - loss: 0.7134 - precision: 0.8289 - recall: 0.6560
# Epoch 35/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 655ms/step - accuracy: 0.7314 - f1_score: 0.6257 - loss: 0.7076 - precision: 0.8190 - recall: 0.6347
# Epoch 36/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 655ms/step - accuracy: 0.7546 - f1_score: 0.6164 - loss: 0.6756 - precision: 0.8331 - recall: 0.6839
# Epoch 37/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 658ms/step - accuracy: 0.7579 - f1_score: 0.6383 - loss: 0.6744 - precision: 0.8373 - recall: 0.6693
# Epoch 38/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 666ms/step - accuracy: 0.7501 - f1_score: 0.6451 - loss: 0.7008 - precision: 0.8285 - recall: 0.6572
# Epoch 39/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 652ms/step - accuracy: 0.7385 - f1_score: 0.6279 - loss: 0.7077 - precision: 0.8141 - recall: 0.6452
# Epoch 40/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 656ms/step - accuracy: 0.7119 - f1_score: 0.6158 - loss: 0.7801 - precision: 0.8019 - recall: 0.6132
# Epoch 41/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 661ms/step - accuracy: 0.7170 - f1_score: 0.5997 - loss: 0.7662 - precision: 0.8116 - recall: 0.6223
# Epoch 42/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.7566 - f1_score: 0.6427 - loss: 0.7009 - precision: 0.8339 - recall: 0.6634
# Epoch 43/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 635ms/step - accuracy: 0.7629 - f1_score: 0.6523 - loss: 0.6347 - precision: 0.8321 - recall: 0.6802
# Epoch 44/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 636ms/step - accuracy: 0.7658 - f1_score: 0.6466 - loss: 0.6414 - precision: 0.8529 - recall: 0.6922
# Epoch 45/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 663ms/step - accuracy: 0.7654 - f1_score: 0.6680 - loss: 0.6264 - precision: 0.8391 - recall: 0.6799
# Epoch 46/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 633ms/step - accuracy: 0.7769 - f1_score: 0.6795 - loss: 0.6152 - precision: 0.8453 - recall: 0.6903
# Epoch 47/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 646ms/step - accuracy: 0.7637 - f1_score: 0.6633 - loss: 0.6411 - precision: 0.8353 - recall: 0.6960
# Epoch 48/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 651ms/step - accuracy: 0.7860 - f1_score: 0.7059 - loss: 0.5672 - precision: 0.8492 - recall: 0.7152
# Epoch 49/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 645ms/step - accuracy: 0.7867 - f1_score: 0.7008 - loss: 0.5700 - precision: 0.8529 - recall: 0.7115
# Epoch 50/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 632ms/step - accuracy: 0.7823 - f1_score: 0.6931 - loss: 0.6039 - precision: 0.8469 - recall: 0.7140
# Epoch 51/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 623ms/step - accuracy: 0.7977 - f1_score: 0.7019 - loss: 0.5675 - precision: 0.8603 - recall: 0.7465
# Epoch 52/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 637ms/step - accuracy: 0.8037 - f1_score: 0.7181 - loss: 0.5375 - precision: 0.8527 - recall: 0.7391
# Epoch 53/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 630ms/step - accuracy: 0.7958 - f1_score: 0.7184 - loss: 0.5259 - precision: 0.8507 - recall: 0.7378
# Epoch 54/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 631ms/step - accuracy: 0.7935 - f1_score: 0.7114 - loss: 0.5383 - precision: 0.8522 - recall: 0.7346
# Epoch 55/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 636ms/step - accuracy: 0.8161 - f1_score: 0.7593 - loss: 0.4939 - precision: 0.8691 - recall: 0.7745
# Epoch 56/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 642ms/step - accuracy: 0.8184 - f1_score: 0.7584 - loss: 0.4940 - precision: 0.8704 - recall: 0.7697
# Epoch 57/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 636ms/step - accuracy: 0.8271 - f1_score: 0.7755 - loss: 0.4724 - precision: 0.8681 - recall: 0.7832
# Epoch 58/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 634ms/step - accuracy: 0.8231 - f1_score: 0.7631 - loss: 0.4855 - precision: 0.8664 - recall: 0.7777
# Epoch 59/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 634ms/step - accuracy: 0.8276 - f1_score: 0.7708 - loss: 0.4622 - precision: 0.8696 - recall: 0.7855
# Epoch 60/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 654ms/step - accuracy: 0.8349 - f1_score: 0.7861 - loss: 0.4541 - precision: 0.8799 - recall: 0.7932
# Epoch 61/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 642ms/step - accuracy: 0.8396 - f1_score: 0.7991 - loss: 0.4376 - precision: 0.8825 - recall: 0.7993
# Epoch 62/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 645ms/step - accuracy: 0.8377 - f1_score: 0.7901 - loss: 0.4423 - precision: 0.8751 - recall: 0.8088
# Epoch 63/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 639ms/step - accuracy: 0.8389 - f1_score: 0.7981 - loss: 0.4528 - precision: 0.8797 - recall: 0.7977
# Epoch 64/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 639ms/step - accuracy: 0.8454 - f1_score: 0.8056 - loss: 0.4389 - precision: 0.8853 - recall: 0.8077
# Epoch 65/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.8592 - f1_score: 0.8335 - loss: 0.3939 - precision: 0.8972 - recall: 0.8170
# Epoch 66/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 642ms/step - accuracy: 0.8600 - f1_score: 0.8328 - loss: 0.3683 - precision: 0.9002 - recall: 0.8329
# Epoch 67/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 642ms/step - accuracy: 0.8459 - f1_score: 0.8074 - loss: 0.3934 - precision: 0.8867 - recall: 0.8204
# Epoch 68/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 636ms/step - accuracy: 0.8548 - f1_score: 0.8208 - loss: 0.4068 - precision: 0.8952 - recall: 0.8165
# Epoch 69/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 654ms/step - accuracy: 0.8568 - f1_score: 0.8293 - loss: 0.3914 - precision: 0.8959 - recall: 0.8225
# Epoch 70/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 640ms/step - accuracy: 0.8754 - f1_score: 0.8459 - loss: 0.3581 - precision: 0.9024 - recall: 0.8510
# Epoch 71/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 637ms/step - accuracy: 0.8699 - f1_score: 0.8460 - loss: 0.3557 - precision: 0.9118 - recall: 0.8408
# Epoch 72/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 655ms/step - accuracy: 0.8740 - f1_score: 0.8516 - loss: 0.3488 - precision: 0.9033 - recall: 0.8433
# Epoch 73/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 637ms/step - accuracy: 0.8770 - f1_score: 0.8505 - loss: 0.3455 - precision: 0.9052 - recall: 0.8423
# Epoch 74/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 634ms/step - accuracy: 0.8669 - f1_score: 0.8443 - loss: 0.3533 - precision: 0.9013 - recall: 0.8400
# Epoch 75/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 659ms/step - accuracy: 0.8769 - f1_score: 0.8447 - loss: 0.3455 - precision: 0.9083 - recall: 0.8588
# Epoch 76/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.8742 - f1_score: 0.8519 - loss: 0.3530 - precision: 0.9061 - recall: 0.8453
# Epoch 77/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 635ms/step - accuracy: 0.8702 - f1_score: 0.8486 - loss: 0.3347 - precision: 0.9037 - recall: 0.8399
# Epoch 78/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 643ms/step - accuracy: 0.8690 - f1_score: 0.8502 - loss: 0.3610 - precision: 0.8906 - recall: 0.8338
# Epoch 79/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 637ms/step - accuracy: 0.8738 - f1_score: 0.8580 - loss: 0.3226 - precision: 0.9092 - recall: 0.8474
# Epoch 80/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 651ms/step - accuracy: 0.8844 - f1_score: 0.8670 - loss: 0.3247 - precision: 0.9149 - recall: 0.8597
# Epoch 81/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 638ms/step - accuracy: 0.8964 - f1_score: 0.8788 - loss: 0.2946 - precision: 0.9200 - recall: 0.8711
# Epoch 82/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 641ms/step - accuracy: 0.8805 - f1_score: 0.8615 - loss: 0.3136 - precision: 0.9075 - recall: 0.8596
# Epoch 83/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 649ms/step - accuracy: 0.8872 - f1_score: 0.8646 - loss: 0.3209 - precision: 0.9089 - recall: 0.8588
# Epoch 84/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.8992 - f1_score: 0.8782 - loss: 0.2937 - precision: 0.9213 - recall: 0.8699
# Epoch 85/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 642ms/step - accuracy: 0.8802 - f1_score: 0.8621 - loss: 0.3251 - precision: 0.9103 - recall: 0.8578
# Epoch 86/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 636ms/step - accuracy: 0.8830 - f1_score: 0.8785 - loss: 0.3125 - precision: 0.9145 - recall: 0.8654
# Epoch 87/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 643ms/step - accuracy: 0.8937 - f1_score: 0.8806 - loss: 0.2975 - precision: 0.9218 - recall: 0.8658
# Epoch 88/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 655ms/step - accuracy: 0.8944 - f1_score: 0.8934 - loss: 0.2854 - precision: 0.9170 - recall: 0.8687
# Epoch 89/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 649ms/step - accuracy: 0.8895 - f1_score: 0.8756 - loss: 0.2889 - precision: 0.9129 - recall: 0.8678
# Epoch 90/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 636ms/step - accuracy: 0.8920 - f1_score: 0.8820 - loss: 0.2931 - precision: 0.9153 - recall: 0.8710
# Epoch 91/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 644ms/step - accuracy: 0.8902 - f1_score: 0.8777 - loss: 0.2922 - precision: 0.9175 - recall: 0.8711
# Epoch 92/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 637ms/step - accuracy: 0.9086 - f1_score: 0.9007 - loss: 0.2690 - precision: 0.9293 - recall: 0.8876
# Epoch 93/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 645ms/step - accuracy: 0.8947 - f1_score: 0.8932 - loss: 0.2954 - precision: 0.9163 - recall: 0.8680
# Epoch 94/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 652ms/step - accuracy: 0.9014 - f1_score: 0.8970 - loss: 0.2800 - precision: 0.9270 - recall: 0.8769
# Epoch 95/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 637ms/step - accuracy: 0.8946 - f1_score: 0.8850 - loss: 0.2862 - precision: 0.9203 - recall: 0.8706
# Epoch 96/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 643ms/step - accuracy: 0.9089 - f1_score: 0.9015 - loss: 0.2588 - precision: 0.9293 - recall: 0.8881
# Epoch 97/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 636ms/step - accuracy: 0.8967 - f1_score: 0.8815 - loss: 0.2763 - precision: 0.9215 - recall: 0.8696
# Epoch 98/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 639ms/step - accuracy: 0.9047 - f1_score: 0.8922 - loss: 0.2542 - precision: 0.9204 - recall: 0.8846
# Epoch 99/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 636ms/step - accuracy: 0.9045 - f1_score: 0.8959 - loss: 0.2585 - precision: 0.9226 - recall: 0.8857
# Epoch 100/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 655ms/step - accuracy: 0.9055 - f1_score: 0.9042 - loss: 0.2462 - precision: 0.9270 - recall: 0.8937
# Epoch 101/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 641ms/step - accuracy: 0.9020 - f1_score: 0.8992 - loss: 0.2577 - precision: 0.9245 - recall: 0.8843
# Epoch 102/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 647ms/step - accuracy: 0.8830 - f1_score: 0.8746 - loss: 0.3602 - precision: 0.9082 - recall: 0.8616
# Epoch 103/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 644ms/step - accuracy: 0.7313 - f1_score: 0.6568 - loss: 0.7979 - precision: 0.7903 - recall: 0.6629
# Epoch 104/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 644ms/step - accuracy: 0.8074 - f1_score: 0.7744 - loss: 0.5432 - precision: 0.8495 - recall: 0.7597
# Epoch 105/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 630ms/step - accuracy: 0.8595 - f1_score: 0.8351 - loss: 0.4165 - precision: 0.8962 - recall: 0.8263
# Epoch 106/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 639ms/step - accuracy: 0.8687 - f1_score: 0.8444 - loss: 0.3719 - precision: 0.8941 - recall: 0.8387
# Epoch 107/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 627ms/step - accuracy: 0.8620 - f1_score: 0.8517 - loss: 0.3790 - precision: 0.8951 - recall: 0.8357
# Epoch 108/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 628ms/step - accuracy: 0.8795 - f1_score: 0.8640 - loss: 0.3528 - precision: 0.8999 - recall: 0.8496
# Epoch 109/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 624ms/step - accuracy: 0.8810 - f1_score: 0.8660 - loss: 0.3429 - precision: 0.9100 - recall: 0.8611
# Epoch 110/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 64s 625ms/step - accuracy: 0.8651 - f1_score: 0.8516 - loss: 0.3914 - precision: 0.8954 - recall: 0.8344
# Epoch 111/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 631ms/step - accuracy: 0.9018 - f1_score: 0.8945 - loss: 0.2757 - precision: 0.9281 - recall: 0.8781
# Epoch 112/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 651ms/step - accuracy: 0.8929 - f1_score: 0.8784 - loss: 0.3198 - precision: 0.9156 - recall: 0.8761
# Epoch 113/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 653ms/step - accuracy: 0.9063 - f1_score: 0.8899 - loss: 0.2606 - precision: 0.9313 - recall: 0.8859
# Epoch 114/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 636ms/step - accuracy: 0.9173 - f1_score: 0.9122 - loss: 0.2461 - precision: 0.9307 - recall: 0.8989
# Epoch 115/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 635ms/step - accuracy: 0.9059 - f1_score: 0.9030 - loss: 0.2687 - precision: 0.9232 - recall: 0.8930
# Epoch 116/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 640ms/step - accuracy: 0.8973 - f1_score: 0.8871 - loss: 0.3109 - precision: 0.9172 - recall: 0.8803
# Epoch 117/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 638ms/step - accuracy: 0.8936 - f1_score: 0.8868 - loss: 0.2839 - precision: 0.9193 - recall: 0.8763
# Epoch 118/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 642ms/step - accuracy: 0.9119 - f1_score: 0.9097 - loss: 0.2448 - precision: 0.9289 - recall: 0.8975
# Epoch 119/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 649ms/step - accuracy: 0.9145 - f1_score: 0.9140 - loss: 0.2528 - precision: 0.9276 - recall: 0.8994
# Epoch 120/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 635ms/step - accuracy: 0.9260 - f1_score: 0.9254 - loss: 0.2361 - precision: 0.9373 - recall: 0.9087
# Epoch 121/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 642ms/step - accuracy: 0.9072 - f1_score: 0.9011 - loss: 0.2451 - precision: 0.9283 - recall: 0.8947
# Epoch 122/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 633ms/step - accuracy: 0.9187 - f1_score: 0.9168 - loss: 0.2248 - precision: 0.9362 - recall: 0.9014
# Epoch 123/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 637ms/step - accuracy: 0.9104 - f1_score: 0.9020 - loss: 0.2578 - precision: 0.9262 - recall: 0.8955
# Epoch 124/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 640ms/step - accuracy: 0.9141 - f1_score: 0.9157 - loss: 0.2290 - precision: 0.9292 - recall: 0.9004
# Epoch 125/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 656ms/step - accuracy: 0.9261 - f1_score: 0.9250 - loss: 0.2197 - precision: 0.9414 - recall: 0.9135
# Epoch 126/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 638ms/step - accuracy: 0.9162 - f1_score: 0.9094 - loss: 0.2363 - precision: 0.9314 - recall: 0.9062
# Epoch 127/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 633ms/step - accuracy: 0.9074 - f1_score: 0.9049 - loss: 0.2492 - precision: 0.9294 - recall: 0.8965
# Epoch 128/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 640ms/step - accuracy: 0.9233 - f1_score: 0.9213 - loss: 0.1949 - precision: 0.9409 - recall: 0.9156
# Epoch 129/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 65s 631ms/step - accuracy: 0.9167 - f1_score: 0.9108 - loss: 0.2246 - precision: 0.9314 - recall: 0.9043
# Epoch 130/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 637ms/step - accuracy: 0.9188 - f1_score: 0.9175 - loss: 0.2159 - precision: 0.9342 - recall: 0.9075
# Epoch 131/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 645ms/step - accuracy: 0.9327 - f1_score: 0.9335 - loss: 0.2017 - precision: 0.9446 - recall: 0.9252
# Epoch 132/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 642ms/step - accuracy: 0.9244 - f1_score: 0.9258 - loss: 0.2010 - precision: 0.9418 - recall: 0.9102
# Epoch 133/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 633ms/step - accuracy: 0.9208 - f1_score: 0.9188 - loss: 0.2229 - precision: 0.9334 - recall: 0.9092
# Epoch 134/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 634ms/step - accuracy: 0.9167 - f1_score: 0.9098 - loss: 0.2183 - precision: 0.9304 - recall: 0.9070
# Epoch 135/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 640ms/step - accuracy: 0.9308 - f1_score: 0.9302 - loss: 0.1954 - precision: 0.9456 - recall: 0.9210
# Epoch 136/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 647ms/step - accuracy: 0.9261 - f1_score: 0.9279 - loss: 0.1983 - precision: 0.9423 - recall: 0.9126
# Epoch 137/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 637ms/step - accuracy: 0.9348 - f1_score: 0.9334 - loss: 0.1908 - precision: 0.9463 - recall: 0.9257
# Epoch 138/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 643ms/step - accuracy: 0.9315 - f1_score: 0.9287 - loss: 0.1929 - precision: 0.9458 - recall: 0.9228
# Epoch 139/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 649ms/step - accuracy: 0.9306 - f1_score: 0.9296 - loss: 0.1822 - precision: 0.9444 - recall: 0.9177
# Epoch 140/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 640ms/step - accuracy: 0.9395 - f1_score: 0.9395 - loss: 0.1645 - precision: 0.9555 - recall: 0.9312
# Epoch 141/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 637ms/step - accuracy: 0.9273 - f1_score: 0.9284 - loss: 0.1870 - precision: 0.9397 - recall: 0.9189
# Epoch 142/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 631ms/step - accuracy: 0.9247 - f1_score: 0.9295 - loss: 0.2144 - precision: 0.9367 - recall: 0.9136
# Epoch 143/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 639ms/step - accuracy: 0.9394 - f1_score: 0.9394 - loss: 0.1867 - precision: 0.9520 - recall: 0.9239
# Epoch 144/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.9397 - f1_score: 0.9458 - loss: 0.1630 - precision: 0.9558 - recall: 0.9290
# Epoch 145/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 638ms/step - accuracy: 0.9324 - f1_score: 0.9372 - loss: 0.1967 - precision: 0.9378 - recall: 0.9190
# Epoch 146/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 639ms/step - accuracy: 0.9397 - f1_score: 0.9424 - loss: 0.1758 - precision: 0.9489 - recall: 0.9302
# Epoch 147/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 654ms/step - accuracy: 0.9295 - f1_score: 0.9232 - loss: 0.1835 - precision: 0.9452 - recall: 0.9181
# Epoch 148/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 652ms/step - accuracy: 0.9313 - f1_score: 0.9347 - loss: 0.1800 - precision: 0.9439 - recall: 0.9193
# Epoch 149/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 643ms/step - accuracy: 0.9416 - f1_score: 0.9449 - loss: 0.1529 - precision: 0.9539 - recall: 0.9319
# Epoch 150/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 640ms/step - accuracy: 0.9313 - f1_score: 0.9361 - loss: 0.1859 - precision: 0.9379 - recall: 0.9221
# Epoch 151/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 649ms/step - accuracy: 0.9326 - f1_score: 0.9332 - loss: 0.1865 - precision: 0.9413 - recall: 0.9265
# Epoch 152/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 645ms/step - accuracy: 0.9371 - f1_score: 0.9391 - loss: 0.1731 - precision: 0.9491 - recall: 0.9282
# Epoch 153/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 641ms/step - accuracy: 0.9340 - f1_score: 0.9368 - loss: 0.1994 - precision: 0.9457 - recall: 0.9176
# Epoch 154/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 643ms/step - accuracy: 0.9364 - f1_score: 0.9418 - loss: 0.1890 - precision: 0.9469 - recall: 0.9226
# Epoch 155/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 648ms/step - accuracy: 0.9302 - f1_score: 0.9260 - loss: 0.1834 - precision: 0.9446 - recall: 0.9244
# Epoch 156/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 643ms/step - accuracy: 0.9370 - f1_score: 0.9396 - loss: 0.1619 - precision: 0.9492 - recall: 0.9264
# Epoch 157/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 642ms/step - accuracy: 0.9462 - f1_score: 0.9498 - loss: 0.1499 - precision: 0.9584 - recall: 0.9389
# Epoch 158/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 657ms/step - accuracy: 0.9422 - f1_score: 0.9388 - loss: 0.1492 - precision: 0.9567 - recall: 0.9304
# Epoch 159/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 648ms/step - accuracy: 0.9426 - f1_score: 0.9479 - loss: 0.1512 - precision: 0.9512 - recall: 0.9334
# Epoch 160/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 637ms/step - accuracy: 0.9452 - f1_score: 0.9472 - loss: 0.1500 - precision: 0.9547 - recall: 0.9334
# Epoch 161/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 66s 640ms/step - accuracy: 0.9398 - f1_score: 0.9404 - loss: 0.1790 - precision: 0.9531 - recall: 0.9295
# Epoch 162/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 649ms/step - accuracy: 0.9403 - f1_score: 0.9454 - loss: 0.1706 - precision: 0.9486 - recall: 0.9300
# Epoch 163/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 662ms/step - accuracy: 0.9478 - f1_score: 0.9588 - loss: 0.1586 - precision: 0.9558 - recall: 0.9396
# Epoch 164/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 663ms/step - accuracy: 0.9348 - f1_score: 0.9385 - loss: 0.1681 - precision: 0.9464 - recall: 0.9233
# Epoch 165/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 660ms/step - accuracy: 0.9337 - f1_score: 0.9364 - loss: 0.1685 - precision: 0.9486 - recall: 0.9237
# Epoch 166/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 655ms/step - accuracy: 0.9357 - f1_score: 0.9415 - loss: 0.1910 - precision: 0.9431 - recall: 0.9273
# Epoch 167/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 664ms/step - accuracy: 0.9512 - f1_score: 0.9494 - loss: 0.1356 - precision: 0.9585 - recall: 0.9454
# Epoch 168/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 673ms/step - accuracy: 0.9399 - f1_score: 0.9432 - loss: 0.1537 - precision: 0.9499 - recall: 0.9335
# Epoch 169/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 670ms/step - accuracy: 0.9502 - f1_score: 0.9528 - loss: 0.1231 - precision: 0.9634 - recall: 0.9467
# Epoch 170/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 662ms/step - accuracy: 0.9537 - f1_score: 0.9587 - loss: 0.1321 - precision: 0.9586 - recall: 0.9483
# Epoch 171/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 656ms/step - accuracy: 0.9552 - f1_score: 0.9599 - loss: 0.1212 - precision: 0.9639 - recall: 0.9518
# Epoch 172/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 660ms/step - accuracy: 0.9515 - f1_score: 0.9572 - loss: 0.1405 - precision: 0.9552 - recall: 0.9434
# Epoch 173/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 673ms/step - accuracy: 0.9485 - f1_score: 0.9492 - loss: 0.1409 - precision: 0.9562 - recall: 0.9422
# Epoch 174/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 664ms/step - accuracy: 0.9532 - f1_score: 0.9555 - loss: 0.1193 - precision: 0.9619 - recall: 0.9484
# Epoch 175/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 672ms/step - accuracy: 0.9493 - f1_score: 0.9566 - loss: 0.1390 - precision: 0.9570 - recall: 0.9421
# Epoch 176/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 70s 675ms/step - accuracy: 0.9516 - f1_score: 0.9581 - loss: 0.1375 - precision: 0.9581 - recall: 0.9470
# Epoch 177/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 652ms/step - accuracy: 0.9569 - f1_score: 0.9594 - loss: 0.1307 - precision: 0.9673 - recall: 0.9524
# Epoch 178/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 664ms/step - accuracy: 0.9486 - f1_score: 0.9550 - loss: 0.1370 - precision: 0.9571 - recall: 0.9421
# Epoch 179/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 69s 673ms/step - accuracy: 0.9423 - f1_score: 0.9443 - loss: 0.1423 - precision: 0.9546 - recall: 0.9368
# Epoch 180/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 657ms/step - accuracy: 0.9414 - f1_score: 0.9437 - loss: 0.1457 - precision: 0.9529 - recall: 0.9362
# Epoch 181/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 652ms/step - accuracy: 0.9547 - f1_score: 0.9563 - loss: 0.1252 - precision: 0.9635 - recall: 0.9457
# Epoch 182/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 656ms/step - accuracy: 0.9559 - f1_score: 0.9601 - loss: 0.1131 - precision: 0.9653 - recall: 0.9503
# Epoch 183/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 68s 659ms/step - accuracy: 0.9495 - f1_score: 0.9544 - loss: 0.1318 - precision: 0.9565 - recall: 0.9464
# Epoch 184/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 645ms/step - accuracy: 0.9545 - f1_score: 0.9571 - loss: 0.1355 - precision: 0.9598 - recall: 0.9484
# Epoch 185/185
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 67s 646ms/step - accuracy: 0.9469 - f1_score: 0.9511 - loss: 0.1363 - precision: 0.9558 - recall: 0.9377
# Training metrics saved to training_metrics.csv
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 144s 6s/step - accuracy: 0.9001 - f1_score: 0.9144 - loss: 0.3182 - precision: 0.9099 - recall: 0.8906
# Test Loss: 0.3343764543533325
# Test Accuracy: 0.8971354365348816
# Test Precision: 0.9077540040016174
# Test Recall: 0.8841145634651184
# Test F1 Score: tf.Tensor(
# [0.9032257  0.9719625  0.7314814  0.9803921  0.91262126 0.9117221
#  0.96      ], shape=(7,), dtype=float32)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator

num_classes = 7
height = 128
n_fft = 2048
hop_length = 256
sr = 16000
T = 1

hop_size_sec = hop_length / sr
audio_length_samples = T * sr

width = 1 + int((audio_length_samples - n_fft) / hop_length)

channels = 3

batch_size = 32

model = tf.keras.models.load_model('al-emadi_rnn_mcc_standardized_unknown_256HL.keras')

test_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms_256HL/Test/'

test_datagen = ImageDataGenerator()

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(height, width),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

loss, accuracy, precision, recall, f1_score = model.evaluate(test_generator)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test F1 Score:", f1_score)

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true class labels
true_classes = test_generator.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)
print("\nConfusion Matrix:")
print(conf_matrix)

# Get class labels
class_labels = list(test_generator.class_indices.keys())

# Calculate accuracy for each class
class_accuracy = {}
for i, class_label in enumerate(class_labels):
    correct_indices = np.where(true_classes == i)[0]
    correct_predictions = np.sum(predicted_classes[correct_indices] == i)
    total_samples = len(correct_indices)
    class_accuracy[class_label] = correct_predictions / total_samples if total_samples > 0 else 0.0

# Print accuracy for each class
print("\nAccuracy for each class:")
for class_label in class_labels:
    print(f"{class_label}: {class_accuracy[class_label]:.4f}")

# Print classification report (includes precision, recall, F1-score)
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# Found 768 images belonging to 7 classes.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 28s 786ms/step - accuracy: 0.9169 - f1_score: 0.6205 - loss: 0.2990 - precision: 0.9277 - recall: 0.9072
# Test Loss: 0.3343764841556549
# Test Accuracy: 0.8971354365348816
# Test Precision: 0.9077540040016174
# Test Recall: 0.8841145634651184
# Test F1 Score: tf.Tensor(
# [0.9032257  0.9719625  0.7314814  0.9803921  0.91262126 0.9117221
#  0.96      ], shape=(7,), dtype=float32)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 13s 524ms/step
#
# Confusion Matrix:
# [[ 98   0   3   0   0   3   0]
#  [  0  52   0   0   0   0   0]
#  [  8   1  79   1   1  14   0]
#  [  0   0   0  50   0   0   0]
#  [  0   0   0   1  47   2   0]
#  [  7   2  30   0   2 315   1]
#  [  0   0   0   0   3   0  48]]
#
# Accuracy for each class:
# Bebop: 0.9423
# Crazyflie: 1.0000
# Mambo: 0.7596
# Matrice100: 1.0000
# Mavic: 0.9400
# NonDrone: 0.8824
# Phantom: 0.9412
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Bebop       0.87      0.94      0.90       104
#    Crazyflie       0.95      1.00      0.97        52
#        Mambo       0.71      0.76      0.73       104
#   Matrice100       0.96      1.00      0.98        50
#        Mavic       0.89      0.94      0.91        50
#     NonDrone       0.94      0.88      0.91       357
#      Phantom       0.98      0.94      0.96        51
#
#     accuracy                           0.90       768
#    macro avg       0.90      0.92      0.91       768
# weighted avg       0.90      0.90      0.90       768

# %%
import os
import numpy as np
from scipy.stats import entropy
from tensorflow.keras.preprocessing import image

model = tf.keras.models.load_model('/content/al-emadi_rnn_mcc_standardized_unknown_256HL.keras')
classes = ['Bebop', 'Crazyflie', 'Mambo', 'Matrice100', 'Mavic', 'NonDrone', 'Phantom']

known_counter = 0
unknown_counter = 0

def load_spectrogram(file_path):
    # Load and preprocess the image
    num_classes = 7
    height = 128
    n_fft = 2048
    hop_length = 256
    sr = 16000
    T = 1

    hop_size_sec = hop_length / sr
    audio_length_samples = T * sr

    width = 1 + int((audio_length_samples - n_fft) / hop_length)

    channels = 3

    img = image.load_img(file_path, target_size=(height, width))  # Assuming input size expected by your model
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    #img_array = img_array / 255.0  # Normalize pixel values to [0, 1]
    return img_array

# Function to classify a single spectrogram
def classify_spectrogram(spectrogram, entropy_threshold):
    global known_counter
    global unknown_counter

    probabilities = model.predict(spectrogram)[0]  # Get class probabilities from the model
    ent = entropy(probabilities, base=2)  # Calculate entropy of the probability distribution

    if ent > entropy_threshold:
        unknown_counter+=1
        return "UnknownDrone"
    else:
        known_counter+=1
        max_index = np.argmax(probabilities)  # Get the index of the maximum probability
        return classes[max_index]  # Return the corresponding drone class

# Directory containing spectrogram files
unknown_spectrogram_dir = '/content/drive/MyDrive/UnknownDrone_256HL/'
spectrogram_dir = '/content/drive/MyDrive/Colab Notebooks/TAMUCC REU 2024/DS1/Al-Emadi_Standardized_Unknown_Spectrograms_256HL/Test/Phantom/'

# Entropy threshold
entropy_threshold =  0.018 # Adjust this threshold based on your model and validation results

# List all files in the directory
spectrogram_files = os.listdir(spectrogram_dir)

# Process each spectrogram file
for filename in spectrogram_files:
    if filename.endswith('.png'):  # Assuming spectrograms are saved as PNG files
        # Load the spectrogram (you need to implement this part based on your data loading method)
        spectrogram = load_spectrogram(os.path.join(spectrogram_dir, filename))

        # Classify the spectrogram
        predicted_class = classify_spectrogram(spectrogram, entropy_threshold)

        # Print the filename and predicted class
        print(f"{filename}: {predicted_class}")

print("Unknown Drone Count:", unknown_counter)
print("Known Drone Count:", known_counter)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Phantom_Test_File1_0_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Phantom_Test_File1_8_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Phantom_Test_File2_3_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Phantom_Test_File2_10_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Phantom_Test_File2_13_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Phantom_Test_File2_16_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Phantom_Test_File2_21_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Phantom_Test_File2_24_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Phantom_Test_File3_4_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Phantom_Test_File3_9_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Phantom_Test_File1_0_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Phantom_Test_File1_8_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Phantom_Test_File2_3_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Phantom_Test_File2_10_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Phantom_Test_File2_13_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Phantom_Test_File2_16_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Phantom_Test_File2_21_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Phantom_Test_File2_24_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Phantom_Test_File2_26_PS-2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File3_4_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Phantom_Test_File3_9_PS-2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File1_0_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File1_8_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Phantom_Test_File2_3_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File2_10_PS-1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File2_13_PS-1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File2_16_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File2_21_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Phantom_Test_File2_24_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Phantom_Test_File3_4_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File3_9_PS-1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Phantom_Test_File1_0_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Phantom_Test_File1_8_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File2_3_PS+1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Phantom_Test_File2_10_PS+1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Phantom_Test_File2_13_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Phantom_Test_File2_16_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Phantom_Test_File2_21_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Phantom_Test_File2_24_PS+1_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Phantom_Test_File3_4_PS+1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Phantom_Test_File3_9_PS+1_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Phantom_Test_File1_0_PS+2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Phantom_Test_File1_8_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Phantom_Test_File2_3_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Phantom_Test_File2_10_PS+2_mel.png: UnknownDrone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Phantom_Test_File2_13_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Phantom_Test_File2_16_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Phantom_Test_File2_21_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Phantom_Test_File2_24_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Phantom_Test_File3_4_PS+2_mel.png: Phantom
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Phantom_Test_File3_9_PS+2_mel.png: Phantom
# Unknown Drone Count: 14
# Known Drone Count: 37
